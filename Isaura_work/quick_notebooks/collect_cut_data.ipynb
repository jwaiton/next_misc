# %% [markdown]
# #### a notebook to save all the data from the efficiency cuts for future use
# Applying the cuts every time is just stupid

# %%
import sys,os,os.path

sys.path.append("../../")   # cite IC from parent directory
                            # NOTE if you can't import IC stuff, its because of the
                            # above line
#sys.path.append(os.path.expanduser('~/code/eol_hsrl_python'))
os.environ['ICTDIR']='/home/e78368jw/Documents/NEXT_CODE/IC'

import matplotlib.pyplot as plt
import pandas as pd
import numpy  as np
import tables as tb
import IC.invisible_cities.io.dst_io                           as     dstio
import IC.invisible_cities.io.mcinfo_io as mcio
from    IC.invisible_cities.core.core_functions   import shift_to_bin_centers

import scipy.special as special
from scipy.stats import skewnorm
from scipy.optimize import curve_fit

from scipy.integrate import quad

from Th_studies.functions import isaura_analyse as isa

# %%
def apply_cuts_raw(tracks, e_low_cut = 0.05, fid_lower_z = 20, fid_upper_z = 1195, fid_r_lim = 472, e_lower = 1.35, e_upper = 1.9):
    '''
    Apply all relevant cuts and spit out dataframe at the end
    The most barebones version, no efficiency calcs, it just spits out the dataframe
    '''


    # Low energy tracks, make this function work better. It seems busted currently
    low_e_cut_tracks = isa.remove_low_E_events(tracks, energy_limit = e_low_cut)
  
    # make fiducial cuts
    fiducial_rel = isa.fiducial_track_cut_2(low_e_cut_tracks, lower_z = fid_lower_z, upper_z=fid_upper_z, r_lim = fid_r_lim, verbose = False)

    # one track cuts 
    one_track_rel = isa.one_track_cuts(fiducial_rel, verbose = False)

    # overlapping blob cut
    ovlp_rel = isa.overlapping_cuts(one_track_rel)


    # energy cuts
    ecut_rel = isa.energy_cuts(ovlp_rel, lower_e = e_lower, upper_e = e_upper)

    # return it
    return ecut_rel

# %%
folder_path = '../LPR_rerun_voxel/isaura_10x10x10mm/PORT_1a/prod/isaura/'

# load in tracks
data = isa.load_tracks(folder_path)
# Out:
# Warning! This method may take some time,
# and works best with smaller datasets (like LPR).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_97968/3730254169.py in ?()
# ----> 4 folder_path = '../LPR_rerun_voxel/isaura_10x10x10mm/PORT_1a/prod/isaura/'
#       5
#       6 # load in tracks
#       7 data = isa.load_tracks(folder_path)
#
# ~/Documents/NEXT_CODE/Th_studies/quick_notebooks/../../Th_studies/functions/isaura_analyse.py in ?(data_path, filter)
#     953     print("Warning! This method may take some time,\nand works best with smaller datasets (like LPR).")
#     954     for file in file_names:
#     955
#     956         file_path = data_path + file
# --> 957         df = dstio.load_dst(file_path, 'Tracking', 'Tracks')
#     958         df_tracks.append(df)
#     959
#     960         # tracking
#
# ~/Documents/NEXT_CODE/Th_studies/quick_notebooks/../../IC/invisible_cities/io/dst_io.py in ?(filename, group, node, evt_list, ignore_errors)
#      42             warnings.warn(f' corrupted: file = {filename} ', UserWarning)
#      43         except IOError:
#      44             warnings.warn(f' does not exist: file = {filename} ', UserWarning)
#      45     else:
# ---> 46         return read_dst_(filename, group, node, evt_list)
#
# ~/Documents/NEXT_CODE/Th_studies/quick_notebooks/../../IC/invisible_cities/io/dst_io.py in ?(filename, group, node, evt_list)
#      30                 values = table.read()
#      31             else:
#      32                 events = table.read(field='event')
#      33                 values = table.read_coordinates(np.where(np.isin(events, evt_list)))
# ---> 34             return _decode_str_columns(pd.DataFrame.from_records(values, columns=table.colnames))
#
# ~/Documents/NEXT_CODE/Th_studies/quick_notebooks/../../IC/invisible_cities/io/dst_io.py in ?(df)
#      18 def _decode_str_columns(df):
#      19     to_string = lambda x: x.astype(bytes).str.decode('utf-8') if x.dtype == object else x
# ---> 20     df        = df.apply(to_string)
#      21     return df
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    8736             result_type=result_type,
#    8737             args=args,
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/apply.py in ?(self)
#     684         # raw
#     685         elif self.raw:
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/apply.py in ?(self)
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#     815         return self.wrap_results(results, res_index)
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/apply.py in ?(self)
#     828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#     831                     #  series_generator will swap out the underlying data
# --> 832                     results[i] = results[i].copy(deep=False)
#     833
#     834         return results, res_index
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/apply.py in ?(.0)
# --> 878     def series_generator(self):
#     879         return (self.obj._ixs(i, axis=1) for i in range(len(self.columns)))
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, i, axis)
#    3393         else:
#    3394             label = self.columns[i]
#    3395
#    3396             values = self._mgr.iget(i)
# -> 3397             result = self._box_col_values(values, i)
#    3398
#    3399             # this is a cached value, mark it so
#    3400             result._set_as_cached(label, self)
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, values, loc)
#    3864         # Lookup in columns so that if e.g. a str datetime was passed
#    3865         #  we attach the Timestamp object as the name.
#    3866         name = self.columns[loc]
#    3867         klass = self._constructor_sliced
# -> 3868         return klass(values, index=self.index, name=name, fastpath=True)
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     443                     data = SingleBlockManager.from_array(data, index)
#     444                 elif manager == "array":
#     445                     data = SingleArrayManager.from_array(data, index)
#     446
# --> 447         generic.NDFrame.__init__(self, data)
#     448         self.name = name
#     449         self._set_axis(0, index, fastpath=True)
#
# ~/anaconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, data, copy, attrs)
#     241         object.__setattr__(self, "_is_copy", None)
#     242         object.__setattr__(self, "_mgr", data)
#     243         object.__setattr__(self, "_item_cache", {})
#     244         if attrs is None:
# --> 245             attrs = {}
#     246         else:
#     247             attrs = dict(attrs)
#     248         object.__setattr__(self, "_attrs", attrs)
#
# KeyboardInterrupt:

# %%
display(data)
# Out:
#           event  trackID    energy      length  numb_of_voxels  numb_of_hits  \
# 0       5080000        0  1.051154  121.454061             104         11063
# 1       5080000        1  0.013352    9.928571               2            71
# 2       5080002        0  1.768218  136.325163             128         11033
# 3       5080002        1  0.309468  112.683992              31          1829
# 4       5080002        2  0.019542   13.772242               2             4
# ...         ...      ...       ...         ...             ...           ...
# 258315  4060708        1  0.121964   14.142136               3          1244
# 258316  4060708        2  0.033485   10.000000               2           144
# 258317  4060710        0  0.572125   44.565517              36          7243
# 258318  4060712        0  0.888838  109.999957              76          6895
# 258319  4060712        1  0.000585    0.000000               1            18
#
#         numb_of_tracks    x_min    y_min       z_min  ...     blob1_z  \
# 0                    2  368.675  160.675  334.439758  ...  358.948175
# 1                    2  388.675  270.675  440.460083  ...  442.236380
# 2                    5  -98.325  361.675  587.473511  ...  613.110772
# 3                    5   52.675  348.675  498.257599  ...  502.310940
# 4                    5   18.675  351.675  555.981140  ...  563.299622
# ...                ...      ...      ...         ...  ...         ...
# 258315               3  184.675  346.675  305.074768  ...  309.084361
# 258316               3  153.675  366.675  386.938629  ...  389.045441
# 258317               1  315.675  294.675  522.397217  ...  532.700813
# 258318               2   -6.325  415.675  335.498718  ...  352.800524
# 258319               2   65.675  424.675  350.184662  ...  350.184662
#
#            blob2_x     blob2_y     blob2_z    eblob1    eblob2  \
# 0       381.376657  256.794897  408.658585  0.483891  0.015104
# 1       390.287922  283.647294  446.131930  0.013352  0.013352
# 2        -6.622819  382.940215  589.840154  0.162713  0.073897
# 3        54.698632  349.802676  526.248103  0.162199  0.021946
# 4        27.644104  359.876147  555.981140  0.019542  0.019542
# ...            ...         ...         ...       ...       ...
# 258315  199.819036  352.583988  308.110573  0.121964  0.121964
# 258316  162.594082  366.980910  390.887885  0.033485  0.033472
# 258317  331.038243  299.916212  527.865748  0.279909  0.256440
# 258318   25.058429  476.143700  418.546023  0.688630  0.026967
# 258319   67.733877  426.232716  350.184662  0.000585  0.000585
#
#         ovlp_blob_energy  vox_size_x  vox_size_y  vox_size_z
# 0               0.000000    9.857143    9.928571    9.619794
# 1               0.013352    9.857143    9.928571    9.619794
# 2               0.000000    9.750000    9.571429    9.902647
# 3               0.000000    9.750000    9.571429    9.902647
# 4               0.019542    9.750000    9.571429    9.902647
# ...                  ...         ...         ...         ...
# 258315          0.121964   10.000000   10.000000    9.859631
# 258316          0.033472   10.000000   10.000000    9.859631
# 258317          0.002211    9.833333    9.428571    8.912888
# 258318          0.000000    9.500000    8.875000    9.673330
# 258319          0.000585    9.500000    8.875000    9.673330
#
# [258320 rows x 37 columns]

# %%
cut_data = apply_cuts_raw(data)
# Out:
# 96485
# 66540
# 11009
# /home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/../../Th_studies/functions/isaura_analyse.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_low_E['numb_of_tracks'] = remove_low_E['event'].map(event_counts)

# %%
display(cut_data)
# Out:
#           event  trackID    energy      length  numb_of_voxels  numb_of_hits  \
# 85      5080072        0  1.446411  269.412086             160         11861
# 184     5080188        0  1.596243  137.456298             113         11993
# 393     5080380        0  1.524555  192.344174             105         10753
# 518     5080496        0  1.594183  154.743531             127         12870
# 606     5080582        0  1.595847  134.427703             165         12424
# ...         ...      ...       ...         ...             ...           ...
# 187807  4060288        0  1.511853  126.138705              76         11089
# 187873  4060350        0  1.594714  193.786162             142         12044
# 187893  4060374        0  1.604224  110.101848             113         13741
# 188001  4060490        0  1.864831  381.203537             167         13538
# 188003  4060498        0  1.590435  178.002963             131         11709
#
#         numb_of_tracks    x_min    y_min       z_min  ...     blob1_z  \
# 85                   1  239.675  -28.325  122.387062  ...  138.525487
# 184                  1  156.675  107.675  734.490601  ...  789.447427
# 393                  1    8.675 -246.325   88.786362  ...   95.391985
# 518                  1  147.675 -166.325  322.920868  ...  348.181738
# 606                  1  293.675  -43.325  683.036133  ...  726.958593
# ...                ...      ...      ...         ...  ...         ...
# 187807               1   36.675  208.675  132.908066  ...  142.685251
# 187873               1   43.675   21.675  412.145233  ...  443.268241
# 187893               1  231.675  227.675  516.088623  ...  540.399202
# 188001               1  107.675  156.675  112.931786  ...  130.044463
# 188003               1   17.675 -233.325  486.703430  ...  491.400110
#
#            blob2_x     blob2_y     blob2_z    eblob1    eblob2  \
# 85      275.569139   50.293813  288.435271  0.262021  0.093567
# 184     249.494267  184.766019  738.319437  0.511776  0.245868
# 393      90.288190 -141.125375  211.595246  0.350357  0.040686
# 518     150.682122 -134.107884  329.234220  0.444847  0.443488
# 606     344.200068   58.357780  714.376938  0.327431  0.169420
# ...            ...         ...         ...       ...       ...
# 187807   40.680198  236.922760  162.777904  0.448037  0.408669
# 187873   95.273416   71.054266  541.965957  0.498915  0.433457
# 187893  301.620382  314.980297  538.400907  0.565798  0.366740
# 188001  161.745678  263.632032  197.834300  0.487851  0.043959
# 188003   47.331190 -219.427662  532.143136  0.459535  0.165835
#
#         ovlp_blob_energy  vox_size_x  vox_size_y  vox_size_z
# 85                   0.0    9.538462    9.357143    9.500244
# 184                  0.0   10.000000    9.333333    9.592146
# 393                  0.0    9.666667    9.666667    9.603581
# 518                  0.0    9.533333    9.200000    8.737142
# 606                  0.0    9.272727    9.615385    8.566711
# ...                  ...         ...         ...         ...
# 187807               0.0    9.866667    9.571429    9.222986
# 187873               0.0    9.769231    9.000000    9.744980
# 187893               0.0    9.625000    9.300000    9.434460
# 188001               0.0    9.782609    9.750000    9.553649
# 188003               0.0    9.700000    9.636364    9.337909
#
# [2637 rows x 37 columns]

# %%
# save cut data
cut_data.to_hdf('P_1A_10x10x10.h5', key = 'cut', mode = 'w')

# %%
test = pd.read_hdf('P_1A_10x10x10.h5')
display(test)
del test
# Out:
#           event  trackID    energy      length  numb_of_voxels  numb_of_hits  \
# 85      5080072        0  1.446411  269.412086             160         11861
# 184     5080188        0  1.596243  137.456298             113         11993
# 393     5080380        0  1.524555  192.344174             105         10753
# 518     5080496        0  1.594183  154.743531             127         12870
# 606     5080582        0  1.595847  134.427703             165         12424
# ...         ...      ...       ...         ...             ...           ...
# 187807  4060288        0  1.511853  126.138705              76         11089
# 187873  4060350        0  1.594714  193.786162             142         12044
# 187893  4060374        0  1.604224  110.101848             113         13741
# 188001  4060490        0  1.864831  381.203537             167         13538
# 188003  4060498        0  1.590435  178.002963             131         11709
#
#         numb_of_tracks    x_min    y_min       z_min  ...     blob1_z  \
# 85                   1  239.675  -28.325  122.387062  ...  138.525487
# 184                  1  156.675  107.675  734.490601  ...  789.447427
# 393                  1    8.675 -246.325   88.786362  ...   95.391985
# 518                  1  147.675 -166.325  322.920868  ...  348.181738
# 606                  1  293.675  -43.325  683.036133  ...  726.958593
# ...                ...      ...      ...         ...  ...         ...
# 187807               1   36.675  208.675  132.908066  ...  142.685251
# 187873               1   43.675   21.675  412.145233  ...  443.268241
# 187893               1  231.675  227.675  516.088623  ...  540.399202
# 188001               1  107.675  156.675  112.931786  ...  130.044463
# 188003               1   17.675 -233.325  486.703430  ...  491.400110
#
#            blob2_x     blob2_y     blob2_z    eblob1    eblob2  \
# 85      275.569139   50.293813  288.435271  0.262021  0.093567
# 184     249.494267  184.766019  738.319437  0.511776  0.245868
# 393      90.288190 -141.125375  211.595246  0.350357  0.040686
# 518     150.682122 -134.107884  329.234220  0.444847  0.443488
# 606     344.200068   58.357780  714.376938  0.327431  0.169420
# ...            ...         ...         ...       ...       ...
# 187807   40.680198  236.922760  162.777904  0.448037  0.408669
# 187873   95.273416   71.054266  541.965957  0.498915  0.433457
# 187893  301.620382  314.980297  538.400907  0.565798  0.366740
# 188001  161.745678  263.632032  197.834300  0.487851  0.043959
# 188003   47.331190 -219.427662  532.143136  0.459535  0.165835
#
#         ovlp_blob_energy  vox_size_x  vox_size_y  vox_size_z
# 85                   0.0    9.538462    9.357143    9.500244
# 184                  0.0   10.000000    9.333333    9.592146
# 393                  0.0    9.666667    9.666667    9.603581
# 518                  0.0    9.533333    9.200000    8.737142
# 606                  0.0    9.272727    9.615385    8.566711
# ...                  ...         ...         ...         ...
# 187807               0.0    9.866667    9.571429    9.222986
# 187873               0.0    9.769231    9.000000    9.744980
# 187893               0.0    9.625000    9.300000    9.434460
# 188001               0.0    9.782609    9.750000    9.553649
# 188003               0.0    9.700000    9.636364    9.337909
#
# [2637 rows x 37 columns]

# %%
folder_paths =  ['../LPR_rerun_voxel/isaura_10x10x10mm/PORT_1a/prod/isaura/',
                '../LPR_rerun_voxel/isaura_10x10x10mm/PORT_1b/prod/isaura/',
                '../LPR_rerun_voxel/isaura_10x10x10mm/PORT_2a/prod/isaura/',
                '../LPR_rerun_voxel/isaura_10x10x10mm/PORT_2b/prod/isaura/']
h5_file_names = ['P1A_10x10x10.h5',
                 'P1B_10x10x10.h5',
                 'P2A_10x10x10.h5',
                 'P2B_10x10x10.h5']


for i in range(len(folder_paths)):
    print(h5_file_names[i])
    print("")
    # load data
    data = isa.load_tracks(folder_paths[i])

    # cut data
    cut_data = apply_cuts_raw(data)

    # save data
    cut_data.to_hdf(h5_file_names[i], key = 'cut', mode = 'w')

    # cleanup
    del data
    del cut_data
# Out:
# P1A_10x10x10.h5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/collect_cut_data.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/collect_cut_data.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> print("")
#      <a href='vscode-notebook-cell:/home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/collect_cut_data.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> # load data
# ---> <a href='vscode-notebook-cell:/home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/collect_cut_data.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> data = isa.load_tracks(folder_paths[i])
#      <a href='vscode-notebook-cell:/home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/collect_cut_data.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> # cut data
#      <a href='vscode-notebook-cell:/home/e78368jw/Documents/NEXT_CODE/Th_studies/quick_notebooks/collect_cut_data.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a> cut_data = apply_cuts_raw(data)
#
# NameError: name 'isa' is not defined

# %%
# proof of concept
proof = pd.read_hdf('../analysis_data/10x10x10_cut_data/P1A_10x10x10.h5')
display(proof.head(20))
# Out:
#         event  trackID    energy      length  numb_of_voxels  numb_of_hits  \
# 85    5080072        0  1.446411  269.412086             160         11861
# 184   5080188        0  1.596243  137.456298             113         11993
# 393   5080380        0  1.524555  192.344174             105         10753
# 518   5080496        0  1.594183  154.743531             127         12870
# 606   5080582        0  1.595847  134.427703             165         12424
# 660   5080650        0  1.748762  162.472990             103         11927
# 674   5080676        0  1.594673  123.527479             117         12643
# 682   5080682        0  1.377104  238.782842             173         10535
# 714   5080732        0  1.478560   89.722345              98         12815
# 741   1740022        0  1.595029  246.160982             147         12240
# 803   1740082        0  1.621295  232.570108             143         11521
# 954   1740232        0  1.736286  229.538524             155         13704
# 988   1740276        0  1.848341  140.377675             140         11971
# 1103  1740398        0  1.389969  120.811009             123         10548
# 1221  1740502        0  1.818189  135.023713             122         12970
# 1269  1740572        0  1.610053  145.416054             150         12892
# 1346  3580002        0  1.374864  219.301971             133         11576
# 1381  3580030        0  1.683973  309.345456             184         11844
# 1512  3580184        0  1.596952  210.176919             136         12720
# 1642  3580356        0  1.418325  178.340175             124         10812
#
#       numb_of_tracks    x_min    y_min        z_min  ...      blob1_z  \
# 85                 1  239.675  -28.325   122.387062  ...   138.525487
# 184                1  156.675  107.675   734.490601  ...   789.447427
# 393                1    8.675 -246.325    88.786362  ...    95.391985
# 518                1  147.675 -166.325   322.920868  ...   348.181738
# 606                1  293.675  -43.325   683.036133  ...   726.958593
# 660                1  119.675  163.675  1055.785767  ...  1121.741700
# 674                1  185.675  150.675   453.089264  ...   466.743201
# 682                1 -209.325  135.675   465.691925  ...   469.571998
# 714                1 -306.325  -87.325   208.472778  ...   215.848058
# 741                1  186.675  -40.325   405.846893  ...   498.364705
# 803                1   -9.325 -335.325   191.680923  ...   255.239925
# 954                1  331.675   90.675   426.811279  ...   575.001246
# 988                1  202.675  105.675   700.895691  ...   703.332493
# 1103               1  203.675  302.675   267.254059  ...   271.220201
# 1221               1 -316.325  254.675    35.256062  ...    43.260370
# 1269               1 -101.325 -456.325   436.304749  ...   522.938656
# 1346               1  223.675  169.675   344.952728  ...   370.786007
# 1381               1   67.675  -40.325   140.271973  ...   144.278574
# 1512               1   87.675  286.675   153.902756  ...   214.041428
# 1642               1 -335.325   67.675   295.627869  ...   300.653597
#
#          blob2_x     blob2_y      blob2_z    eblob1    eblob2  \
# 85    275.569139   50.293813   288.435271  0.262021  0.093567
# 184   249.494267  184.766019   738.319437  0.511776  0.245868
# 393    90.288190 -141.125375   211.595246  0.350357  0.040686
# 518   150.682122 -134.107884   329.234220  0.444847  0.443488
# 606   344.200068   58.357780   714.376938  0.327431  0.169420
# 660   124.306671  169.886005  1067.395276  0.421753  0.119933
# 674   273.441110  157.500124   496.954274  0.612307  0.345949
# 682   -54.536134  167.500030   588.524921  0.291483  0.022169
# 714  -240.026783  -43.028553   239.957890  0.375855  0.187197
# 741   201.867704   58.954131   414.055713  0.492123  0.414989
# 803    67.675000 -163.325000   249.403687  0.457842  0.014532
# 954   336.150417  174.316065   429.383343  0.053243  0.043193
# 988   289.753594  159.656178   811.989394  0.119445  0.019763
# 1103  216.987334  353.317597   371.012104  0.106461  0.050102
# 1221 -226.737270  263.745573   115.931329  0.536075  0.065094
# 1269  -90.355666 -372.274817   527.177016  0.448995  0.172687
# 1346  273.421204  223.449289   398.613367  0.100794  0.027249
# 1381  181.193226   66.589419   266.832110  0.551802  0.051860
# 1512  218.983909  291.827323   188.099396  0.496821  0.448385
# 1642 -283.939514  190.678234   381.636617  0.465326  0.113822
#
#       ovlp_blob_energy  vox_size_x  vox_size_y  vox_size_z
# 85                 0.0    9.538462    9.357143    9.500244
# 184                0.0   10.000000    9.333333    9.592146
# 393                0.0    9.666667    9.666667    9.603581
# 518                0.0    9.533333    9.200000    8.737142
# 606                0.0    9.272727    9.615385    8.566711
# 660                0.0    9.882353    9.500000    9.256758
# 674                0.0    9.416667   10.000000    9.292014
# 682                0.0    9.647059    9.500000    9.836374
# 714                0.0    9.000000    9.875000    9.602687
# 741                0.0   10.000000    9.333333    9.967749
# 803                0.0    9.700000    9.761905    9.968830
# 954                0.0    9.200000   10.000000    9.774855
# 988                0.0   10.000000    9.926829    9.916719
# 1103               0.0    9.166667    9.500000    9.686810
# 1221               0.0    9.250000    9.250000    9.438344
# 1269               0.0    9.000000    9.384615    9.442682
# 1346               0.0    9.608696   10.000000    9.347853
# 1381               0.0    9.916667    9.416667    9.934486
# 1512               0.0    9.857143    9.714286    9.726704
# 1642               0.0    9.625000    9.500000    9.963434
#
# [20 rows x 37 columns]

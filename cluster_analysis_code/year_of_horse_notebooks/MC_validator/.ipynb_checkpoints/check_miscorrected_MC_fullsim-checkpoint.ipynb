# %% [markdown]
# # Check the Ec against Z of the MC - Full Sim

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import tables as tb
from matplotlib import colors

from typing          import Optional
from typing          import Union
from typing          import Callable

from concurrent.futures import ProcessPoolExecutor

import sys,os,os.path
from pathlib import Path
sys.path.append("/gluster/data/next/software/IC_311024/")
sys.path.append(os.path.expanduser('~/code/eol_hsrl_python'))
sys.path.append("/gluster/data/next/notebooks/")
os.environ['ICTDIR']='/gluster/data/next/software/IC_311024/'

from invisible_cities.io.dst_io           import load_dst, load_dsts, df_writer
from invisible_cities.io.hits_io          import hits_writer
from invisible_cities.core                import tbl_functions   as tbl
from invisible_cities.core.core_functions import in_range
#from invisible_cities.cities.beersheba    import hitc_to_df_
from invisible_cities.io.hits_io          import hits_from_df
from invisible_cities.evm.nh5             import HitsTable
from invisible_cities.types.symbols       import NormStrategy
from invisible_cities.types.ic_types      import NoneType
from invisible_cities.reco.corrections    import read_maps, get_df_to_z_converter, apply_all_correction
from invisible_cities.evm.event_model     import HitCollection

from tqdm import tqdm


from john_books.year_of_horse_notebooks.MC_validator import functions_HE as func

# %%
import traceback

def load_single_file(file_path):
    '''
    Load data from a single h5 file and produce dataframes for /Tracking/Tracks

    Args:
        file_path       :       str
                                Path to the h5 file to be loaded.

    Returns:
        tracks_df       :       pandas.DataFrame
                                DataFrame containing the /Tracking/Tracks data.
        failed          :       int
                                1 if the file failed to load, 0 otherwise.
    '''
    try: 
        tracks_df = load_dst(file_path, 'RECO', 'Events')
        # extract the file_path number, set the event number to that
        evt_num   = file_path.split('.')[0].split('_')[-1]
        tracks_df['event'] = evt_num
        return tracks_df, 0
    except Exception as e:
        print(f'File {file_path} broke with error:\n{e}')
        x = pd.DataFrame()
        return x, 1

def load_data_fast(folder_path):
    '''
    Load multiple h5 files and produce concatenated dataframes for /Tracking/Tracks, /MC/Particles, and their corresponding eventmap.

    Args:
        folder_path     :       str
                                Path to the folder containing the h5 files.

    Returns:
        tracks          :       pandas.DataFrame
                                Concatenated DataFrame containing the /Tracking/Tracks data from all h5 files.
        total_failures  :       int
                                Total number of failed file loads.
    '''
    try:
        file_names = [f for f in os.listdir(folder_path) if f.endswith('.h5')]
        file_paths = [os.path.join(folder_path, f) for f in file_names]#[:500]

        with ProcessPoolExecutor() as executor:
            results = list(executor.map(load_single_file, file_paths))

        # Separate the results into respective lists
        tracks_list, failures = zip(*results)

        tracks = pd.concat(tracks_list, axis=0, ignore_index=True)

        # Sum up the failures
        total_failures = sum(failures)

        return tracks, total_failures
    except Exception as e:
        print(f"An error occurred: {e}")
        traceback.print_exc()

# %% [markdown]
# # Load it in

# %%
n100_dir = '/gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/'

holder, err = load_data_fast(n100_dir)
# Out:
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10176.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10278.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_102.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10536.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11159.h5 broke with error:
# HDF5 error back trace
#
#   File "H5F.c", line 836, in H5Fopen
#     unable to synchronously open file
#   File "H5F.c", line 796, in H5F__open_api_common
#     unable to open file
#   File "H5VLcallback.c", line 3863, in H5VL_file_open
#     open failed
#   File "H5VLcallback.c", line 3675, in H5VL__file_open
#     open failed
#   File "H5VLnative_file.c", line 128, in H5VL__native_file_open
#     unable to open file
#   File "H5Fint.c", line 1965, in H5F_open
#     unable to read superblock
#   File "H5Fsuper.c", line 614, in H5F__super_read
#     truncated file: eof = 331776, sblock->base_addr = 0, stored_eof = 377955
#
# End of HDF5 error back trace
#
# Unable to open/create file '/gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11159.h5'
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11236.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11456.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12070.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12737.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13179.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13459.h5 broke with error:
# group ``/`` does not have a child named ``RECO``File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13472.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
#
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13689.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13820.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14224.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14227.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14710.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15156.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15631.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15639.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15684.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_16313.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_1643.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_17177.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_17255.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18028.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18261.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_1863.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18733.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18811.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18823.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18871.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18958.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_19176.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_19367.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_19827.h5 broke with error:
# group ``/`` does not have a child named ``RECO``File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_19829.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
#
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_2247.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_2410.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_2732.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_2853.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3192.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3406.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3452.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3478.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_349.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3636.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4080.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_476.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4792.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4853.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_5576.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_6856.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_7642.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_7906.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8274.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8331.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8342.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8405.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8482.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8807.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8855.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8895.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_9070.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10186.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10399.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10517.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11169.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11181.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11563.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11671.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_11855.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12002.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12028.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12043.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12316.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12440.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_12556.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13011.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13632.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_13792.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14094.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14136.h5 broke with error:
# HDF5 error back trace
#
#   File "H5F.c", line 836, in H5Fopen
#     unable to synchronously open file
#   File "H5F.c", line 796, in H5F__open_api_common
#     unable to open file
#   File "H5VLcallback.c", line 3863, in H5VL_file_open
#     open failed
#   File "H5VLcallback.c", line 3675, in H5VL__file_open
#     open failed
#   File "H5VLnative_file.c", line 128, in H5VL__native_file_open
#     unable to open file
#   File "H5Fint.c", line 1965, in H5F_open
#     unable to read superblock
#   File "H5Fsuper.c", line 614, in H5F__super_read
#     truncated file: eof = 198144, sblock->base_addr = 0, stored_eof = 409261
#
# End of HDF5 error back trace
#
# Unable to open/create file '/gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14136.h5'
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14205.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14403.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_14499.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_1500.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15109.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15916.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15974.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15978.h5 broke with error:
# HDF5 error back trace
#
#   File "H5F.c", line 836, in H5Fopen
#     unable to synchronously open file
#   File "H5F.c", line 796, in H5F__open_api_common
#     unable to open file
#   File "H5VLcallback.c", line 3863, in H5VL_file_open
#     open failed
#   File "H5VLcallback.c", line 3675, in H5VL__file_open
#     open failed
#   File "H5VLnative_file.c", line 128, in H5VL__native_file_open
#     unable to open file
#   File "H5Fint.c", line 1965, in H5F_open
#     unable to read superblock
#   File "H5Fsuper.c", line 614, in H5F__super_read
#     truncated file: eof = 214016, sblock->base_addr = 0, stored_eof = 347029
#
# End of HDF5 error back trace
#
# Unable to open/create file '/gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_15978.h5'
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_16199.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_16963.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_1698.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_17599.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_17729.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18605.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_18738.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_19673.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_1988.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_19915.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_251.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_2863.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3073.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3090.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3167.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_3253.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4015.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4153.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4343.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_4805.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_5082.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_6759.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_7120.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_7351.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_7552.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_8553.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_892.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_9289.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_953.h5 broke with error:
# group ``/`` does not have a child named ``RECO``
# File /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_9645.h5 broke with error:
# group ``/`` does not have a child named ``RECO``

# %%
#file_names = [f for f in os.listdir(n100_dir) if f.endswith('.h5')]
#file_paths = [os.path.join(n100_dir, f) for f in file_names][:500]

#print(file_paths[0])
#print(file_paths[0].split('.')[0].split('_')[-1])
# Out:
# /gluster/data/next/files/TOPOLOGY_John/MC_data/th_port1a_dep_202602_full/sophronia/NEXT100_Tl208_Port1a_DEP_Full_sophronia_10000.h5
# 10000
#         event        time  npeak      Xpeak       Ypeak  nsipm        X  \
# 0           0  108543.776      0  59.470117  328.287557      1   73.675
# 1           0  108543.776      0  59.470117  328.287557      1   73.675
# 2           0  108543.776      0  59.470117  328.287557      1   89.225
# 3           0  108543.776      0  59.470117  328.287557      1   89.225
# 4           0  108543.776      0  59.470117  328.287557      1  104.775
# ...       ...         ...    ...        ...         ...    ...      ...
# 383807      0   84138.538      2 -26.743700  386.000122      1  -35.175
# 383808      0   84138.538      2 -26.743700  386.000122      1   -4.075
# 383809      0   84138.538      2 -26.743700  386.000122      1  -66.275
# 383810      0   84138.538      2 -26.743700  386.000122      1  -35.175
# 383811      0   84138.538      2 -26.743700  386.000122      1  -19.625
#
#               Y  Xrms  Yrms           Z          Q            E   Qc  \
# 0       402.925   0.0   0.0  542.260886   7.942029   596.315707 -1.0
# 1       418.475   0.0   0.0  542.260886  10.840580   813.949245 -1.0
# 2       402.925   0.0   0.0  542.260886  13.971014  1048.993350 -1.0
# 3       418.475   0.0   0.0  542.260886  10.434783   783.480565 -1.0
# 4       402.925   0.0   0.0  542.260886  11.304348   848.770594 -1.0
# ...         ...   ...   ...         ...        ...          ...  ...
# 383807  480.675   0.0   0.0  769.128611   6.260870   721.578320 -1.0
# 383808  480.675   0.0   0.0  769.128611   5.391304   621.359076 -1.0
# 383809  480.675   0.0   0.0  772.426618   6.260870   643.995230 -1.0
# 383810  496.225   0.0   0.0  772.426618   5.101449   524.736832 -1.0
# 383811  480.675   0.0   0.0  775.909554   6.492754  1315.057628 -1.0
#
#               Ec  track_id   Ep
# 0       0.002648        -1 -1.0
# 1       0.003673        -1 -1.0
# 2       0.004672        -1 -1.0
# 3       0.003552        -1 -1.0
# 4       0.003813        -1 -1.0
# ...          ...       ...  ...
# 383807  0.004627        -1 -1.0
# 383808  0.003951        -1 -1.0
# 383809  0.004263        -1 -1.0
# 383810  0.002417        -1 -1.0
# 383811  0.008393        -1 -1.0
#
# [383812 rows x 17 columns]

# %%
display(holder)
# Out:
#           event        time  npeak       Xpeak       Ypeak  nsipm        X  \
# 0         10000  108543.776      0   59.470117  328.287557      1   73.675
# 1         10000  108543.776      0   59.470117  328.287557      1   73.675
# 2         10000  108543.776      0   59.470117  328.287557      1   89.225
# 3         10000  108543.776      0   59.470117  328.287557      1   89.225
# 4         10000  108543.776      0   59.470117  328.287557      1  104.775
# ...         ...         ...    ...         ...         ...    ...      ...
# 14111957     99   67927.272      0  151.263700  122.821113      1  244.725
# 14111958     99   67927.272      0  151.263700  122.821113      1  244.725
# 14111959     99   67927.272      0  151.263700  122.821113      1  244.725
# 14111960     99   67927.272      0  151.263700  122.821113      1  260.275
# 14111961     99   67927.272      0  151.263700  122.821113      1  275.825
#
#                 Y  Xrms  Yrms            Z          Q            E   Qc  \
# 0         402.925   0.0   0.0   542.260886   7.942029   596.315707 -1.0
# 1         418.475   0.0   0.0   542.260886  10.840580   813.949245 -1.0
# 2         402.925   0.0   0.0   542.260886  13.971014  1048.993350 -1.0
# 3         418.475   0.0   0.0   542.260886  10.434783   783.480565 -1.0
# 4         402.925   0.0   0.0   542.260886  11.304348   848.770594 -1.0
# ...           ...   ...   ...          ...        ...          ...  ...
# 14111957  154.125   0.0   0.0  1032.484027   6.840580   805.345259 -1.0
# 14111958  169.675   0.0   0.0  1032.484027  10.144928  1194.367972 -1.0
# 14111959  185.225   0.0   0.0  1032.484027   6.028986   709.795792 -1.0
# 14111960  185.225   0.0   0.0  1032.484027   6.840580   805.345202 -1.0
# 14111961  154.125   0.0   0.0  1032.484027   5.217391   614.246325 -1.0
#
#                 Ec  track_id   Ep
# 0         0.002648        -1 -1.0
# 1         0.003673        -1 -1.0
# 2         0.004672        -1 -1.0
# 3         0.003552        -1 -1.0
# 4         0.003813        -1 -1.0
# ...            ...       ...  ...
# 14111957  0.003348        -1 -1.0
# 14111958  0.005000        -1 -1.0
# 14111959  0.002992        -1 -1.0
# 14111960  0.003444        -1 -1.0
# 14111961  0.002612        -1 -1.0
#
# [14111962 rows x 17 columns]

# %%
print(holder.columns.values)
# Out:
# ['event' 'time' 'npeak' 'Xpeak' 'Ypeak' 'nsipm' 'X' 'Y' 'Xrms' 'Yrms' 'Z'
#  'Q' 'E' 'Qc' 'Ec' 'track_id' 'Ep']

# %%
from matplotlib.colors import LogNorm

plt.hist2d(holder.groupby('event').Z.mean(), holder.groupby('event').Ec.sum(), 
           range=[[0, 1200], [1.3, 1.8]], bins=70)#, norm=LogNorm())

plt.xlabel('Z (mm)')
plt.ylabel('Ec (MeV)')
plt.colorbar(label='Counts') #(log scale)')
plt.show()

# %%
from matplotlib.colors import LogNorm

plt.hist2d(holder.groupby('event').Z.mean(), holder.groupby('event').E.sum(), 
           bins=70, norm=LogNorm())

plt.xlabel('Z (mm)')
plt.ylabel('E (MeV)')
plt.colorbar(label='Counts (log scale)')
plt.show()

# %%
from matplotlib.colors import LogNorm

plt.hist2d(holder.groupby('event').Z.mean(), holder.groupby('event').Ec.sum(), 
           range=[[0, 1200], [1.5, 1.7]], bins=70, norm=LogNorm())

plt.xlabel('Z (mm)')
plt.ylabel('Ec (MeV)')
plt.colorbar(label='Counts (log scale)')
plt.show()

# %%
from matplotlib.colors import LogNorm

holder['radius'] = (holder['X']**2 + holder['Y']**2)**0.5

# %%
plt.hist2d(holder.groupby('event').radius.mean(), holder.groupby('event').Ec.sum(), 
            range=[[0, 500], [1.5, 1.7]], bins=70)
plt.xlabel('R (mm)')
plt.ylabel('Ec (MeV)')
plt.title('NEXT100_Tl208_Port1a_DEP_Full')
plt.colorbar(label='Counts')# (log scale)')
plt.show()

# %%
plt.hist2d(holder.groupby('event').radius.mean(), holder.groupby('event').E.sum(), 
            bins=70)
plt.xlabel('R (mm)')
plt.ylabel('Ec (MeV)')
plt.colorbar(label='Counts')# (log scale)')
plt.show()

# %%
plt.hist(holder.groupby('event').Ec.sum(), bins = 50, range = (1.5, 1.7))
plt.title('MC')
plt.xlabel('Energy (Ec)')
plt.show()

range = 450
plt.hist(holder[holder['radius'] < range].groupby('event').Ec.sum(), bins=50, range=(1.5, 1.7))
plt.title(f'MC R < {range} mm')
plt.xlabel('Energy (Ec)')
plt.show()

range = 300
plt.hist(holder[holder['radius'] < range].groupby('event').Ec.sum(), bins=50, range=(1.5, 1.7))
plt.title(f'MC R < {range} mm')
plt.xlabel('Energy (Ec)')
plt.show()

range = 200
plt.hist(holder[holder['radius'] < range].groupby('event').Ec.sum(), bins=50, range=(1.5, 1.7))
plt.title(f'MC R < {range} mm')
plt.xlabel('Energy (Ec)')
plt.show()

# %% [markdown]
# # r dependence wrt z position

# %%
from matplotlib.colors import LogNorm
z_range = 800

plt.hist2d(holder[holder.Z > z_range].groupby('event').radius.mean(), holder[holder.Z > z_range].groupby('event').Ec.sum(), 
           range=[[0, 500], [1.5, 1.7]], bins=70, norm=LogNorm())

plt.xlabel('R (mm)')
plt.ylabel('Ec (MeV)')
plt.title(f'z cut at {z_range} mm')
plt.colorbar(label='Counts (log scale)')
plt.show()

# %% [markdown]
# # Read in new data files

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import tables as tb
from matplotlib import colors 

from typing          import Optional
from typing          import Union
from typing          import Callable

import sys,os,os.path
sys.path.append("/gluster/data/next/software/IC_311024/")
sys.path.append(os.path.expanduser('~/code/eol_hsrl_python'))
#sys.path.append("/home/e78368jw/Documents/NEXT_CODE/next_misc/")
os.environ['ICTDIR']='/gluster/data/next/software/IC_311024/'

from invisible_cities.io.dst_io           import load_dst, load_dsts, df_writer
from invisible_cities.io.hits_io          import hits_writer
from invisible_cities.reco                import tbl_functions   as tbl
from invisible_cities.core.core_functions import in_range
from invisible_cities.cities.beersheba    import hitc_to_df_
from invisible_cities.io.hits_io          import hits_from_df
from invisible_cities.evm.nh5             import HitsTable
from invisible_cities.types.symbols       import NormStrategy
from invisible_cities.types.ic_types      import NoneType
from invisible_cities.reco.corrections    import read_maps, get_df_to_z_converter, apply_all_correction
from invisible_cities.evm.event_model     import HitCollection

from tqdm import tqdm

# %% [markdown]
# # Read in data to collect the events that are normal

# %%
n100_dir = '/gluster/data/next/files/TOPOLOGY_John/N100_data/15107/sophronia/trigger2/'

full_dst = []

for i in tqdm(range(1, 8)):

    print(f"LDC {i}")
    folder_path = n100_dir + 'ldc' + str(i) + '/'
    file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]
    
    full_dst.append(load_dsts([folder_path + x for x in file_names], 'DST', 'Events'))

full_dst = pd.concat(full_dst)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# LDC 1
#  14%|█▍        | 1/7 [01:03<06:23, 63.89s/it]
# LDC 2
#  29%|██▊       | 2/7 [02:27<06:16, 75.36s/it]
# LDC 3
#  43%|████▎     | 3/7 [03:38<04:53, 73.27s/it]
# LDC 4
#  57%|█████▋    | 4/7 [04:54<03:43, 74.58s/it]
# LDC 5
#  71%|███████▏  | 5/7 [06:19<02:36, 78.16s/it]
# LDC 6
#  86%|████████▌ | 6/7 [07:45<01:20, 80.97s/it]
# LDC 7
# 100%|██████████| 7/7 [09:09<00:00, 78.45s/it]

# %%
display(full_dst)
# Out:
#         event          time  s1_peak  s2_peak  nS1  nS2    S1w        S1h  \
# 0         156  1.742935e+09        0        0    1    2  600.0  24.381660
# 1         156  1.742935e+09        0        1    1    2  600.0  24.381660
# 2         275  1.742935e+09        0        0    1    1  375.0  20.105528
# 3         317  1.742935e+09        0        0    3    3  225.0  19.746523
# 4         317  1.742935e+09        0        1    3    3  225.0  19.746523
# ...       ...           ...      ...      ...  ...  ...    ...        ...
# 25176  391495  1.742940e+09    65535        5    0    6    NaN        NaN
# 25177  391810  1.742940e+09        0        0    1    4  725.0  35.936073
# 25178  391810  1.742940e+09        0        1    1    4  725.0  35.936073
# 25179  391810  1.742940e+09        0        2    1    4  725.0  35.936073
# 25180  391810  1.742940e+09        0        3    1    4  725.0  35.936073
#
#               S1e        S1t  ...  Nsipm           DT            Z       Zrms  \
# 0      136.866943   619825.0  ...   2111  -218.339066  -218.339066  19.622758
# 1      136.866943   619825.0  ...   2152   787.668030   787.668030  18.626027
# 2      130.680893  1217525.0  ...   2539   185.960632   185.960632  18.371055
# 3      148.996826   562650.0  ...    776    -3.149063    -3.149063   3.503168
# 4      148.996826   562650.0  ...    724   452.851776   452.851776   6.683204
# ...           ...        ...  ...    ...          ...          ...        ...
# 25176         NaN        NaN  ...    856          NaN          NaN   3.964980
# 25177  198.177307   754925.0  ...    381   569.543152   569.543152   4.456573
# 25178  198.177307   754925.0  ...   2237   647.567139   647.567139   8.598272
# 25179  198.177307   754925.0  ...   1914   865.564148   865.564148   8.254498
# 25180  198.177307   754925.0  ...    351  1058.562500  1058.562500   6.228166
#
#                 X           Y           R       Phi        Xrms        Yrms
# 0      137.029985   27.834735  139.828428  0.200402  240.724924  195.344402
# 1      116.011572  -55.936634  128.792826 -0.449277  221.975949  200.956738
# 2       15.761644  -65.178615   67.057299 -1.333529  190.955556  208.454665
# 3       66.337331    2.219122   66.374438  0.033440  211.118392  194.975194
# 4       17.697822   39.607853   43.381966  1.150585  253.569501  263.959456
# ...           ...         ...         ...       ...         ...         ...
# 25176  -80.113536  134.404147  156.469337  2.108317  242.908390  271.176978
# 25177  -47.094804   33.190097   57.615129  2.527685  233.144656  219.503977
# 25178   16.955107   33.760311   37.778754  1.105374  243.084097  206.085915
# 25179 -112.437175   60.467513  127.665338  2.648173  249.455369  211.893678
# 25180   63.353932    0.765341   63.358555  0.012080  266.173222  233.200932
#
# [174567 rows x 26 columns]

# %%
#remove all events between range X < DT < y
upper_lim = 1500
lower_lim = 0
relevant_dst = full_dst[full_dst.DT > lower_lim]
relevant_dst = relevant_dst[relevant_dst.DT < upper_lim]

print(f'DT cut applied\nEfficiency: {relevant_dst.event.nunique()/full_dst.event.nunique()*100:.2f}%')
# Out:
# DT cut applied
# Efficiency: 90.79%

# %%
# 1 S1, 1 S2
one_s1s2 = relevant_dst[relevant_dst.nS1 == 1]
one_s1s2 = one_s1s2[one_s1s2.nS2 == 1]

print(f'S1S2 cut applied\nRelative Efficiency: {one_s1s2.event.nunique()/relevant_dst.event.nunique()*100:.2f}%\nAbsolute Efficiency: {one_s1s2.event.nunique()/full_dst.event.nunique()*100:.2f}%')
# Out:
# S1S2 cut applied
# Relative Efficiency: 40.23%
# Absolute Efficiency: 36.53%

# %%
plt.hist(one_s1s2.S2e.values, bins = 50)
plt.title('Uncorrected S2 energy')
plt.yscale('log')
plt.xlabel('S2 energy (PES?)')
plt.show()

# %%
plt.hist(one_s1s2.S2e.values, bins = 50, range = [0, 5e5])
plt.title('Uncorrected S2 energy')
#plt.yscale('log')
plt.xlabel('S2 energy (PES?)')
plt.show()

# %%
display(one_s1s2)
# Out:
#          event          time  s1_peak  s2_peak  nS1  nS2    S1w        S1h  \
# 2          275  1.742935e+09        0        0    1    1  375.0  20.105528
# 14         590  1.742935e+09        0        0    1    1  400.0  41.841473
# 15         597  1.742935e+09        0        0    1    1  650.0  16.592751
# 20        1556  1.742935e+09        0        0    1    1  350.0  17.792589
# 25        1794  1.742935e+09        0        0    1    1  275.0  21.349106
# ...        ...           ...      ...      ...  ...  ...    ...        ...
# 25147   658454  1.742944e+09        0        0    1    1  375.0  10.825253
# 25152   658699  1.742944e+09        0        0    1    1  575.0  16.538542
# 25153   658923  1.742944e+09        0        0    1    1  625.0  15.709264
# 25160  1074513  1.742949e+09        0        0    1    1  350.0  19.289764
# 25164  1074912  1.742949e+09        0        0    1    1  325.0  57.295929
#
#               S1e        S1t  ...  Nsipm           DT            Z       Zrms  \
# 2      130.680893  1217525.0  ...   2539   185.960632   185.960632  18.371055
# 14     240.074432  1139325.0  ...   2969   266.157379   266.157379  29.010471
# 15      97.683167   493475.0  ...   2261   919.024780   919.024780   9.251109
# 20     102.266724   530275.0  ...   2102   877.213196   877.213196   8.832326
# 25     106.103920   877900.0  ...   2550   531.588501   531.588501   8.046095
# ...           ...        ...  ...    ...          ...          ...        ...
# 25147   69.822937  1202675.0  ...   2851   205.808258   205.808258   9.201199
# 25152   87.122505   839450.0  ...   2870   567.041748   567.041748  12.670540
# 25153   91.425804  1274300.0  ...   2163   129.195633   129.195633  18.046918
# 25160  105.112312   792425.0  ...   2470   616.065002   616.065002  13.975123
# 25164  309.272644   371725.0  ...   3005  1040.768677  1040.768677  33.414348
#
#                 X          Y           R       Phi        Xrms        Yrms
# 2       15.761644 -65.178615   67.057299 -1.333529  190.955556  208.454665
# 14     170.053074  19.509000  171.168482  0.114224  217.766683  168.386432
# 15      75.948209  52.021293   92.056208  0.600559  214.760246  197.605371
# 20     110.182593   3.345906  110.233384  0.030358  237.921637  199.830332
# 25     108.494903  87.064883  139.109446  0.676251  240.576917  220.669800
# ...           ...        ...         ...       ...         ...         ...
# 25147   15.608674  98.721551   99.947863  1.413986  224.630671  251.603989
# 25152   40.841408  -8.578211   41.732557 -0.207028  226.215802  217.065314
# 25153   86.402601 -24.296199   89.753634 -0.274119  203.298461  188.980867
# 25160   -3.418172  -1.705237    3.819913 -2.678846  203.424014  201.055704
# 25164 -107.260682 -11.486681  107.873990 -3.034908  203.519569  173.929109
#
# [24826 rows x 26 columns]

# %%
one_s1s2.to_hdf('files/DST_15107_passing.h5', key = 'DST/Events')

# %%
check = pd.read_hdf('files/DST_15107_passing.h5')
display(check)
events_of_interest = check.event.unique()
# Out:
#          event          time  s1_peak  s2_peak  nS1  nS2    S1w        S1h  \
# 2          275  1.742935e+09        0        0    1    1  375.0  20.105528
# 14         590  1.742935e+09        0        0    1    1  400.0  41.841473
# 15         597  1.742935e+09        0        0    1    1  650.0  16.592751
# 20        1556  1.742935e+09        0        0    1    1  350.0  17.792589
# 25        1794  1.742935e+09        0        0    1    1  275.0  21.349106
# ...        ...           ...      ...      ...  ...  ...    ...        ...
# 25147   658454  1.742944e+09        0        0    1    1  375.0  10.825253
# 25152   658699  1.742944e+09        0        0    1    1  575.0  16.538542
# 25153   658923  1.742944e+09        0        0    1    1  625.0  15.709264
# 25160  1074513  1.742949e+09        0        0    1    1  350.0  19.289764
# 25164  1074912  1.742949e+09        0        0    1    1  325.0  57.295929
#
#               S1e        S1t  ...  Nsipm           DT            Z       Zrms  \
# 2      130.680893  1217525.0  ...   2539   185.960632   185.960632  18.371055
# 14     240.074432  1139325.0  ...   2969   266.157379   266.157379  29.010471
# 15      97.683167   493475.0  ...   2261   919.024780   919.024780   9.251109
# 20     102.266724   530275.0  ...   2102   877.213196   877.213196   8.832326
# 25     106.103920   877900.0  ...   2550   531.588501   531.588501   8.046095
# ...           ...        ...  ...    ...          ...          ...        ...
# 25147   69.822937  1202675.0  ...   2851   205.808258   205.808258   9.201199
# 25152   87.122505   839450.0  ...   2870   567.041748   567.041748  12.670540
# 25153   91.425804  1274300.0  ...   2163   129.195633   129.195633  18.046918
# 25160  105.112312   792425.0  ...   2470   616.065002   616.065002  13.975123
# 25164  309.272644   371725.0  ...   3005  1040.768677  1040.768677  33.414348
#
#                 X          Y           R       Phi        Xrms        Yrms
# 2       15.761644 -65.178615   67.057299 -1.333529  190.955556  208.454665
# 14     170.053074  19.509000  171.168482  0.114224  217.766683  168.386432
# 15      75.948209  52.021293   92.056208  0.600559  214.760246  197.605371
# 20     110.182593   3.345906  110.233384  0.030358  237.921637  199.830332
# 25     108.494903  87.064883  139.109446  0.676251  240.576917  220.669800
# ...           ...        ...         ...       ...         ...         ...
# 25147   15.608674  98.721551   99.947863  1.413986  224.630671  251.603989
# 25152   40.841408  -8.578211   41.732557 -0.207028  226.215802  217.065314
# 25153   86.402601 -24.296199   89.753634 -0.274119  203.298461  188.980867
# 25160   -3.418172  -1.705237    3.819913 -2.678846  203.424014  201.055704
# 25164 -107.260682 -11.486681  107.873990 -3.034908  203.519569  173.929109
#
# [24826 rows x 26 columns]

# %% [markdown]
# # Correct the sophronia hits of interest based on selection
# selection found from DSTs in `files/DST_15107_passing.h5`

# %%
n100_dir = '/gluster/data/next/files/TOPOLOGY_John/N100_data/15107/sophronia/trigger2/'

full_dst = []

for i in tqdm(range(1, 8)):

    print(f"LDC {i}")
    folder_path = n100_dir + 'ldc' + str(i) + '/'
    file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]
    
    dst = load_dsts([folder_path + x for x in file_names], 'RECO', 'Events')
    dst = dst[dst.event.isin(events_of_interest)]
    full_dst.append(dst)

full_dst = pd.concat(full_dst)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# LDC 1
#   0%|          | 0/7 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 11
#       8 folder_path = n100_dir + 'ldc' + str(i) + '/'
#       9 file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]
# ---> 11 dst = load_dsts([folder_path + x for x in file_names], 'RECO', 'Events')
#      12 dst = dst[dst.event.isin(events_of_interest)]
#      13 full_dst.append(dst)
#
# File /gluster/data/next/software/IC_satkill/IC/invisible_cities/io/dst_io.py:50, in load_dsts(dst_list, group, node, evt_list, ignore_errors)
#      49 def load_dsts(dst_list, group, node, evt_list=None, ignore_errors=False):
# ---> 50     dsts = [load_dst(filename, group, node, evt_list, ignore_errors) for filename in dst_list]
#      51     return pd.concat(dsts, ignore_index=True)
#
# File /gluster/data/next/software/IC_satkill/IC/invisible_cities/io/dst_io.py:50, in <listcomp>(.0)
#      49 def load_dsts(dst_list, group, node, evt_list=None, ignore_errors=False):
# ---> 50     dsts = [load_dst(filename, group, node, evt_list, ignore_errors) for filename in dst_list]
#      51     return pd.concat(dsts, ignore_index=True)
#
# File /gluster/data/next/software/IC_satkill/IC/invisible_cities/io/dst_io.py:46, in load_dst(filename, group, node, evt_list, ignore_errors)
#      44         warnings.warn(f' does not exist: file = {filename} ', UserWarning)
#      45 else:
# ---> 46     return read_dst_(filename, group, node, evt_list)
#
# File /gluster/data/next/software/IC_satkill/IC/invisible_cities/io/dst_io.py:30, in load_dst.<locals>.read_dst_(filename, group, node, evt_list)
#      28 table  = getattr(getattr(h5in.root, group), node)
#      29 if evt_list is None:
# ---> 30     values = table.read()
#      31 else:
#      32     events = table.read(field='event')
#
# File /gluster/data/next/software/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/tables/table.py:1900, in Table.read(self, start, stop, step, field, out)
#    1895     raise TypeError(msg)
#    1897 start, stop, step = self._process_range(start, stop, step,
#    1898                                         warn_negstep=False)
# -> 1900 arr = self._read(start, stop, step, field, out)
#    1901 return internal_to_flavor(arr, self.flavor)
#
# File /gluster/data/next/software/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/tables/table.py:1814, in Table._read(self, start, stop, step, field, out)
#    1810 # Call the routine to fill-up the resulting array
#    1811 if step == 1 and not field:
#    1812     # This optimization works three times faster than
#    1813     # the row._fill_col method (up to 170 MB/s on a pentium IV @ 2GHz)
# -> 1814     self._read_records(start, stop - start, result)
#    1815 # Warning!: _read_field_name should not be used until
#    1816 # H5TBread_fields_name in tableextension will be finished
#    1817 # F. Alted 2005/05/26
#    1818 # XYX Ho implementem per a PyTables 2.0??
#    1819 elif field and step > 15 and 0:
#    1820     # For step>15, this seems to work always faster than row._fill_col.
#
# KeyboardInterrupt:

# %%
#display(full_dst)
#full_dst.to_hdf('files/RECO_15107_passing.h5', key = 'RECO/Events')
#full_dst.to_hdf('files/15107_passing.h5', key = 'RECO/Events')
one_s1s2.to_hdf('files/15107_passing.h5', key = 'DST/Events')

# %%
display(pd.read_hdf('files/15107_passing.h5', key = 'DST/Events'))
r = pd.read_hdf('files/15107_passing.h5', key = 'RECO/Events')
display(r)
# Out:
#          event          time  s1_peak  s2_peak  nS1  nS2    S1w        S1h  \
# 2          275  1.742935e+09        0        0    1    1  375.0  20.105528
# 14         590  1.742935e+09        0        0    1    1  400.0  41.841473
# 15         597  1.742935e+09        0        0    1    1  650.0  16.592751
# 20        1556  1.742935e+09        0        0    1    1  350.0  17.792589
# 25        1794  1.742935e+09        0        0    1    1  275.0  21.349106
# ...        ...           ...      ...      ...  ...  ...    ...        ...
# 25147   658454  1.742944e+09        0        0    1    1  375.0  10.825253
# 25152   658699  1.742944e+09        0        0    1    1  575.0  16.538542
# 25153   658923  1.742944e+09        0        0    1    1  625.0  15.709264
# 25160  1074513  1.742949e+09        0        0    1    1  350.0  19.289764
# 25164  1074912  1.742949e+09        0        0    1    1  325.0  57.295929
#
#               S1e        S1t  ...  Nsipm           DT            Z       Zrms  \
# 2      130.680893  1217525.0  ...   2539   185.960632   185.960632  18.371055
# 14     240.074432  1139325.0  ...   2969   266.157379   266.157379  29.010471
# 15      97.683167   493475.0  ...   2261   919.024780   919.024780   9.251109
# 20     102.266724   530275.0  ...   2102   877.213196   877.213196   8.832326
# 25     106.103920   877900.0  ...   2550   531.588501   531.588501   8.046095
# ...           ...        ...  ...    ...          ...          ...        ...
# 25147   69.822937  1202675.0  ...   2851   205.808258   205.808258   9.201199
# 25152   87.122505   839450.0  ...   2870   567.041748   567.041748  12.670540
# 25153   91.425804  1274300.0  ...   2163   129.195633   129.195633  18.046918
# 25160  105.112312   792425.0  ...   2470   616.065002   616.065002  13.975123
# 25164  309.272644   371725.0  ...   3005  1040.768677  1040.768677  33.414348
#
#                 X          Y           R       Phi        Xrms        Yrms
# 2       15.761644 -65.178615   67.057299 -1.333529  190.955556  208.454665
# 14     170.053074  19.509000  171.168482  0.114224  217.766683  168.386432
# 15      75.948209  52.021293   92.056208  0.600559  214.760246  197.605371
# 20     110.182593   3.345906  110.233384  0.030358  237.921637  199.830332
# 25     108.494903  87.064883  139.109446  0.676251  240.576917  220.669800
# ...           ...        ...         ...       ...         ...         ...
# 25147   15.608674  98.721551   99.947863  1.413986  224.630671  251.603989
# 25152   40.841408  -8.578211   41.732557 -0.207028  226.215802  217.065314
# 25153   86.402601 -24.296199   89.753634 -0.274119  203.298461  188.980867
# 25160   -3.418172  -1.705237    3.819913 -2.678846  203.424014  201.055704
# 25164 -107.260682 -11.486681  107.873990 -3.034908  203.519569  173.929109
#
# [24826 rows x 26 columns]
#             event          time  npeak       Xpeak      Ypeak  nsipm        X  \
# 1483          275  1.742935e+09      3   15.761644 -65.178616      1  474.475
# 1484          275  1.742935e+09      3   15.761644 -65.178616      1 -265.925
# 1485          275  1.742935e+09      3   15.761644 -65.178616      1  181.025
# 1486          275  1.742935e+09      3   15.761644 -65.178616      1 -281.475
# 1487          275  1.742935e+09      3   15.761644 -65.178616      1  212.125
# ...           ...           ...    ...         ...        ...    ...      ...
# 14175231  1074912  1.742949e+09      0 -107.260682 -11.486680      1  196.575
# 14175232  1074912  1.742949e+09      0 -107.260682 -11.486680      1 -389.325
# 14175233  1074912  1.742949e+09      0 -107.260682 -11.486680      1  -65.775
# 14175234  1074912  1.742949e+09      0 -107.260682 -11.486680      1   88.725
# 14175235  1074912  1.742949e+09      0 -107.260682 -11.486680      1  243.225
#
#                 Y  Xrms  Yrms            Z         Q           E   Qc  \
# 1483      -32.475   0.0   0.0   159.434125  5.256973   -2.562765 -1.0
# 1484      399.925   0.0   0.0   161.691000  7.539444   -3.154945 -1.0
# 1485      414.975   0.0   0.0   161.691000  6.790727   -2.841638 -1.0
# 1486     -279.275   0.0   0.0   165.937000  5.034613   17.929243 -1.0
# 1487     -325.425   0.0   0.0   167.834250  5.043945  159.742005 -1.0
# ...           ...   ...   ...          ...       ...         ...  ...
# 14175231  214.825   0.0   0.0  1144.738500  5.329231    5.760224 -1.0
# 14175232  214.325   0.0   0.0  1147.229500  8.552230   -6.227441 -1.0
# 14175233 -356.525   0.0   0.0  1147.229500  6.788672   -4.943279 -1.0
# 14175234  492.725   0.0   0.0  1147.229500  6.301342   -4.588421 -1.0
# 14175235 -309.875   0.0   0.0  1147.229500  5.044473   -3.673212 -1.0
#
#                 Ec  track_id   Ep
# 1483           NaN        -1 -1.0
# 1484           NaN        -1 -1.0
# 1485     -0.000009        -1 -1.0
# 1486      0.000050        -1 -1.0
# 1487      0.000450        -1 -1.0
# ...            ...       ...  ...
# 14175231  0.000017        -1 -1.0
# 14175232 -0.000021        -1 -1.0
# 14175233 -0.000015        -1 -1.0
# 14175234       NaN        -1 -1.0
# 14175235 -0.000012        -1 -1.0
#
# [28931638 rows x 17 columns]

# %% [markdown]
# # Correct energy
# Taking the hits corrector explicitly from IC

# %%
def hits_corrector( filename   : str
                  , apply_temp : bool
                  , norm_strat : NormStrategy
                  , norm_value : Optional[Union[float, NoneType]] = None
                  ) -> Callable:
    """
    Applies energy correction map and converts drift time to z.

    Parameters
    ----------
    map_fname  : string (filepath)
        filename of the map
    apply_temp : bool
        whether to apply temporal corrections
        must be set to False if no temporal correction dataframe exists in map file

    Returns
    ----------
    A function that takes a HitCollection as input and returns
    the same object with modified Ec and Z fields.
    """

    if ( ((norm_strat is not NormStrategy.custom)  ^  (norm_value is None)) or
          (norm_strat is     NormStrategy.custom) and (norm_value<= 0)):
        raise ValueError(
            "`NormStrategy.custom` requires `norm_value` to be greater than 0. "
            "For all other `NormStrategy` options, `norm_value` must not be provided."
        )

    maps      = read_maps(os.path.expandvars(filename))
    get_coef  = apply_all_correction( maps
                                    , apply_temp = apply_temp
                                    , norm_strat = norm_strat
                                    , norm_value = norm_value)
    time_to_Z = get_df_to_z_converter(maps) if maps.t_evol is not None else identity

    def correct(hitc : HitCollection) -> HitCollection:
        for hit in hitc.hits:
            corr    = get_coef([hit.X], [hit.Y], [hit.Z], hitc.time)[0]
            hit.Ec  = hit.E * corr
            hit.xyz = (hit.X, hit.Y, time_to_Z(hit.Z)) # ugly, but temporary
        return hitc

    return correct

# %%
corrector = hits_corrector('/gluster/data/next/files/TOPOLOGY_John/LPR/LightTables/map_4bar_15063.h5',
                           True,
                           NormStrategy.kr)

corrected_RECO = []

for i, df in tqdm(r.groupby('event')):
    #print(i)
    #display(df)
    hitc = hits_from_df(df)
    key = list(hitc.keys())[0]
    correct_hitc = corrector(hitc[key])
    corrected_RECO.append(hitc_to_df_(correct_hitc))
    
corrected_RECO = pd.concat(corrected_RECO)
'''
maps      = read_maps(os.path.expandvars('/gluster/data/next/files/TOPOLOGY_John/LPR/LightTables/map_4bar_15063.h5'))
get_coef  = apply_all_correction( maps
                                , apply_temp = True
                                , norm_strat = NormStrategy.kr)



# ^^^ This shit was too slow, so have to rewrite the logic to apply to a full df
#coefs = get_coef(r.)
'''

# %%
for hit in hitc[list(hitc.keys())[0]].hits:
    print(type(hit.X))
    print([hit.X])
    break
print([[x] for x in r.X.values[1:5]])
# Out:
# <class 'numpy.float64'>
# [-142.525]
# [[-265.925], [181.025], [-281.475], [212.125]]

# %%
display(r)
x_vals = r.X.values
y_vals = r.Y.values
z_vals = r.Z.values
t_vals = r.time.values
print(x_vals, y_vals, z_vals, t_vals)
# Out:
#             event          time  npeak       Xpeak      Ypeak  nsipm        X  \
# 1483          275  1.742935e+09      3   15.761644 -65.178616      1  474.475
# 1484          275  1.742935e+09      3   15.761644 -65.178616      1 -265.925
# 1485          275  1.742935e+09      3   15.761644 -65.178616      1  181.025
# 1486          275  1.742935e+09      3   15.761644 -65.178616      1 -281.475
# 1487          275  1.742935e+09      3   15.761644 -65.178616      1  212.125
# ...           ...           ...    ...         ...        ...    ...      ...
# 14175231  1074912  1.742949e+09      0 -107.260682 -11.486680      1  196.575
# 14175232  1074912  1.742949e+09      0 -107.260682 -11.486680      1 -389.325
# 14175233  1074912  1.742949e+09      0 -107.260682 -11.486680      1  -65.775
# 14175234  1074912  1.742949e+09      0 -107.260682 -11.486680      1   88.725
# 14175235  1074912  1.742949e+09      0 -107.260682 -11.486680      1  243.225
#
#                 Y  Xrms  Yrms            Z         Q           E   Qc  \
# 1483      -32.475   0.0   0.0   159.434125  5.256973   -2.562765 -1.0
# 1484      399.925   0.0   0.0   161.691000  7.539444   -3.154945 -1.0
# 1485      414.975   0.0   0.0   161.691000  6.790727   -2.841638 -1.0
# 1486     -279.275   0.0   0.0   165.937000  5.034613   17.929243 -1.0
# 1487     -325.425   0.0   0.0   167.834250  5.043945  159.742005 -1.0
# ...           ...   ...   ...          ...       ...         ...  ...
# 14175231  214.825   0.0   0.0  1144.738500  5.329231    5.760224 -1.0
# 14175232  214.325   0.0   0.0  1147.229500  8.552230   -6.227441 -1.0
# 14175233 -356.525   0.0   0.0  1147.229500  6.788672   -4.943279 -1.0
# 14175234  492.725   0.0   0.0  1147.229500  6.301342   -4.588421 -1.0
# 14175235 -309.875   0.0   0.0  1147.229500  5.044473   -3.673212 -1.0
#
#                 Ec  track_id   Ep
# 1483           NaN        -1 -1.0
# 1484           NaN        -1 -1.0
# 1485     -0.000009        -1 -1.0
# 1486      0.000050        -1 -1.0
# 1487      0.000450        -1 -1.0
# ...            ...       ...  ...
# 14175231  0.000017        -1 -1.0
# 14175232 -0.000021        -1 -1.0
# 14175233 -0.000015        -1 -1.0
# 14175234       NaN        -1 -1.0
# 14175235 -0.000012        -1 -1.0
#
# [28931638 rows x 17 columns]
# [ 474.475 -265.925  181.025 ...  -65.775   88.725  243.225] [ -32.475  399.925  414.975 ... -356.525  492.725 -309.875] [ 159.434125  161.691     161.691    ... 1147.2295   1147.2295
#  1147.2295  ] [1.74293525e+09 1.74293525e+09 1.74293525e+09 ... 1.74294899e+09
#  1.74294899e+09 1.74294899e+09]

# %% [markdown]
# # Correct E

# %%
maps       = read_maps(os.path.expandvars('/gluster/data/next/files/TOPOLOGY_John/LPR/LightTables/map_4bar_15063.h5'))
apply_temp = True
norm_strat = NormStrategy.kr

get_coef  = apply_all_correction( maps
                                , apply_temp = apply_temp
                                , norm_strat = norm_strat
                                , norm_value = None)

time_to_Z = get_df_to_z_converter(maps) if maps.t_evol is not None else identity

# %%
get_all_coefs = get_coef(x_vals, y_vals, z_vals, t_vals)

# %%
display(get_all_coefs)
print(len(get_all_coefs))
print(len(x_vals))
# Out:
# array([6.30227589e-06,            nan, 6.23666148e-06, ...,
#        5.30967606e-06,            nan, 5.40289690e-06])
# 28931638
# 28931638

# %%
e_corr = r.E.values * get_all_coefs
print(e_corr)
z_corr = time_to_Z(z_vals)
print(z_corr)
# Out:
# [-1.61512502e-05             nan -1.77223338e-05 ... -2.62472084e-05
#              nan -1.98459866e-05]
# [ 346.84728506  351.75709321  351.75709321 ... 2495.78587656 2495.78587656
#  2495.78587656]

# %%
r['Ec'] = e_corr

# %%
display(r)
plt.hist(r.groupby('event').Ec.sum(), bins = 50, range = [0, 3])
plt.xlabel('Energy (MeV)')
plt.title('Correct energy distribution')
plt.show()
#display(pd.read_hdf('/gluster/data/next/files/TOPOLOGY_John/N100_data/15107/sophronia_cor/trigger2/ldc1/run_15107_0001_ldc1_trg2.v2.3.1.20250312-1-gc1f0fe5.HE.sophronia.h5', 'DST/Events'))
# Out:
#             event          time  npeak       Xpeak      Ypeak  nsipm        X  \
# 1483          275  1.742935e+09      3   15.761644 -65.178616      1  474.475
# 1484          275  1.742935e+09      3   15.761644 -65.178616      1 -265.925
# 1485          275  1.742935e+09      3   15.761644 -65.178616      1  181.025
# 1486          275  1.742935e+09      3   15.761644 -65.178616      1 -281.475
# 1487          275  1.742935e+09      3   15.761644 -65.178616      1  212.125
# ...           ...           ...    ...         ...        ...    ...      ...
# 14175231  1074912  1.742949e+09      0 -107.260682 -11.486680      1  196.575
# 14175232  1074912  1.742949e+09      0 -107.260682 -11.486680      1 -389.325
# 14175233  1074912  1.742949e+09      0 -107.260682 -11.486680      1  -65.775
# 14175234  1074912  1.742949e+09      0 -107.260682 -11.486680      1   88.725
# 14175235  1074912  1.742949e+09      0 -107.260682 -11.486680      1  243.225
#
#                 Y  Xrms  Yrms            Z         Q           E   Qc  \
# 1483      -32.475   0.0   0.0   159.434125  5.256973   -2.562765 -1.0
# 1484      399.925   0.0   0.0   161.691000  7.539444   -3.154945 -1.0
# 1485      414.975   0.0   0.0   161.691000  6.790727   -2.841638 -1.0
# 1486     -279.275   0.0   0.0   165.937000  5.034613   17.929243 -1.0
# 1487     -325.425   0.0   0.0   167.834250  5.043945  159.742005 -1.0
# ...           ...   ...   ...          ...       ...         ...  ...
# 14175231  214.825   0.0   0.0  1144.738500  5.329231    5.760224 -1.0
# 14175232  214.325   0.0   0.0  1147.229500  8.552230   -6.227441 -1.0
# 14175233 -356.525   0.0   0.0  1147.229500  6.788672   -4.943279 -1.0
# 14175234  492.725   0.0   0.0  1147.229500  6.301342   -4.588421 -1.0
# 14175235 -309.875   0.0   0.0  1147.229500  5.044473   -3.673212 -1.0
#
#                 Ec  track_id   Ep
# 1483     -0.000016        -1 -1.0
# 1484           NaN        -1 -1.0
# 1485     -0.000018        -1 -1.0
# 1486      0.000097        -1 -1.0
# 1487      0.000833        -1 -1.0
# ...            ...       ...  ...
# 14175231  0.000029        -1 -1.0
# 14175232 -0.000040        -1 -1.0
# 14175233 -0.000026        -1 -1.0
# 14175234       NaN        -1 -1.0
# 14175235 -0.000020        -1 -1.0
#
# [28931638 rows x 17 columns]

# %% [markdown]
# # Lets try and read everything into one file to be used

# %%
r.to_hdf('files/15107_corrected.h5', key = 'RECO/Events', mode = 'a')

# %%
dsts = pd.read_hdf('files/15107_passing.h5', key = 'DST/Events')
display(dsts)
# Out:
#          event          time  s1_peak  s2_peak  nS1  nS2    S1w        S1h  \
# 2          275  1.742935e+09        0        0    1    1  375.0  20.105528
# 14         590  1.742935e+09        0        0    1    1  400.0  41.841473
# 15         597  1.742935e+09        0        0    1    1  650.0  16.592751
# 20        1556  1.742935e+09        0        0    1    1  350.0  17.792589
# 25        1794  1.742935e+09        0        0    1    1  275.0  21.349106
# ...        ...           ...      ...      ...  ...  ...    ...        ...
# 25147   658454  1.742944e+09        0        0    1    1  375.0  10.825253
# 25152   658699  1.742944e+09        0        0    1    1  575.0  16.538542
# 25153   658923  1.742944e+09        0        0    1    1  625.0  15.709264
# 25160  1074513  1.742949e+09        0        0    1    1  350.0  19.289764
# 25164  1074912  1.742949e+09        0        0    1    1  325.0  57.295929
#
#               S1e        S1t  ...  Nsipm           DT            Z       Zrms  \
# 2      130.680893  1217525.0  ...   2539   185.960632   185.960632  18.371055
# 14     240.074432  1139325.0  ...   2969   266.157379   266.157379  29.010471
# 15      97.683167   493475.0  ...   2261   919.024780   919.024780   9.251109
# 20     102.266724   530275.0  ...   2102   877.213196   877.213196   8.832326
# 25     106.103920   877900.0  ...   2550   531.588501   531.588501   8.046095
# ...           ...        ...  ...    ...          ...          ...        ...
# 25147   69.822937  1202675.0  ...   2851   205.808258   205.808258   9.201199
# 25152   87.122505   839450.0  ...   2870   567.041748   567.041748  12.670540
# 25153   91.425804  1274300.0  ...   2163   129.195633   129.195633  18.046918
# 25160  105.112312   792425.0  ...   2470   616.065002   616.065002  13.975123
# 25164  309.272644   371725.0  ...   3005  1040.768677  1040.768677  33.414348
#
#                 X          Y           R       Phi        Xrms        Yrms
# 2       15.761644 -65.178615   67.057299 -1.333529  190.955556  208.454665
# 14     170.053074  19.509000  171.168482  0.114224  217.766683  168.386432
# 15      75.948209  52.021293   92.056208  0.600559  214.760246  197.605371
# 20     110.182593   3.345906  110.233384  0.030358  237.921637  199.830332
# 25     108.494903  87.064883  139.109446  0.676251  240.576917  220.669800
# ...           ...        ...         ...       ...         ...         ...
# 25147   15.608674  98.721551   99.947863  1.413986  224.630671  251.603989
# 25152   40.841408  -8.578211   41.732557 -0.207028  226.215802  217.065314
# 25153   86.402601 -24.296199   89.753634 -0.274119  203.298461  188.980867
# 25160   -3.418172  -1.705237    3.819913 -2.678846  203.424014  201.055704
# 25164 -107.260682 -11.486681  107.873990 -3.034908  203.519569  173.929109
#
# [24826 rows x 26 columns]

# %%
dsts.to_hdf('files/15107_corrected.h5', key = 'DST/Events', mode = 'a')

# %%
print(r.event.nunique())
print(dsts.event.nunique())
# Out:
# 24826
# 24826

# %%
# !ptdump files/15107_corrected.h5
# Out:
# ^C

# %%
q = pd.read_hdf('files/15107_corrected.h5', key = 'RECO/Events')
display(q)
# Out:
#             event          time  npeak       Xpeak      Ypeak  nsipm        X  \
# 1483          275  1.742935e+09      3   15.761644 -65.178616      1  474.475
# 1484          275  1.742935e+09      3   15.761644 -65.178616      1 -265.925
# 1485          275  1.742935e+09      3   15.761644 -65.178616      1  181.025
# 1486          275  1.742935e+09      3   15.761644 -65.178616      1 -281.475
# 1487          275  1.742935e+09      3   15.761644 -65.178616      1  212.125
# ...           ...           ...    ...         ...        ...    ...      ...
# 14175231  1074912  1.742949e+09      0 -107.260682 -11.486680      1  196.575
# 14175232  1074912  1.742949e+09      0 -107.260682 -11.486680      1 -389.325
# 14175233  1074912  1.742949e+09      0 -107.260682 -11.486680      1  -65.775
# 14175234  1074912  1.742949e+09      0 -107.260682 -11.486680      1   88.725
# 14175235  1074912  1.742949e+09      0 -107.260682 -11.486680      1  243.225
#
#                 Y  Xrms  Yrms            Z         Q           E   Qc  \
# 1483      -32.475   0.0   0.0   159.434125  5.256973   -2.562765 -1.0
# 1484      399.925   0.0   0.0   161.691000  7.539444   -3.154945 -1.0
# 1485      414.975   0.0   0.0   161.691000  6.790727   -2.841638 -1.0
# 1486     -279.275   0.0   0.0   165.937000  5.034613   17.929243 -1.0
# 1487     -325.425   0.0   0.0   167.834250  5.043945  159.742005 -1.0
# ...           ...   ...   ...          ...       ...         ...  ...
# 14175231  214.825   0.0   0.0  1144.738500  5.329231    5.760224 -1.0
# 14175232  214.325   0.0   0.0  1147.229500  8.552230   -6.227441 -1.0
# 14175233 -356.525   0.0   0.0  1147.229500  6.788672   -4.943279 -1.0
# 14175234  492.725   0.0   0.0  1147.229500  6.301342   -4.588421 -1.0
# 14175235 -309.875   0.0   0.0  1147.229500  5.044473   -3.673212 -1.0
#
#                 Ec  track_id   Ep
# 1483     -0.000016        -1 -1.0
# 1484           NaN        -1 -1.0
# 1485     -0.000018        -1 -1.0
# 1486      0.000097        -1 -1.0
# 1487      0.000833        -1 -1.0
# ...            ...       ...  ...
# 14175231  0.000029        -1 -1.0
# 14175232 -0.000040        -1 -1.0
# 14175233 -0.000026        -1 -1.0
# 14175234       NaN        -1 -1.0
# 14175235 -0.000020        -1 -1.0
#
# [28931638 rows x 17 columns]

# %%
n100_dir = '/gluster/data/next/files/TOPOLOGY_John/N100_data/15107/sophronia/trigger2/'

evt_dst  = []
run_info = []

for i in tqdm(range(1, 8)):

    print(f"LDC {i}")
    folder_path = n100_dir + 'ldc' + str(i) + '/'
    file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]
    
    dst = load_dsts([folder_path + x for x in file_names], 'Run', 'events')
    dst = dst[dst.evt_number.isin(events_of_interest)]
    evt_dst.append(dst)

evt_dst = pd.concat(evt_dst)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# LDC 1
#  14%|█▍        | 1/7 [00:39<03:58, 39.82s/it]
# LDC 2
#  29%|██▊       | 2/7 [01:31<03:55, 47.03s/it]
# LDC 3
#  43%|████▎     | 3/7 [02:20<03:11, 47.84s/it]
# LDC 4
#  57%|█████▋    | 4/7 [03:10<02:25, 48.57s/it]
# LDC 5
#  71%|███████▏  | 5/7 [04:03<01:40, 50.18s/it]
# LDC 6
#  86%|████████▌ | 6/7 [04:55<00:50, 50.92s/it]
# LDC 7
# 100%|██████████| 7/7 [05:50<00:00, 50.06s/it]

# %%
display(evt_dst)
# Out:
#       evt_number      timestamp
# 1            275  1742935251202
# 4            590  1742935255246
# 5            597  1742935255345
# 8           1556  1742935267472
# 11          1794  1742935270569
# ...          ...            ...
# 9871      658454  1742943661813
# 9873      658699  1742943664872
# 9874      658923  1742943667847
# 9876     1074513  1742948988242
# 9878     1074912  1742948993256
#
# [24826 rows x 2 columns]

# %%
dst = load_dsts([folder_path + x for x in file_names], 'Run', 'runInfo')

# %%
#dst = pd.concat([dst, dst])
#dst = dst.head(24826)
display(dst)
display(r)
display(evt_dst)
# Out:
#       run_number
# 0          15107
# 1          15107
# 2          15107
# 3          15107
# 4          15107
# ...          ...
# 5055       15107
# 5056       15107
# 5057       15107
# 5058       15107
# 5059       15107
#
# [24826 rows x 1 columns]
#             event          time  npeak       Xpeak      Ypeak  nsipm        X  \
# 1483          275  1.742935e+09      3   15.761644 -65.178616      1  474.475
# 1484          275  1.742935e+09      3   15.761644 -65.178616      1 -265.925
# 1485          275  1.742935e+09      3   15.761644 -65.178616      1  181.025
# 1486          275  1.742935e+09      3   15.761644 -65.178616      1 -281.475
# 1487          275  1.742935e+09      3   15.761644 -65.178616      1  212.125
# ...           ...           ...    ...         ...        ...    ...      ...
# 14175231  1074912  1.742949e+09      0 -107.260682 -11.486680      1  196.575
# 14175232  1074912  1.742949e+09      0 -107.260682 -11.486680      1 -389.325
# 14175233  1074912  1.742949e+09      0 -107.260682 -11.486680      1  -65.775
# 14175234  1074912  1.742949e+09      0 -107.260682 -11.486680      1   88.725
# 14175235  1074912  1.742949e+09      0 -107.260682 -11.486680      1  243.225
#
#                 Y  Xrms  Yrms            Z         Q           E   Qc  \
# 1483      -32.475   0.0   0.0   159.434125  5.256973   -2.562765 -1.0
# 1484      399.925   0.0   0.0   161.691000  7.539444   -3.154945 -1.0
# 1485      414.975   0.0   0.0   161.691000  6.790727   -2.841638 -1.0
# 1486     -279.275   0.0   0.0   165.937000  5.034613   17.929243 -1.0
# 1487     -325.425   0.0   0.0   167.834250  5.043945  159.742005 -1.0
# ...           ...   ...   ...          ...       ...         ...  ...
# 14175231  214.825   0.0   0.0  1144.738500  5.329231    5.760224 -1.0
# 14175232  214.325   0.0   0.0  1147.229500  8.552230   -6.227441 -1.0
# 14175233 -356.525   0.0   0.0  1147.229500  6.788672   -4.943279 -1.0
# 14175234  492.725   0.0   0.0  1147.229500  6.301342   -4.588421 -1.0
# 14175235 -309.875   0.0   0.0  1147.229500  5.044473   -3.673212 -1.0
#
#                 Ec  track_id   Ep
# 1483     -0.000016        -1 -1.0
# 1484           NaN        -1 -1.0
# 1485     -0.000018        -1 -1.0
# 1486      0.000097        -1 -1.0
# 1487      0.000833        -1 -1.0
# ...            ...       ...  ...
# 14175231  0.000029        -1 -1.0
# 14175232 -0.000040        -1 -1.0
# 14175233 -0.000026        -1 -1.0
# 14175234       NaN        -1 -1.0
# 14175235 -0.000020        -1 -1.0
#
# [28931638 rows x 17 columns]
#       evt_number      timestamp
# 1            275  1742935251202
# 4            590  1742935255246
# 5            597  1742935255345
# 8           1556  1742935267472
# 11          1794  1742935270569
# ...          ...            ...
# 9871      658454  1742943661813
# 9873      658699  1742943664872
# 9874      658923  1742943667847
# 9876     1074513  1742948988242
# 9878     1074912  1742948993256
#
# [24826 rows x 2 columns]

# %%
file = 'files/15107_formatted.h5'
compression = 'ZLIB4'
with tb.open_file(file, "w", filters = tbl.filters(compression)) as h5out:

    df_writer(h5out,   r, "RECO", "Events" , compression="ZLIB4")
    df_writer(h5out, dst, "Run" , "runInfo" , compression="ZLIB4")
    df_writer(h5out,   evt_dst, "Run" , "events", compression="ZLIB4")

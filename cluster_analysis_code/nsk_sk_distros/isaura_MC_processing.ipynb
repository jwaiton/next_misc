# %% [markdown]
# ### This notebook will take MC hits and process them such that they can be compared to the isaura tracks information

# %%
import sys,os,os.path
#sys.path.append("../../")   # cite IC from parent directory
sys.path.append("/gluster/data/next/software/IC_satkill/")
#sys.path.append("/gluster/data/next/software/IC_sophronia/")
#sys.path.append(os.path.expanduser('~/code/eol_hsrl_python'))
sys.path.append(os.path.expanduser('~/code/eol_hsrl_python'))
os.environ['ICTDIR']='/gluster/data/next/software/IC_satkill/'

sys.path.append('/gluster/data/next/notebooks/john_books/fom_fitting')
import functions as func

from IC.invisible_cities.dataflow                  import                  dataflow as  fl
from IC.invisible_cities.cities.components import track_blob_info_creator_extractor
from IC.invisible_cities.types  .ic_types          import         types_dict_tracks
from IC.invisible_cities.core                      import           system_of_units as units
from IC.invisible_cities.evm.event_model     import HitCollection
from IC.invisible_cities.evm.event_model     import Hit
from IC.invisible_cities.evm.event_model     import Cluster
from IC.invisible_cities.types.ic_types     import xy
from IC.invisible_cities.reco.paolina_functions import voxelize_hits, drop_end_point_voxels, make_track_graphs, get_track_energy

from typing                import Dict
import time

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['mathtext.fontset'] = 'stix'
rcParams['font.family'] = 'STIXGeneral'
rcParams['figure.figsize'] = [10, 8]
rcParams['font.size'] = 22

import pandas as pd
import numpy  as np
import tables as tb

# %%
def hits_from_df_MC (dst : pd.DataFrame, skip_NN : bool = False) -> Dict[int, HitCollection]:
    """
    Function that transforms pandas DataFrame dst to HitCollection
    ------
    Parameters
    ------
    dst : pd.DataFrame
        DataFrame with obligatory columns :
                event, npeak, X, Y, Z,  Q, E
        If time, nsipm, Xrms, Yrms, Qc, Ec, track_id are not
        inside dst the default value is set to -1
        If Xpeak, Ypeak not in dst the default value is -1000
    ------
    Returns
    ------
    Dictionary {event_number : HitCollection}
    """
    all_events = {}
    times = getattr(dst, 'time', [-1]*len(dst))
    for (event, time) , df in dst.groupby(['event_id', times]):
        #pandas is not consistent with numpy dtypes so we have to change it by hand
        event = np.int32(event)
        hits  = []
        for i, row in df.iterrows():
            Q = getattr(row,'Q', row.energy)
            if skip_NN and Q == NN:
                continue
            if hasattr(row, 'Xrms'):
                Xrms  = row.Xrms
                Xrms2 = Xrms**2
            else:
                Xrms = Xrms2 = -1
            if hasattr(row, 'Yrms'):
                Yrms  = row.Yrms
                Yrms2 = Yrms**2
            else:
                Yrms = Yrms2 = -1
            nsipm   = getattr(row, 'nsipm'   , -1   )     # for backwards compatibility
            Qc      = getattr(row, 'Qc'      , -1   )     # for backwards compatibility
            Xpeak   = getattr(row, 'Xpeak'   , -1000)     # for backwards compatibility
            Ypeak   = getattr(row, 'Ypeak'   , -1000)     # for backwards compatibility
            Ec      = getattr(row, 'Ec'      , -1   )     # for backwards compatibility
            trackID = getattr(row, 'track_id', -1   )     # for backwards compatibility
            Ep      = getattr(row, "Ep"      , -1   )     # for backwards compatibility

            hit = Hit(row.npeak            ,
                      Cluster(Q               ,
                              xy(row.x, row.y),
                              xy(Xrms2, Yrms2),
                              nsipm = nsipm   ,
                              z     = row.z   ,
                              E     = row.energy   ,
                              Qc    = Qc      ),
                      row.z                ,
                      row.energy                ,
                      xy(Xpeak, Ypeak)     ,
                      s2_energy_c = Ec     ,
                      track_id    = trackID,
                      Ep          = Ep     )

            hits.append(hit)

        if len(hits):
            all_events[event] = HitCollection(event, time, hits=hits)

    return all_events


def count_tracks_mc(hits_deco):
   
    # stuff needed for paolina track counting
    energy_threshold = 10
    min_voxels = 3
    
    base_vsize = 12 #mm
    the_hits = []

    xs = hits_deco.x
    ys = hits_deco.y
    zs = hits_deco.z
    es = hits_deco.energy

    for x, y, z, e in zip(xs, ys, zs, es):
        if np.isnan(e): continue
        h = Hit(0, Cluster(0, xy(x,y), xy(0,0), 0), z, e*1000, xy(0,0))
        the_hits.append(h)

    voxels = voxelize_hits(the_hits,
                           np.array([base_vsize, base_vsize, base_vsize]), False)

    (mod_voxels, dropped_voxels) = drop_end_point_voxels(voxels, energy_threshold, min_voxels)

    
    tracks = make_track_graphs(mod_voxels)
    tracks = sorted(tracks, key=get_track_energy, reverse = True)
    
    track_no = 0
    for c, t in enumerate(tracks, 0):
        track_no += 1
    
    return track_no

# %%
folder_path = '/gluster/data/next/files/TOPOLOGY_John/HYPPOS_DATA_QTHR/BEERSHEBA_STUDY/satkill/PORT_1a/isaura/'


# take the event energy from the summary
file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]


dfs = []

for file in file_names:
    file_path = folder_path + file
    df_MC = pd.read_hdf(file_path, 'MC/hits')
    # do the processing for the hits here
    for pid, df in df_MC.groupby('event_id'):
        # find each track and how much energy should be attributed to it

    dfs.append(df)
    
MC_hit_energy = pd.concat(dfs, axis = 0, ignore_index = True)

# %%
# one file first
v_size = 12

paolina_params = dict(
                    vox_size = [v_size * units.mm, v_size * units.mm, v_size * units.mm],
                    strict_vox_size = False,
                    energy_threshold = 10 * units.keV,
                    min_voxels = 3,
                    blob_radius = 18 * units.mm,
                    max_num_hits = 10000)

topology_extractor = track_blob_info_creator_extractor(**paolina_params)

folder_path = '/gluster/data/next/files/TOPOLOGY_John/HYPPOS_DATA_QTHR/BEERSHEBA_STUDY/satkill/PORT_1a/isaura/'
file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]
df_MC = pd.read_hdf(folder_path + file_names[0], 'MC/hits')
# add npeaks (this is so janky)
df_MC['npeak'] = 1

# generate hit collection from MC (might work?)
mc_hitc = hits_from_df_MC(df_MC)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 23
#      20 # generate hit collection from MC (might work?)
#      21 mc_hitc = hits_from_df_MC(df_MC)
# ---> 23 output = topology_extractor(mc_hitc)
#
# File /gluster/data/next/software/IC_satkill/IC/invisible_cities/cities/components.py:1267, in track_blob_info_creator_extractor.<locals>.create_extract_track_blob_info(hitc)
#    1265 def create_extract_track_blob_info(hitc):
#    1266     df = pd.DataFrame(columns=list(types_dict_tracks.keys()))
# -> 1267     if len(hitc.hits) > max_num_hits:
#    1268         return df, hitc, True
#    1269     #track_hits is a new Hitcollection object that contains hits belonging to tracks, and hits that couldnt be corrected
#
# AttributeError: 'dict' object has no attribute 'hits'

# %%
print(mc_hitc)
# Out:
# {80000: HitCollectionHit list:<Hit : npeak = 1 z = 742.98828125 XYpeak = -1000, -1000 E = 0.008066149428486824 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.008066149428486824
#                     xy = xy(x=405.6971130371094, y=84.1243667602539) 3dHit = Hit(405.6971130371094, 84.1243667602539, 742.98828125, E=0.008066149428486824)  > >, 80001: HitCollectionHit list:<Hit : npeak = 1 z = 989.3580932617188 XYpeak = -1000, -1000 E = 0.0013445025542750955 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0013445025542750955
#                     xy = xy(x=138.13656616210938, y=-98.83601379394531) 3dHit = Hit(138.13656616210938, -98.83601379394531, 989.3580932617188, E=0.0013445025542750955)  > >, 80002: HitCollectionHit list:<Hit : npeak = 1 z = 251.62342834472656 XYpeak = -1000, -1000 E = 0.0019958766642957926 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0019958766642957926
#                     xy = xy(x=-258.01922607421875, y=335.5096435546875) 3dHit = Hit(-258.01922607421875, 335.5096435546875, 251.62342834472656, E=0.0019958766642957926)  > >, 80003: HitCollectionHit list:<Hit : npeak = 1 z = 290.4821472167969 XYpeak = -1000, -1000 E = 0.0008020616951398551 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008020616951398551
#                     xy = xy(x=-83.13700103759766, y=-432.9624328613281) 3dHit = Hit(-83.13700103759766, -432.9624328613281, 290.4821472167969, E=0.0008020616951398551)  > >, 80004: HitCollectionHit list:<Hit : npeak = 1 z = 1110.349609375 XYpeak = -1000, -1000 E = 0.00017510262841824442 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00017510262841824442
#                     xy = xy(x=48.51671600341797, y=19.88475799560547) 3dHit = Hit(48.51671600341797, 19.88475799560547, 1110.349609375, E=0.00017510262841824442)  > >, 80005: HitCollectionHit list:<Hit : npeak = 1 z = 666.8612060546875 XYpeak = -1000, -1000 E = 0.0031339996494352818 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0031339996494352818
#                     xy = xy(x=263.7099304199219, y=252.40098571777344) 3dHit = Hit(263.7099304199219, 252.40098571777344, 666.8612060546875, E=0.0031339996494352818)  > >, 80006: HitCollectionHit list:<Hit : npeak = 1 z = 621.2135620117188 XYpeak = -1000, -1000 E = 0.0021383834537118673 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0021383834537118673
#                     xy = xy(x=-17.38610076904297, y=297.31732177734375) 3dHit = Hit(-17.38610076904297, 297.31732177734375, 621.2135620117188, E=0.0021383834537118673)  > >, 80007: HitCollectionHit list:<Hit : npeak = 1 z = 433.3847961425781 XYpeak = -1000, -1000 E = 0.0010364569025114179 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010364569025114179
#                     xy = xy(x=192.9977264404297, y=173.4539337158203) 3dHit = Hit(192.9977264404297, 173.4539337158203, 433.3847961425781, E=0.0010364569025114179)  > >, 80008: HitCollectionHit list:<Hit : npeak = 1 z = 911.8324584960938 XYpeak = -1000, -1000 E = 0.0005986575852148235 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005986575852148235
#                     xy = xy(x=110.43807983398438, y=199.11788940429688) 3dHit = Hit(110.43807983398438, 199.11788940429688, 911.8324584960938, E=0.0005986575852148235)  > >, 80009: HitCollectionHit list:<Hit : npeak = 1 z = 308.0854187011719 XYpeak = -1000, -1000 E = 0.0016710360068827868 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016710360068827868
#                     xy = xy(x=170.42047119140625, y=152.9593048095703) 3dHit = Hit(170.42047119140625, 152.9593048095703, 308.0854187011719, E=0.0016710360068827868)  > >, 80010: HitCollectionHit list:<Hit : npeak = 1 z = 600.2237548828125 XYpeak = -1000, -1000 E = 0.0012704270193353295 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012704270193353295
#                     xy = xy(x=328.99407958984375, y=-39.30674743652344) 3dHit = Hit(328.99407958984375, -39.30674743652344, 600.2237548828125, E=0.0012704270193353295)  > >, 80011: HitCollectionHit list:<Hit : npeak = 1 z = 399.68487548828125 XYpeak = -1000, -1000 E = 8.766972314333543e-06 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 8.766972314333543e-06
#                     xy = xy(x=421.50079345703125, y=253.93917846679688) 3dHit = Hit(421.50079345703125, 253.93917846679688, 399.68487548828125, E=8.766972314333543e-06)  > >, 80012: HitCollectionHit list:<Hit : npeak = 1 z = 643.3394775390625 XYpeak = -1000, -1000 E = 0.002771124942228198 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002771124942228198
#                     xy = xy(x=-361.179931640625, y=-315.75201416015625) 3dHit = Hit(-361.179931640625, -315.75201416015625, 643.3394775390625, E=0.002771124942228198)  > >, 80013: HitCollectionHit list:<Hit : npeak = 1 z = 350.7464599609375 XYpeak = -1000, -1000 E = 0.00010676588135538623 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00010676588135538623
#                     xy = xy(x=55.54607009887695, y=492.0) 3dHit = Hit(55.54607009887695, 492.0, 350.7464599609375, E=0.00010676588135538623)  > >, 80014: HitCollectionHit list:<Hit : npeak = 1 z = 1151.41796875 XYpeak = -1000, -1000 E = 0.00047295918921008706 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00047295918921008706
#                     xy = xy(x=-418.4467468261719, y=-232.83773803710938) 3dHit = Hit(-418.4467468261719, -232.83773803710938, 1151.41796875, E=0.00047295918921008706)  > >, 80015: HitCollectionHit list:<Hit : npeak = 1 z = 359.96453857421875 XYpeak = -1000, -1000 E = 0.0004203109710942954 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0004203109710942954
#                     xy = xy(x=-423.4985046386719, y=23.010656356811523) 3dHit = Hit(-423.4985046386719, 23.010656356811523, 359.96453857421875, E=0.0004203109710942954)  > >, 80016: HitCollectionHit list:<Hit : npeak = 1 z = 434.7783508300781 XYpeak = -1000, -1000 E = 0.0032734586857259274 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0032734586857259274
#                     xy = xy(x=8.031726837158203, y=476.6605224609375) 3dHit = Hit(8.031726837158203, 476.6605224609375, 434.7783508300781, E=0.0032734586857259274)  > >, 80017: HitCollectionHit list:<Hit : npeak = 1 z = 718.2802734375 XYpeak = -1000, -1000 E = 0.0008191851084120572 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008191851084120572
#                     xy = xy(x=135.1602325439453, y=214.5701446533203) 3dHit = Hit(135.1602325439453, 214.5701446533203, 718.2802734375, E=0.0008191851084120572)  > >, 80018: HitCollectionHit list:<Hit : npeak = 1 z = 572.8950805664062 XYpeak = -1000, -1000 E = 0.0005326740792952478 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005326740792952478
#                     xy = xy(x=-181.9770050048828, y=-370.4104919433594) 3dHit = Hit(-181.9770050048828, -370.4104919433594, 572.8950805664062, E=0.0005326740792952478)  > >, 80019: HitCollectionHit list:<Hit : npeak = 1 z = 742.4160766601562 XYpeak = -1000, -1000 E = 0.0001731086813379079 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0001731086813379079
#                     xy = xy(x=-149.97096252441406, y=44.47807693481445) 3dHit = Hit(-149.97096252441406, 44.47807693481445, 742.4160766601562, E=0.0001731086813379079)  > >, 80020: HitCollectionHit list:<Hit : npeak = 1 z = 476.4447937011719 XYpeak = -1000, -1000 E = 0.0016563181998208165 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016563181998208165
#                     xy = xy(x=220.1230010986328, y=27.72784996032715) 3dHit = Hit(220.1230010986328, 27.72784996032715, 476.4447937011719, E=0.0016563181998208165)  > >, 80021: HitCollectionHit list:<Hit : npeak = 1 z = 1207.6048583984375 XYpeak = -1000, -1000 E = 0.0012260511284694076 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012260511284694076
#                     xy = xy(x=346.05120849609375, y=-142.0093536376953) 3dHit = Hit(346.05120849609375, -142.0093536376953, 1207.6048583984375, E=0.0012260511284694076)  > >, 80022: HitCollectionHit list:<Hit : npeak = 1 z = 113.78150177001953 XYpeak = -1000, -1000 E = 0.0010238852119073272 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010238852119073272
#                     xy = xy(x=364.2755432128906, y=2.6714348793029785) 3dHit = Hit(364.2755432128906, 2.6714348793029785, 113.78150177001953, E=0.0010238852119073272)  > >, 80023: HitCollectionHit list:<Hit : npeak = 1 z = 572.093017578125 XYpeak = -1000, -1000 E = 0.0010419582249596715 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010419582249596715
#                     xy = xy(x=-124.31891632080078, y=185.3267364501953) 3dHit = Hit(-124.31891632080078, 185.3267364501953, 572.093017578125, E=0.0010419582249596715)  > >, 80024: HitCollectionHit list:<Hit : npeak = 1 z = 295.63470458984375 XYpeak = -1000, -1000 E = 0.0009041986195370555 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009041986195370555
#                     xy = xy(x=262.6881103515625, y=-169.1105194091797) 3dHit = Hit(262.6881103515625, -169.1105194091797, 295.63470458984375, E=0.0009041986195370555)  > >, 80025: HitCollectionHit list:<Hit : npeak = 1 z = 107.6778793334961 XYpeak = -1000, -1000 E = 0.002103997627273202 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002103997627273202
#                     xy = xy(x=76.70034790039062, y=-136.10592651367188) 3dHit = Hit(76.70034790039062, -136.10592651367188, 107.6778793334961, E=0.002103997627273202)  > >, 80026: HitCollectionHit list:<Hit : npeak = 1 z = 5.492738246917725 XYpeak = -1000, -1000 E = 0.0010494294110685587 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010494294110685587
#                     xy = xy(x=-431.1250305175781, y=65.95555114746094) 3dHit = Hit(-431.1250305175781, 65.95555114746094, 5.492738246917725, E=0.0010494294110685587)  > >, 80027: HitCollectionHit list:<Hit : npeak = 1 z = 356.5737609863281 XYpeak = -1000, -1000 E = 0.001796517870388925 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001796517870388925
#                     xy = xy(x=-410.117431640625, y=141.1871795654297) 3dHit = Hit(-410.117431640625, 141.1871795654297, 356.5737609863281, E=0.001796517870388925)  > >, 80028: HitCollectionHit list:<Hit : npeak = 1 z = 166.2476348876953 XYpeak = -1000, -1000 E = 0.0007355244015343487 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007355244015343487
#                     xy = xy(x=242.1359405517578, y=12.032073974609375) 3dHit = Hit(242.1359405517578, 12.032073974609375, 166.2476348876953, E=0.0007355244015343487)  > >, 80029: HitCollectionHit list:<Hit : npeak = 1 z = 356.0455017089844 XYpeak = -1000, -1000 E = 0.00018493636162020266 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00018493636162020266
#                     xy = xy(x=304.9466857910156, y=157.55812072753906) 3dHit = Hit(304.9466857910156, 157.55812072753906, 356.0455017089844, E=0.00018493636162020266)  > >, 80030: HitCollectionHit list:<Hit : npeak = 1 z = 560.4244384765625 XYpeak = -1000, -1000 E = 0.0010545473778620362 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010545473778620362
#                     xy = xy(x=165.0695037841797, y=230.54232788085938) 3dHit = Hit(165.0695037841797, 230.54232788085938, 560.4244384765625, E=0.0010545473778620362)  > >, 80031: HitCollectionHit list:<Hit : npeak = 1 z = 410.38128662109375 XYpeak = -1000, -1000 E = 0.00020159236737526953 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00020159236737526953
#                     xy = xy(x=-158.60618591308594, y=73.76724243164062) 3dHit = Hit(-158.60618591308594, 73.76724243164062, 410.38128662109375, E=0.00020159236737526953)  > >, 80032: HitCollectionHit list:<Hit : npeak = 1 z = 1098.1773681640625 XYpeak = -1000, -1000 E = 0.0016160893719643354 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016160893719643354
#                     xy = xy(x=246.40155029296875, y=415.0158386230469) 3dHit = Hit(246.40155029296875, 415.0158386230469, 1098.1773681640625, E=0.0016160893719643354)  > >, 80033: HitCollectionHit list:<Hit : npeak = 1 z = 354.310791015625 XYpeak = -1000, -1000 E = 0.0005583824822679162 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005583824822679162
#                     xy = xy(x=138.58766174316406, y=-422.6390075683594) 3dHit = Hit(138.58766174316406, -422.6390075683594, 354.310791015625, E=0.0005583824822679162)  > >, 80034: HitCollectionHit list:<Hit : npeak = 1 z = 1063.1019287109375 XYpeak = -1000, -1000 E = 0.0012529600644484162 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012529600644484162
#                     xy = xy(x=229.02333068847656, y=149.12066650390625) 3dHit = Hit(229.02333068847656, 149.12066650390625, 1063.1019287109375, E=0.0012529600644484162)  > >, 80035: HitCollectionHit list:<Hit : npeak = 1 z = 1027.8267822265625 XYpeak = -1000, -1000 E = 0.0005465269787237048 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005465269787237048
#                     xy = xy(x=-252.88723754882812, y=397.96075439453125) 3dHit = Hit(-252.88723754882812, 397.96075439453125, 1027.8267822265625, E=0.0005465269787237048)  > >, 80036: HitCollectionHit list:<Hit : npeak = 1 z = 1129.4267578125 XYpeak = -1000, -1000 E = 0.0018798145465552807 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0018798145465552807
#                     xy = xy(x=-39.67066955566406, y=329.3470153808594) 3dHit = Hit(-39.67066955566406, 329.3470153808594, 1129.4267578125, E=0.0018798145465552807)  > >, 80037: HitCollectionHit list:<Hit : npeak = 1 z = 741.6205444335938 XYpeak = -1000, -1000 E = 0.0016198763623833656 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016198763623833656
#                     xy = xy(x=391.0351257324219, y=-91.75900268554688) 3dHit = Hit(391.0351257324219, -91.75900268554688, 741.6205444335938, E=0.0016198763623833656)  > >, 80038: HitCollectionHit list:<Hit : npeak = 1 z = 253.90521240234375 XYpeak = -1000, -1000 E = 0.002353866584599018 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002353866584599018
#                     xy = xy(x=-259.34796142578125, y=272.5766906738281) 3dHit = Hit(-259.34796142578125, 272.5766906738281, 253.90521240234375, E=0.002353866584599018)  > >, 80039: HitCollectionHit list:<Hit : npeak = 1 z = 553.6817626953125 XYpeak = -1000, -1000 E = 0.0012496537528932095 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012496537528932095
#                     xy = xy(x=319.5870666503906, y=-12.085088729858398) 3dHit = Hit(319.5870666503906, -12.085088729858398, 553.6817626953125, E=0.0012496537528932095)  > >, 80040: HitCollectionHit list:<Hit : npeak = 1 z = 70.12711334228516 XYpeak = -1000, -1000 E = 0.0010280145797878504 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010280145797878504
#                     xy = xy(x=227.30784606933594, y=283.2062072753906) 3dHit = Hit(227.30784606933594, 283.2062072753906, 70.12711334228516, E=0.0010280145797878504)  > >, 80041: HitCollectionHit list:<Hit : npeak = 1 z = 343.4337463378906 XYpeak = -1000, -1000 E = 0.0007564537227153778 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007564537227153778
#                     xy = xy(x=107.9263687133789, y=-78.94827270507812) 3dHit = Hit(107.9263687133789, -78.94827270507812, 343.4337463378906, E=0.0007564537227153778)  > >, 80042: HitCollectionHit list:<Hit : npeak = 1 z = 774.8621215820312 XYpeak = -1000, -1000 E = 1.2776096809830051e-05 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 1.2776096809830051e-05
#                     xy = xy(x=449.5298156738281, y=205.3915252685547) 3dHit = Hit(449.5298156738281, 205.3915252685547, 774.8621215820312, E=1.2776096809830051e-05)  > >, 80043: HitCollectionHit list:<Hit : npeak = 1 z = 350.4761047363281 XYpeak = -1000, -1000 E = 0.0015143726486712694 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0015143726486712694
#                     xy = xy(x=255.29319763183594, y=89.88761138916016) 3dHit = Hit(255.29319763183594, 89.88761138916016, 350.4761047363281, E=0.0015143726486712694)  > >, 80044: HitCollectionHit list:<Hit : npeak = 1 z = 1253.38720703125 XYpeak = -1000, -1000 E = 0.0006847044569440186 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006847044569440186
#                     xy = xy(x=477.9140625, y=-111.36500549316406) 3dHit = Hit(477.9140625, -111.36500549316406, 1253.38720703125, E=0.0006847044569440186)  > >, 80045: HitCollectionHit list:<Hit : npeak = 1 z = 1248.85009765625 XYpeak = -1000, -1000 E = 0.0005055538495071232 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005055538495071232
#                     xy = xy(x=-43.769771575927734, y=303.7145690917969) 3dHit = Hit(-43.769771575927734, 303.7145690917969, 1248.85009765625, E=0.0005055538495071232)  > >, 80046: HitCollectionHit list:<Hit : npeak = 1 z = 1051.49462890625 XYpeak = -1000, -1000 E = 0.0011571107897907495 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0011571107897907495
#                     xy = xy(x=-22.931705474853516, y=-483.3794860839844) 3dHit = Hit(-22.931705474853516, -483.3794860839844, 1051.49462890625, E=0.0011571107897907495)  > >, 80047: HitCollectionHit list:<Hit : npeak = 1 z = 443.2075500488281 XYpeak = -1000, -1000 E = 2.2276368326856755e-05 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 2.2276368326856755e-05
#                     xy = xy(x=222.2420196533203, y=442.68597412109375) 3dHit = Hit(222.2420196533203, 442.68597412109375, 443.2075500488281, E=2.2276368326856755e-05)  > >, 80048: HitCollectionHit list:<Hit : npeak = 1 z = 298.71453857421875 XYpeak = -1000, -1000 E = 0.0002035899378824979 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0002035899378824979
#                     xy = xy(x=20.406091690063477, y=382.11212158203125) 3dHit = Hit(20.406091690063477, 382.11212158203125, 298.71453857421875, E=0.0002035899378824979)  > >, 80049: HitCollectionHit list:<Hit : npeak = 1 z = 186.03102111816406 XYpeak = -1000, -1000 E = 0.0012548287631943822 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012548287631943822
#                     xy = xy(x=27.272214889526367, y=132.2955780029297) 3dHit = Hit(27.272214889526367, 132.2955780029297, 186.03102111816406, E=0.0012548287631943822)  > >, 80050: HitCollectionHit list:<Hit : npeak = 1 z = 500.5394592285156 XYpeak = -1000, -1000 E = 0.0011561873834580183 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0011561873834580183
#                     xy = xy(x=258.3860168457031, y=311.5313720703125) 3dHit = Hit(258.3860168457031, 311.5313720703125, 500.5394592285156, E=0.0011561873834580183)  > >, 80051: HitCollectionHit list:<Hit : npeak = 1 z = 534.5411376953125 XYpeak = -1000, -1000 E = 0.002307446440681815 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002307446440681815
#                     xy = xy(x=-147.1407012939453, y=262.80426025390625) 3dHit = Hit(-147.1407012939453, 262.80426025390625, 534.5411376953125, E=0.002307446440681815)  > >, 80052: HitCollectionHit list:<Hit : npeak = 1 z = 539.6953735351562 XYpeak = -1000, -1000 E = 6.158104952191934e-06 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 6.158104952191934e-06
#                     xy = xy(x=-135.9098358154297, y=474.10833740234375) 3dHit = Hit(-135.9098358154297, 474.10833740234375, 539.6953735351562, E=6.158104952191934e-06)  > >, 80053: HitCollectionHit list:<Hit : npeak = 1 z = 227.447021484375 XYpeak = -1000, -1000 E = 0.00023242496536113322 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00023242496536113322
#                     xy = xy(x=299.6668701171875, y=339.3433837890625) 3dHit = Hit(299.6668701171875, 339.3433837890625, 227.447021484375, E=0.00023242496536113322)  > >, 80054: HitCollectionHit list:<Hit : npeak = 1 z = 326.06292724609375 XYpeak = -1000, -1000 E = 0.0005161683657206595 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005161683657206595
#                     xy = xy(x=-38.94899368286133, y=421.8635559082031) 3dHit = Hit(-38.94899368286133, 421.8635559082031, 326.06292724609375, E=0.0005161683657206595)  > >, 80055: HitCollectionHit list:<Hit : npeak = 1 z = 1095.7421875 XYpeak = -1000, -1000 E = 0.001968278316780925 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001968278316780925
#                     xy = xy(x=-163.29153442382812, y=-337.9321594238281) 3dHit = Hit(-163.29153442382812, -337.9321594238281, 1095.7421875, E=0.001968278316780925)  > >, 80056: HitCollectionHit list:<Hit : npeak = 1 z = 904.3860473632812 XYpeak = -1000, -1000 E = 0.00033725492539815605 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00033725492539815605
#                     xy = xy(x=346.43536376953125, y=-73.28404998779297) 3dHit = Hit(346.43536376953125, -73.28404998779297, 904.3860473632812, E=0.00033725492539815605)  > >, 80057: HitCollectionHit list:<Hit : npeak = 1 z = 633.78369140625 XYpeak = -1000, -1000 E = 0.000931386137381196 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.000931386137381196
#                     xy = xy(x=-132.7699432373047, y=-234.99176025390625) 3dHit = Hit(-132.7699432373047, -234.99176025390625, 633.78369140625, E=0.000931386137381196)  > >, 80058: HitCollectionHit list:<Hit : npeak = 1 z = 275.3172912597656 XYpeak = -1000, -1000 E = 0.0006953699630685151 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006953699630685151
#                     xy = xy(x=327.2029113769531, y=-168.86077880859375) 3dHit = Hit(327.2029113769531, -168.86077880859375, 275.3172912597656, E=0.0006953699630685151)  > >, 80059: HitCollectionHit list:<Hit : npeak = 1 z = 612.7796020507812 XYpeak = -1000, -1000 E = 0.00010948537237709388 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00010948537237709388
#                     xy = xy(x=466.0641174316406, y=-72.6806869506836) 3dHit = Hit(466.0641174316406, -72.6806869506836, 612.7796020507812, E=0.00010948537237709388)  > >, 80060: HitCollectionHit list:<Hit : npeak = 1 z = 1218.6376953125 XYpeak = -1000, -1000 E = 0.0006938032456673682 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006938032456673682
#                     xy = xy(x=38.49989700317383, y=-259.3372497558594) 3dHit = Hit(38.49989700317383, -259.3372497558594, 1218.6376953125, E=0.0006938032456673682)  > >, 80061: HitCollectionHit list:<Hit : npeak = 1 z = 480.83795166015625 XYpeak = -1000, -1000 E = 0.0012312585022300482 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012312585022300482
#                     xy = xy(x=258.9339599609375, y=110.43987274169922) 3dHit = Hit(258.9339599609375, 110.43987274169922, 480.83795166015625, E=0.0012312585022300482)  > >, 80062: HitCollectionHit list:<Hit : npeak = 1 z = 542.3695068359375 XYpeak = -1000, -1000 E = 0.003249388188123703 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.003249388188123703
#                     xy = xy(x=23.335573196411133, y=105.94161987304688) 3dHit = Hit(23.335573196411133, 105.94161987304688, 542.3695068359375, E=0.003249388188123703)  > >, 80063: HitCollectionHit list:<Hit : npeak = 1 z = 365.16021728515625 XYpeak = -1000, -1000 E = 0.000671446556225419 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.000671446556225419
#                     xy = xy(x=385.8395080566406, y=-302.13311767578125) 3dHit = Hit(385.8395080566406, -302.13311767578125, 365.16021728515625, E=0.000671446556225419)  > >, 80064: HitCollectionHit list:<Hit : npeak = 1 z = 674.1915893554688 XYpeak = -1000, -1000 E = 0.0006701163947582245 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006701163947582245
#                     xy = xy(x=229.46717834472656, y=21.218530654907227) 3dHit = Hit(229.46717834472656, 21.218530654907227, 674.1915893554688, E=0.0006701163947582245)  > >, 80065: HitCollectionHit list:<Hit : npeak = 1 z = 855.046875 XYpeak = -1000, -1000 E = 0.0011177610140293837 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0011177610140293837
#                     xy = xy(x=-434.6161804199219, y=-195.73031616210938) 3dHit = Hit(-434.6161804199219, -195.73031616210938, 855.046875, E=0.0011177610140293837)  > >, 80066: HitCollectionHit list:<Hit : npeak = 1 z = 666.3807373046875 XYpeak = -1000, -1000 E = 0.0008184764301404357 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008184764301404357
#                     xy = xy(x=293.9645690917969, y=301.22857666015625) 3dHit = Hit(293.9645690917969, 301.22857666015625, 666.3807373046875, E=0.0008184764301404357)  > >, 80067: HitCollectionHit list:<Hit : npeak = 1 z = 268.5943908691406 XYpeak = -1000, -1000 E = 0.005226350389420986 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.005226350389420986
#                     xy = xy(x=25.399003982543945, y=-277.408203125) 3dHit = Hit(25.399003982543945, -277.408203125, 268.5943908691406, E=0.005226350389420986)  > >, 80068: HitCollectionHit list:<Hit : npeak = 1 z = 11.851923942565918 XYpeak = -1000, -1000 E = 0.0007970142178237438 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007970142178237438
#                     xy = xy(x=196.6151580810547, y=159.34921264648438) 3dHit = Hit(196.6151580810547, 159.34921264648438, 11.851923942565918, E=0.0007970142178237438)  > >, 80069: HitCollectionHit list:<Hit : npeak = 1 z = 1163.0089111328125 XYpeak = -1000, -1000 E = 0.003487922949716449 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.003487922949716449
#                     xy = xy(x=-38.895225524902344, y=174.17965698242188) 3dHit = Hit(-38.895225524902344, 174.17965698242188, 1163.0089111328125, E=0.003487922949716449)  > >, 80070: HitCollectionHit list:<Hit : npeak = 1 z = 488.8609313964844 XYpeak = -1000, -1000 E = 0.0007409325917251408 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007409325917251408
#                     xy = xy(x=319.9148254394531, y=159.9841766357422) 3dHit = Hit(319.9148254394531, 159.9841766357422, 488.8609313964844, E=0.0007409325917251408)  > >, 80071: HitCollectionHit list:<Hit : npeak = 1 z = 609.3321533203125 XYpeak = -1000, -1000 E = 0.0018199330661445856 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0018199330661445856
#                     xy = xy(x=308.6246643066406, y=92.16436767578125) 3dHit = Hit(308.6246643066406, 92.16436767578125, 609.3321533203125, E=0.0018199330661445856)  > >, 80072: HitCollectionHit list:<Hit : npeak = 1 z = 485.0523376464844 XYpeak = -1000, -1000 E = 0.00042318334453739226 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00042318334453739226
#                     xy = xy(x=-228.12474060058594, y=-225.48143005371094) 3dHit = Hit(-228.12474060058594, -225.48143005371094, 485.0523376464844, E=0.00042318334453739226)  > >, 80073: HitCollectionHit list:<Hit : npeak = 1 z = 549.386962890625 XYpeak = -1000, -1000 E = 0.0010589631274342537 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010589631274342537
#                     xy = xy(x=222.9591522216797, y=364.843994140625) 3dHit = Hit(222.9591522216797, 364.843994140625, 549.386962890625, E=0.0010589631274342537)  > >, 80074: HitCollectionHit list:<Hit : npeak = 1 z = 1389.105224609375 XYpeak = -1000, -1000 E = 0.0009364744764752686 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009364744764752686
#                     xy = xy(x=381.3819580078125, y=-288.99859619140625) 3dHit = Hit(381.3819580078125, -288.99859619140625, 1389.105224609375, E=0.0009364744764752686)  > >, 80075: HitCollectionHit list:<Hit : npeak = 1 z = 205.50941467285156 XYpeak = -1000, -1000 E = 0.003420555032789707 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.003420555032789707
#                     xy = xy(x=400.195068359375, y=140.08944702148438) 3dHit = Hit(400.195068359375, 140.08944702148438, 205.50941467285156, E=0.003420555032789707)  > >, 80076: HitCollectionHit list:<Hit : npeak = 1 z = 1092.8778076171875 XYpeak = -1000, -1000 E = 0.0014497407246381044 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0014497407246381044
#                     xy = xy(x=422.1073303222656, y=-113.61495971679688) 3dHit = Hit(422.1073303222656, -113.61495971679688, 1092.8778076171875, E=0.0014497407246381044)  > >, 80077: HitCollectionHit list:<Hit : npeak = 1 z = 1015.80810546875 XYpeak = -1000, -1000 E = 0.0009263602551072836 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009263602551072836
#                     xy = xy(x=58.52580261230469, y=-320.10577392578125) 3dHit = Hit(58.52580261230469, -320.10577392578125, 1015.80810546875, E=0.0009263602551072836)  > >, 80078: HitCollectionHit list:<Hit : npeak = 1 z = 279.09259033203125 XYpeak = -1000, -1000 E = 0.0015356967924162745 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0015356967924162745
#                     xy = xy(x=-282.9909973144531, y=-372.13763427734375) 3dHit = Hit(-282.9909973144531, -372.13763427734375, 279.09259033203125, E=0.0015356967924162745)  > >, 80079: HitCollectionHit list:<Hit : npeak = 1 z = 343.1829528808594 XYpeak = -1000, -1000 E = 0.0006196529720909894 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006196529720909894
#                     xy = xy(x=346.8726806640625, y=-115.71011352539062) 3dHit = Hit(346.8726806640625, -115.71011352539062, 343.1829528808594, E=0.0006196529720909894)  > >, 80080: HitCollectionHit list:<Hit : npeak = 1 z = 696.2186889648438 XYpeak = -1000, -1000 E = 0.0006479481817223132 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006479481817223132
#                     xy = xy(x=-156.68539428710938, y=-78.9953384399414) 3dHit = Hit(-156.68539428710938, -78.9953384399414, 696.2186889648438, E=0.0006479481817223132)  > >, 80081: HitCollectionHit list:<Hit : npeak = 1 z = 561.696044921875 XYpeak = -1000, -1000 E = 0.0012704068794846535 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012704068794846535
#                     xy = xy(x=-84.85928344726562, y=270.03973388671875) 3dHit = Hit(-84.85928344726562, 270.03973388671875, 561.696044921875, E=0.0012704068794846535)  > >, 80082: HitCollectionHit list:<Hit : npeak = 1 z = 457.7365417480469 XYpeak = -1000, -1000 E = 0.0008291935082525015 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008291935082525015
#                     xy = xy(x=-205.9697723388672, y=-69.10953521728516) 3dHit = Hit(-205.9697723388672, -69.10953521728516, 457.7365417480469, E=0.0008291935082525015)  > >, 80083: HitCollectionHit list:<Hit : npeak = 1 z = 610.1531982421875 XYpeak = -1000, -1000 E = 0.0007091190782375634 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007091190782375634
#                     xy = xy(x=154.13377380371094, y=274.96307373046875) 3dHit = Hit(154.13377380371094, 274.96307373046875, 610.1531982421875, E=0.0007091190782375634)  > >, 80084: HitCollectionHit list:<Hit : npeak = 1 z = 549.3387451171875 XYpeak = -1000, -1000 E = 0.0019940936472266912 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0019940936472266912
#                     xy = xy(x=331.5979309082031, y=330.71942138671875) 3dHit = Hit(331.5979309082031, 330.71942138671875, 549.3387451171875, E=0.0019940936472266912)  > >, 80085: HitCollectionHit list:<Hit : npeak = 1 z = 226.72122192382812 XYpeak = -1000, -1000 E = 0.0014043697156012058 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0014043697156012058
#                     xy = xy(x=137.39804077148438, y=228.77012634277344) 3dHit = Hit(137.39804077148438, 228.77012634277344, 226.72122192382812, E=0.0014043697156012058)  > >, 80086: HitCollectionHit list:<Hit : npeak = 1 z = 518.5928955078125 XYpeak = -1000, -1000 E = 0.0009668450802564621 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009668450802564621
#                     xy = xy(x=-68.85227966308594, y=-375.6640930175781) 3dHit = Hit(-68.85227966308594, -375.6640930175781, 518.5928955078125, E=0.0009668450802564621)  > >, 80087: HitCollectionHit list:<Hit : npeak = 1 z = 58.52595520019531 XYpeak = -1000, -1000 E = 0.0016302039148285985 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016302039148285985
#                     xy = xy(x=-192.63580322265625, y=61.311431884765625) 3dHit = Hit(-192.63580322265625, 61.311431884765625, 58.52595520019531, E=0.0016302039148285985)  > >, 80088: HitCollectionHit list:<Hit : npeak = 1 z = 512.0806884765625 XYpeak = -1000, -1000 E = 0.0016730321804061532 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016730321804061532
#                     xy = xy(x=307.5741271972656, y=278.8254089355469) 3dHit = Hit(307.5741271972656, 278.8254089355469, 512.0806884765625, E=0.0016730321804061532)  > >, 80089: HitCollectionHit list:<Hit : npeak = 1 z = 815.5628051757812 XYpeak = -1000, -1000 E = 0.007651930209249258 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.007651930209249258
#                     xy = xy(x=130.1092987060547, y=470.2269287109375) 3dHit = Hit(130.1092987060547, 470.2269287109375, 815.5628051757812, E=0.007651930209249258)  > >, 80090: HitCollectionHit list:<Hit : npeak = 1 z = 731.702392578125 XYpeak = -1000, -1000 E = 0.0012815614463761449 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012815614463761449
#                     xy = xy(x=442.3547058105469, y=-131.13833618164062) 3dHit = Hit(442.3547058105469, -131.13833618164062, 731.702392578125, E=0.0012815614463761449)  > >, 80091: HitCollectionHit list:<Hit : npeak = 1 z = 904.4320678710938 XYpeak = -1000, -1000 E = 0.0016152015887200832 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016152015887200832
#                     xy = xy(x=-291.7117919921875, y=-149.6481170654297) 3dHit = Hit(-291.7117919921875, -149.6481170654297, 904.4320678710938, E=0.0016152015887200832)  > >, 80092: HitCollectionHit list:<Hit : npeak = 1 z = 305.3426513671875 XYpeak = -1000, -1000 E = 0.0018214973388239741 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0018214973388239741
#                     xy = xy(x=333.14447021484375, y=2.2107160091400146) 3dHit = Hit(333.14447021484375, 2.2107160091400146, 305.3426513671875, E=0.0018214973388239741)  > >, 80093: HitCollectionHit list:<Hit : npeak = 1 z = 327.619873046875 XYpeak = -1000, -1000 E = 6.888444477226585e-05 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 6.888444477226585e-05
#                     xy = xy(x=488.261474609375, y=64.24662017822266) 3dHit = Hit(488.261474609375, 64.24662017822266, 327.619873046875, E=6.888444477226585e-05)  > >, 80094: HitCollectionHit list:<Hit : npeak = 1 z = 418.77288818359375 XYpeak = -1000, -1000 E = 0.0005753508303314447 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005753508303314447
#                     xy = xy(x=-17.332050323486328, y=344.3459777832031) 3dHit = Hit(-17.332050323486328, 344.3459777832031, 418.77288818359375, E=0.0005753508303314447)  > >, 80095: HitCollectionHit list:<Hit : npeak = 1 z = 958.134033203125 XYpeak = -1000, -1000 E = 0.002720253774896264 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002720253774896264
#                     xy = xy(x=184.87403869628906, y=-127.4963150024414) 3dHit = Hit(184.87403869628906, -127.4963150024414, 958.134033203125, E=0.002720253774896264)  > >, 80096: HitCollectionHit list:<Hit : npeak = 1 z = 1083.473388671875 XYpeak = -1000, -1000 E = 0.002002117456868291 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002002117456868291
#                     xy = xy(x=-335.8233642578125, y=136.30426025390625) 3dHit = Hit(-335.8233642578125, 136.30426025390625, 1083.473388671875, E=0.002002117456868291)  > >, 80097: HitCollectionHit list:<Hit : npeak = 1 z = 841.6276245117188 XYpeak = -1000, -1000 E = 0.0015585492365062237 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0015585492365062237
#                     xy = xy(x=-45.69289016723633, y=356.9809875488281) 3dHit = Hit(-45.69289016723633, 356.9809875488281, 841.6276245117188, E=0.0015585492365062237)  > >, 80098: HitCollectionHit list:<Hit : npeak = 1 z = 404.9183654785156 XYpeak = -1000, -1000 E = 0.0012306435965001583 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012306435965001583
#                     xy = xy(x=283.7764587402344, y=228.7216796875) 3dHit = Hit(283.7764587402344, 228.7216796875, 404.9183654785156, E=0.0012306435965001583)  > >, 80099: HitCollectionHit list:<Hit : npeak = 1 z = 1037.5928955078125 XYpeak = -1000, -1000 E = 0.0006734189810231328 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006734189810231328
#                     xy = xy(x=254.69554138183594, y=-58.71768569946289) 3dHit = Hit(254.69554138183594, -58.71768569946289, 1037.5928955078125, E=0.0006734189810231328)  > >, 80100: HitCollectionHit list:<Hit : npeak = 1 z = 401.36468505859375 XYpeak = -1000, -1000 E = 0.003182209562510252 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.003182209562510252
#                     xy = xy(x=408.54949951171875, y=55.182804107666016) 3dHit = Hit(408.54949951171875, 55.182804107666016, 401.36468505859375, E=0.003182209562510252)  > >, 80101: HitCollectionHit list:<Hit : npeak = 1 z = 1026.29931640625 XYpeak = -1000, -1000 E = 0.00011567610636120662 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00011567610636120662
#                     xy = xy(x=-350.56011962890625, y=-282.6531066894531) 3dHit = Hit(-350.56011962890625, -282.6531066894531, 1026.29931640625, E=0.00011567610636120662)  > >, 80102: HitCollectionHit list:<Hit : npeak = 1 z = 263.1175842285156 XYpeak = -1000, -1000 E = 0.001103264163248241 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001103264163248241
#                     xy = xy(x=-1.9255532026290894, y=80.126953125) 3dHit = Hit(-1.9255532026290894, 80.126953125, 263.1175842285156, E=0.001103264163248241)  > >, 80103: HitCollectionHit list:<Hit : npeak = 1 z = 825.3825073242188 XYpeak = -1000, -1000 E = 0.0009761034743860364 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009761034743860364
#                     xy = xy(x=62.22230529785156, y=418.91522216796875) 3dHit = Hit(62.22230529785156, 418.91522216796875, 825.3825073242188, E=0.0009761034743860364)  > >, 80104: HitCollectionHit list:<Hit : npeak = 1 z = 553.3629150390625 XYpeak = -1000, -1000 E = 0.0009042127639986575 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009042127639986575
#                     xy = xy(x=224.88262939453125, y=377.1371765136719) 3dHit = Hit(224.88262939453125, 377.1371765136719, 553.3629150390625, E=0.0009042127639986575)  > >, 80105: HitCollectionHit list:<Hit : npeak = 1 z = 576.533203125 XYpeak = -1000, -1000 E = 0.0016509226989001036 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016509226989001036
#                     xy = xy(x=257.00189208984375, y=377.4100646972656) 3dHit = Hit(257.00189208984375, 377.4100646972656, 576.533203125, E=0.0016509226989001036)  > >, 80106: HitCollectionHit list:<Hit : npeak = 1 z = 1388.3323974609375 XYpeak = -1000, -1000 E = 0.001312826294451952 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001312826294451952
#                     xy = xy(x=-81.37979125976562, y=193.76705932617188) 3dHit = Hit(-81.37979125976562, 193.76705932617188, 1388.3323974609375, E=0.001312826294451952)  > >, 80107: HitCollectionHit list:<Hit : npeak = 1 z = 530.7509155273438 XYpeak = -1000, -1000 E = 0.000585684145335108 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.000585684145335108
#                     xy = xy(x=198.99720764160156, y=311.0563049316406) 3dHit = Hit(198.99720764160156, 311.0563049316406, 530.7509155273438, E=0.000585684145335108)  > >, 80108: HitCollectionHit list:<Hit : npeak = 1 z = 273.2335205078125 XYpeak = -1000, -1000 E = 0.0017863555112853646 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0017863555112853646
#                     xy = xy(x=173.02346801757812, y=49.67045593261719) 3dHit = Hit(173.02346801757812, 49.67045593261719, 273.2335205078125, E=0.0017863555112853646)  > >, 80109: HitCollectionHit list:<Hit : npeak = 1 z = 640.7262573242188 XYpeak = -1000, -1000 E = 3.4017681173281744e-05 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 3.4017681173281744e-05
#                     xy = xy(x=-287.91448974609375, y=400.67144775390625) 3dHit = Hit(-287.91448974609375, 400.67144775390625, 640.7262573242188, E=3.4017681173281744e-05)  > >, 80110: HitCollectionHit list:<Hit : npeak = 1 z = 738.4711303710938 XYpeak = -1000, -1000 E = 0.0016958994092419744 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016958994092419744
#                     xy = xy(x=131.35389709472656, y=-234.816650390625) 3dHit = Hit(131.35389709472656, -234.816650390625, 738.4711303710938, E=0.0016958994092419744)  > >, 80111: HitCollectionHit list:<Hit : npeak = 1 z = 350.1708984375 XYpeak = -1000, -1000 E = 0.001021778560243547 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001021778560243547
#                     xy = xy(x=197.0266876220703, y=-89.27860260009766) 3dHit = Hit(197.0266876220703, -89.27860260009766, 350.1708984375, E=0.001021778560243547)  > >, 80112: HitCollectionHit list:<Hit : npeak = 1 z = 1232.4632568359375 XYpeak = -1000, -1000 E = 0.002134517999365926 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.002134517999365926
#                     xy = xy(x=-160.8170623779297, y=-204.98118591308594) 3dHit = Hit(-160.8170623779297, -204.98118591308594, 1232.4632568359375, E=0.002134517999365926)  > >, 80113: HitCollectionHit list:<Hit : npeak = 1 z = 404.1539306640625 XYpeak = -1000, -1000 E = 0.0007538219797424972 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007538219797424972
#                     xy = xy(x=-27.3508243560791, y=-233.30625915527344) 3dHit = Hit(-27.3508243560791, -233.30625915527344, 404.1539306640625, E=0.0007538219797424972)  > >, 80114: HitCollectionHit list:<Hit : npeak = 1 z = 602.86328125 XYpeak = -1000, -1000 E = 0.0017330783884972334 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0017330783884972334
#                     xy = xy(x=406.6856994628906, y=137.37530517578125) 3dHit = Hit(406.6856994628906, 137.37530517578125, 602.86328125, E=0.0017330783884972334)  > >, 80115: HitCollectionHit list:<Hit : npeak = 1 z = 1137.194580078125 XYpeak = -1000, -1000 E = 0.0010611913166940212 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010611913166940212
#                     xy = xy(x=359.7301330566406, y=22.46514129638672) 3dHit = Hit(359.7301330566406, 22.46514129638672, 1137.194580078125, E=0.0010611913166940212)  > >, 80116: HitCollectionHit list:<Hit : npeak = 1 z = 1077.644775390625 XYpeak = -1000, -1000 E = 0.0006529933889396489 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006529933889396489
#                     xy = xy(x=48.108909606933594, y=412.3290710449219) 3dHit = Hit(48.108909606933594, 412.3290710449219, 1077.644775390625, E=0.0006529933889396489)  > >, 80117: HitCollectionHit list:<Hit : npeak = 1 z = 447.99761962890625 XYpeak = -1000, -1000 E = 0.0009431216749362648 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009431216749362648
#                     xy = xy(x=-362.2290344238281, y=-255.2617950439453) 3dHit = Hit(-362.2290344238281, -255.2617950439453, 447.99761962890625, E=0.0009431216749362648)  > >, 80118: HitCollectionHit list:<Hit : npeak = 1 z = 1179.4451904296875 XYpeak = -1000, -1000 E = 0.0012086299248039722 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012086299248039722
#                     xy = xy(x=-162.0473175048828, y=-15.691755294799805) 3dHit = Hit(-162.0473175048828, -15.691755294799805, 1179.4451904296875, E=0.0012086299248039722)  > >, 80119: HitCollectionHit list:<Hit : npeak = 1 z = 831.3094482421875 XYpeak = -1000, -1000 E = 0.00023821080685593188 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00023821080685593188
#                     xy = xy(x=-78.30455017089844, y=108.07051086425781) 3dHit = Hit(-78.30455017089844, 108.07051086425781, 831.3094482421875, E=0.00023821080685593188)  > >, 80120: HitCollectionHit list:<Hit : npeak = 1 z = 612.04345703125 XYpeak = -1000, -1000 E = 0.0002006824652198702 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0002006824652198702
#                     xy = xy(x=243.423583984375, y=421.1973571777344) 3dHit = Hit(243.423583984375, 421.1973571777344, 612.04345703125, E=0.0002006824652198702)  > >, 80121: HitCollectionHit list:<Hit : npeak = 1 z = 294.4812927246094 XYpeak = -1000, -1000 E = 0.0012044963659718633 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012044963659718633
#                     xy = xy(x=-365.642333984375, y=-306.91961669921875) 3dHit = Hit(-365.642333984375, -306.91961669921875, 294.4812927246094, E=0.0012044963659718633)  > >, 80122: HitCollectionHit list:<Hit : npeak = 1 z = 1043.1207275390625 XYpeak = -1000, -1000 E = 0.0010822160402312875 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010822160402312875
#                     xy = xy(x=-88.59552764892578, y=295.3126220703125) 3dHit = Hit(-88.59552764892578, 295.3126220703125, 1043.1207275390625, E=0.0010822160402312875)  > >, 80123: HitCollectionHit list:<Hit : npeak = 1 z = 145.31065368652344 XYpeak = -1000, -1000 E = 0.0009559227037243545 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009559227037243545
#                     xy = xy(x=189.4805908203125, y=111.87651062011719) 3dHit = Hit(189.4805908203125, 111.87651062011719, 145.31065368652344, E=0.0009559227037243545)  > >, 80125: HitCollectionHit list:<Hit : npeak = 1 z = 389.56817626953125 XYpeak = -1000, -1000 E = 0.0009563338244333863 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009563338244333863
#                     xy = xy(x=-216.58905029296875, y=61.050594329833984) 3dHit = Hit(-216.58905029296875, 61.050594329833984, 389.56817626953125, E=0.0009563338244333863)  > >, 80126: HitCollectionHit list:<Hit : npeak = 1 z = 336.7099914550781 XYpeak = -1000, -1000 E = 0.0006611057906411588 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006611057906411588
#                     xy = xy(x=148.80860900878906, y=173.7938690185547) 3dHit = Hit(148.80860900878906, 173.7938690185547, 336.7099914550781, E=0.0006611057906411588)  > >, 80127: HitCollectionHit list:<Hit : npeak = 1 z = 659.48388671875 XYpeak = -1000, -1000 E = 0.005633040796965361 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.005633040796965361
#                     xy = xy(x=208.39183044433594, y=292.1662292480469) 3dHit = Hit(208.39183044433594, 292.1662292480469, 659.48388671875, E=0.005633040796965361)  > >, 80128: HitCollectionHit list:<Hit : npeak = 1 z = 650.4996948242188 XYpeak = -1000, -1000 E = 0.0013129222206771374 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0013129222206771374
#                     xy = xy(x=262.42547607421875, y=-337.9231262207031) 3dHit = Hit(262.42547607421875, -337.9231262207031, 650.4996948242188, E=0.0013129222206771374)  > >, 80129: HitCollectionHit list:<Hit : npeak = 1 z = 627.7567138671875 XYpeak = -1000, -1000 E = 0.0008723108912818134 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008723108912818134
#                     xy = xy(x=335.6842346191406, y=172.9364471435547) 3dHit = Hit(335.6842346191406, 172.9364471435547, 627.7567138671875, E=0.0008723108912818134)  > >, 80130: HitCollectionHit list:<Hit : npeak = 1 z = 824.0909423828125 XYpeak = -1000, -1000 E = 0.0012062116293236613 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012062116293236613
#                     xy = xy(x=-394.79620361328125, y=106.75977325439453) 3dHit = Hit(-394.79620361328125, 106.75977325439453, 824.0909423828125, E=0.0012062116293236613)  > >, 80132: HitCollectionHit list:<Hit : npeak = 1 z = 286.4852294921875 XYpeak = -1000, -1000 E = 0.0006169810076244175 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0006169810076244175
#                     xy = xy(x=-273.9991760253906, y=-84.80034637451172) 3dHit = Hit(-273.9991760253906, -84.80034637451172, 286.4852294921875, E=0.0006169810076244175)  > >, 80133: HitCollectionHit list:<Hit : npeak = 1 z = 768.258056640625 XYpeak = -1000, -1000 E = 0.0013527777045965195 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0013527777045965195
# ...
#                     xy = xy(x=-247.86767578125, y=-197.29307556152344) 3dHit = Hit(-247.86767578125, -197.29307556152344, 1213.8477783203125, E=0.00104467140045017)  > >, 80291: HitCollectionHit list:<Hit : npeak = 1 z = 161.17843627929688 XYpeak = -1000, -1000 E = 0.0011690945830196142 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0011690945830196142
#                     xy = xy(x=-322.4084777832031, y=-22.73531150817871) 3dHit = Hit(-322.4084777832031, -22.73531150817871, 161.17843627929688, E=0.0011690945830196142)  > >, 80292: HitCollectionHit list:<Hit : npeak = 1 z = 17.144207000732422 XYpeak = -1000, -1000 E = 0.0009833842050284147 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009833842050284147
#                     xy = xy(x=-14.159512519836426, y=18.22245216369629) 3dHit = Hit(-14.159512519836426, 18.22245216369629, 17.144207000732422, E=0.0009833842050284147)  > >, 80293: HitCollectionHit list:<Hit : npeak = 1 z = 550.7764282226562 XYpeak = -1000, -1000 E = 6.574275175807998e-05 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 6.574275175807998e-05
#                     xy = xy(x=312.408935546875, y=380.1181640625) 3dHit = Hit(312.408935546875, 380.1181640625, 550.7764282226562, E=6.574275175807998e-05)  > >, 80294: HitCollectionHit list:<Hit : npeak = 1 z = 671.3999633789062 XYpeak = -1000, -1000 E = 0.0009106943034566939 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009106943034566939
#                     xy = xy(x=-26.882720947265625, y=1.464845061302185) 3dHit = Hit(-26.882720947265625, 1.464845061302185, 671.3999633789062, E=0.0009106943034566939)  > >, 80295: HitCollectionHit list:<Hit : npeak = 1 z = 623.84912109375 XYpeak = -1000, -1000 E = 0.00045251662959344685 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00045251662959344685
#                     xy = xy(x=123.4149169921875, y=405.66357421875) 3dHit = Hit(123.4149169921875, 405.66357421875, 623.84912109375, E=0.00045251662959344685)  > >, 80296: HitCollectionHit list:<Hit : npeak = 1 z = 671.4107666015625 XYpeak = -1000, -1000 E = 0.0012555605499073863 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012555605499073863
#                     xy = xy(x=279.2749938964844, y=388.68914794921875) 3dHit = Hit(279.2749938964844, 388.68914794921875, 671.4107666015625, E=0.0012555605499073863)  > >, 80297: HitCollectionHit list:<Hit : npeak = 1 z = 1228.52734375 XYpeak = -1000, -1000 E = 0.0013144643744453788 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0013144643744453788
#                     xy = xy(x=-292.31103515625, y=-137.2310791015625) 3dHit = Hit(-292.31103515625, -137.2310791015625, 1228.52734375, E=0.0013144643744453788)  > >, 80298: HitCollectionHit list:<Hit : npeak = 1 z = 308.90972900390625 XYpeak = -1000, -1000 E = 0.0009481494198553264 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0009481494198553264
#                     xy = xy(x=312.7594909667969, y=263.3196105957031) 3dHit = Hit(312.7594909667969, 263.3196105957031, 308.90972900390625, E=0.0009481494198553264)  > >, 80299: HitCollectionHit list:<Hit : npeak = 1 z = 1010.9385986328125 XYpeak = -1000, -1000 E = 0.0007234924705699086 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007234924705699086
#                     xy = xy(x=317.2691345214844, y=-303.1914367675781) 3dHit = Hit(317.2691345214844, -303.1914367675781, 1010.9385986328125, E=0.0007234924705699086)  > >, 80300: HitCollectionHit list:<Hit : npeak = 1 z = 603.95068359375 XYpeak = -1000, -1000 E = 0.0013944131787866354 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0013944131787866354
#                     xy = xy(x=-34.78862380981445, y=331.6285705566406) 3dHit = Hit(-34.78862380981445, 331.6285705566406, 603.95068359375, E=0.0013944131787866354)  > >, 80301: HitCollectionHit list:<Hit : npeak = 1 z = 45.80574035644531 XYpeak = -1000, -1000 E = 0.004332223441451788 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.004332223441451788
#                     xy = xy(x=-168.09132385253906, y=-437.9220275878906) 3dHit = Hit(-168.09132385253906, -437.9220275878906, 45.80574035644531, E=0.004332223441451788)  > >, 80305: HitCollectionHit list:<Hit : npeak = 1 z = 535.8244018554688 XYpeak = -1000, -1000 E = 0.0010022741043940187 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010022741043940187
#                     xy = xy(x=271.6656188964844, y=226.05398559570312) 3dHit = Hit(271.6656188964844, 226.05398559570312, 535.8244018554688, E=0.0010022741043940187)  > >, 80306: HitCollectionHit list:<Hit : npeak = 1 z = 537.5262451171875 XYpeak = -1000, -1000 E = 0.0008178360294550657 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008178360294550657
#                     xy = xy(x=184.94671630859375, y=263.1856994628906) 3dHit = Hit(184.94671630859375, 263.1856994628906, 537.5262451171875, E=0.0008178360294550657)  > >, 80307: HitCollectionHit list:<Hit : npeak = 1 z = 590.0335693359375 XYpeak = -1000, -1000 E = 0.001100159832276404 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001100159832276404
#                     xy = xy(x=-139.03028869628906, y=-361.19384765625) 3dHit = Hit(-139.03028869628906, -361.19384765625, 590.0335693359375, E=0.001100159832276404)  > >, 80308: HitCollectionHit list:<Hit : npeak = 1 z = 817.5499877929688 XYpeak = -1000, -1000 E = 0.0014685025671496987 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0014685025671496987
#                     xy = xy(x=-149.10659790039062, y=119.70957946777344) 3dHit = Hit(-149.10659790039062, 119.70957946777344, 817.5499877929688, E=0.0014685025671496987)  > >, 80310: HitCollectionHit list:<Hit : npeak = 1 z = 599.8084716796875 XYpeak = -1000, -1000 E = 0.00512199942022562 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00512199942022562
#                     xy = xy(x=332.75347900390625, y=344.5956726074219) 3dHit = Hit(332.75347900390625, 344.5956726074219, 599.8084716796875, E=0.00512199942022562)  > >, 80311: HitCollectionHit list:<Hit : npeak = 1 z = 898.0568237304688 XYpeak = -1000, -1000 E = 0.0007955791079439223 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0007955791079439223
#                     xy = xy(x=71.41000366210938, y=-301.3027038574219) 3dHit = Hit(71.41000366210938, -301.3027038574219, 898.0568237304688, E=0.0007955791079439223)  > >, 80312: HitCollectionHit list:<Hit : npeak = 1 z = 755.4627685546875 XYpeak = -1000, -1000 E = 0.0012240359792485833 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012240359792485833
#                     xy = xy(x=-116.94658660888672, y=-98.68614959716797) 3dHit = Hit(-116.94658660888672, -98.68614959716797, 755.4627685546875, E=0.0012240359792485833)  > >, 80313: HitCollectionHit list:<Hit : npeak = 1 z = 1104.39111328125 XYpeak = -1000, -1000 E = 0.0015243818052113056 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0015243818052113056
#                     xy = xy(x=216.9134979248047, y=82.70252227783203) 3dHit = Hit(216.9134979248047, 82.70252227783203, 1104.39111328125, E=0.0015243818052113056)  > >, 80314: HitCollectionHit list:<Hit : npeak = 1 z = 125.90070343017578 XYpeak = -1000, -1000 E = 0.0005532364011742175 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0005532364011742175
#                     xy = xy(x=108.38728332519531, y=478.4269714355469) 3dHit = Hit(108.38728332519531, 478.4269714355469, 125.90070343017578, E=0.0005532364011742175)  > >, 80315: HitCollectionHit list:<Hit : npeak = 1 z = 477.2120361328125 XYpeak = -1000, -1000 E = 0.0010214311769232154 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010214311769232154
#                     xy = xy(x=170.8221435546875, y=-135.53536987304688) 3dHit = Hit(170.8221435546875, -135.53536987304688, 477.2120361328125, E=0.0010214311769232154)  > >, 80316: HitCollectionHit list:<Hit : npeak = 1 z = 565.1923217773438 XYpeak = -1000, -1000 E = 0.001286119339056313 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001286119339056313
#                     xy = xy(x=255.1329345703125, y=369.1947937011719) 3dHit = Hit(255.1329345703125, 369.1947937011719, 565.1923217773438, E=0.001286119339056313)  > >, 80317: HitCollectionHit list:<Hit : npeak = 1 z = 801.8839721679688 XYpeak = -1000, -1000 E = 0.0001619257964193821 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0001619257964193821
#                     xy = xy(x=-52.96220016479492, y=233.24742126464844) 3dHit = Hit(-52.96220016479492, 233.24742126464844, 801.8839721679688, E=0.0001619257964193821)  > >, 80318: HitCollectionHit list:<Hit : npeak = 1 z = 941.6019287109375 XYpeak = -1000, -1000 E = 0.001670903991907835 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.001670903991907835
#                     xy = xy(x=290.4448547363281, y=-137.7747344970703) 3dHit = Hit(290.4448547363281, -137.7747344970703, 941.6019287109375, E=0.001670903991907835)  > >, 80320: HitCollectionHit list:<Hit : npeak = 1 z = 504.4548034667969 XYpeak = -1000, -1000 E = 0.00015561839973088354 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00015561839973088354
#                     xy = xy(x=300.0245666503906, y=235.33071899414062) 3dHit = Hit(300.0245666503906, 235.33071899414062, 504.4548034667969, E=0.00015561839973088354)  > >, 80321: HitCollectionHit list:<Hit : npeak = 1 z = 470.6303405761719 XYpeak = -1000, -1000 E = 0.0023723000194877386 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0023723000194877386
#                     xy = xy(x=53.190338134765625, y=195.41700744628906) 3dHit = Hit(53.190338134765625, 195.41700744628906, 470.6303405761719, E=0.0023723000194877386)  > >, 80322: HitCollectionHit list:<Hit : npeak = 1 z = 38.3126106262207 XYpeak = -1000, -1000 E = 0.0010488983243703842 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0010488983243703842
#                     xy = xy(x=149.3867645263672, y=-430.70733642578125) 3dHit = Hit(149.3867645263672, -430.70733642578125, 38.3126106262207, E=0.0010488983243703842)  > >, 80323: HitCollectionHit list:<Hit : npeak = 1 z = 360.0772705078125 XYpeak = -1000, -1000 E = 0.0016734023811295629 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016734023811295629
#                     xy = xy(x=245.43789672851562, y=308.41680908203125) 3dHit = Hit(245.43789672851562, 308.41680908203125, 360.0772705078125, E=0.0016734023811295629)  > >, 80324: HitCollectionHit list:<Hit : npeak = 1 z = 284.9734802246094 XYpeak = -1000, -1000 E = 7.572318281745538e-05 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 7.572318281745538e-05
#                     xy = xy(x=-257.39788818359375, y=426.2779235839844) 3dHit = Hit(-257.39788818359375, 426.2779235839844, 284.9734802246094, E=7.572318281745538e-05)  > >, 80325: HitCollectionHit list:<Hit : npeak = 1 z = 292.7604064941406 XYpeak = -1000, -1000 E = 0.00031933566788211465 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00031933566788211465
#                     xy = xy(x=-224.67825317382812, y=-32.22056198120117) 3dHit = Hit(-224.67825317382812, -32.22056198120117, 292.7604064941406, E=0.00031933566788211465)  > >, 80326: HitCollectionHit list:<Hit : npeak = 1 z = 150.17376708984375 XYpeak = -1000, -1000 E = 0.0011683403281494975 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0011683403281494975
#                     xy = xy(x=-284.3652038574219, y=92.75650024414062) 3dHit = Hit(-284.3652038574219, 92.75650024414062, 150.17376708984375, E=0.0011683403281494975)  > >, 80327: HitCollectionHit list:<Hit : npeak = 1 z = 427.27325439453125 XYpeak = -1000, -1000 E = 0.0019491092534735799 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0019491092534735799
#                     xy = xy(x=-218.1911163330078, y=314.56671142578125) 3dHit = Hit(-218.1911163330078, 314.56671142578125, 427.27325439453125, E=0.0019491092534735799)  > >, 80328: HitCollectionHit list:<Hit : npeak = 1 z = 210.20394897460938 XYpeak = -1000, -1000 E = 0.0008020628592930734 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0008020628592930734
#                     xy = xy(x=371.4369812011719, y=-242.4338836669922) 3dHit = Hit(371.4369812011719, -242.4338836669922, 210.20394897460938, E=0.0008020628592930734)  > >, 80329: HitCollectionHit list:<Hit : npeak = 1 z = 682.4751586914062 XYpeak = -1000, -1000 E = 0.00010015303996624425 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00010015303996624425
#                     xy = xy(x=123.9274673461914, y=262.1651306152344) 3dHit = Hit(123.9274673461914, 262.1651306152344, 682.4751586914062, E=0.00010015303996624425)  > >, 80330: HitCollectionHit list:<Hit : npeak = 1 z = 1016.87841796875 XYpeak = -1000, -1000 E = 0.0016013256972655654 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0016013256972655654
#                     xy = xy(x=-272.7997131347656, y=-194.31216430664062) 3dHit = Hit(-272.7997131347656, -194.31216430664062, 1016.87841796875, E=0.0016013256972655654)  > >, 80331: HitCollectionHit list:<Hit : npeak = 1 z = 400.3745422363281 XYpeak = -1000, -1000 E = 0.00013853685231879354 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00013853685231879354
#                     xy = xy(x=444.8283386230469, y=-191.8441925048828) 3dHit = Hit(444.8283386230469, -191.8441925048828, 400.3745422363281, E=0.00013853685231879354)  > >, 80332: HitCollectionHit list:<Hit : npeak = 1 z = 80.15667724609375 XYpeak = -1000, -1000 E = 0.00012845906894654036 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00012845906894654036
#                     xy = xy(x=121.55925750732422, y=310.3343811035156) 3dHit = Hit(121.55925750732422, 310.3343811035156, 80.15667724609375, E=0.00012845906894654036)  > >, 80333: HitCollectionHit list:<Hit : npeak = 1 z = 485.4039001464844 XYpeak = -1000, -1000 E = 0.0004958575591444969 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0004958575591444969
#                     xy = xy(x=425.7525329589844, y=-130.05726623535156) 3dHit = Hit(425.7525329589844, -130.05726623535156, 485.4039001464844, E=0.0004958575591444969)  > >, 80334: HitCollectionHit list:<Hit : npeak = 1 z = 291.3160095214844 XYpeak = -1000, -1000 E = 0.0003924228949472308 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0003924228949472308
#                     xy = xy(x=342.3094787597656, y=-338.4668884277344) 3dHit = Hit(342.3094787597656, -338.4668884277344, 291.3160095214844, E=0.0003924228949472308)  > >, 80335: HitCollectionHit list:<Hit : npeak = 1 z = 140.5194091796875 XYpeak = -1000, -1000 E = 0.0017057571094483137 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0017057571094483137
#                     xy = xy(x=381.8842468261719, y=-122.76245880126953) 3dHit = Hit(381.8842468261719, -122.76245880126953, 140.5194091796875, E=0.0017057571094483137)  > >, 80336: HitCollectionHit list:<Hit : npeak = 1 z = 1143.424072265625 XYpeak = -1000, -1000 E = 0.0002677433658391237 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0002677433658391237
#                     xy = xy(x=242.9799041748047, y=-116.52228546142578) 3dHit = Hit(242.9799041748047, -116.52228546142578, 1143.424072265625, E=0.0002677433658391237)  > >, 80337: HitCollectionHit list:<Hit : npeak = 1 z = 656.7350463867188 XYpeak = -1000, -1000 E = 0.0012607426615431905 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.0012607426615431905
#                     xy = xy(x=131.10498046875, y=195.69720458984375) 3dHit = Hit(131.10498046875, 195.69720458984375, 656.7350463867188, E=0.0012607426615431905)  > >, 80338: HitCollectionHit list:<Hit : npeak = 1 z = 513.6793212890625 XYpeak = -1000, -1000 E = 0.00033488168264739215 Ec = -1 Ep = -1 trackid = -1 cluster =< nsipm = -1 Q = 0.00033488168264739215
#                     xy = xy(x=353.08551025390625, y=198.25921630859375) 3dHit = Hit(353.08551025390625, 198.25921630859375, 513.6793212890625, E=0.00033488168264739215)  > >}

# %%
df_MC_one = df_MC[df_MC.event_id == df_MC.event_id.unique()[0]]
display(df_MC_one)


# stuff needed for paolina track counting
energy_threshold = 10
min_voxels = 3

base_vsize = 12 #mm
the_hits = []
# Out:
#      event_id  particle_id  hit_id           x          y           z  \
# 0       80000           20       0  457.466187 -42.362900  726.263000
# 1       80000           34       0  457.466156 -42.362850  726.263000
# 2       80000           33       0  457.466187 -42.362808  726.262817
# 3       80000           32       0  457.466278 -42.362698  726.263000
# 4       80000           31       0  457.466187 -42.362907  726.263000
# ..        ...          ...     ...         ...        ...         ...
# 247     80000           49      11  445.339355 -21.746880  784.309143
# 248     80000           49      12  445.342560 -21.754063  784.318542
# 249     80000           49      13  445.349548 -21.755783  784.321411
# 250     80000           49      14  445.351959 -21.754690  784.322266
# 251     80000           49      15  445.352448 -21.754904  784.321899
#
#          time    energy   label  npeak
# 0    1.617071  0.000234  ACTIVE      1
# 1    1.617098  0.000021  ACTIVE      1
# 2    1.617118  0.000046  ACTIVE      1
# 3    1.617127  0.000045  ACTIVE      1
# 4    1.617076  0.000021  ACTIVE      1
# ..        ...       ...     ...    ...
# 247  2.134957  0.000844  ACTIVE      1
# 248  2.135220  0.001738  ACTIVE      1
# 249  2.135416  0.002368  ACTIVE      1
# 250  2.135517  0.001516  ACTIVE      1
# 251  2.135561  0.000617  ACTIVE      1
#
# [252 rows x 10 columns]

# %%
display(df_MC)
display(df_MC[df_MC.label == 'ACTIVE'])
# Out:
#         event_id  particle_id  hit_id          x           y           z  \
# 0        1000000           23       0 -62.902893  312.907623  212.046997
# 1        1000000           34       0 -62.902672  312.907623  212.046997
# 2        1000000           33       0 -62.902832  312.907532  212.046951
# 3        1000000           32       0 -62.902912  312.907593  212.047012
# 4        1000000           31       0 -62.902870  312.907654  212.046997
# ...          ...          ...     ...        ...         ...         ...
# 123489   1000340           59       1 -78.538589 -206.739258  762.828735
# 123490   1000340           58       0 -78.538071 -206.738983  762.828674
# 123491   1000340           57       0 -78.539032 -206.739105  762.830566
# 123492   1000340           57       1 -78.540787 -206.739182  762.833557
# 123493   1000340           57       2 -78.540504 -206.739563  762.833618
#
#             time    energy   label
# 0       1.887960  0.000185  ACTIVE
# 1       1.888017  0.000044  ACTIVE
# 2       1.887995  0.000033  ACTIVE
# 3       1.887973  0.000021  ACTIVE
# 4       1.887967  0.000046  ACTIVE
# ...          ...       ...     ...
# 123489  3.137650  0.000382  ACTIVE
# 123490  3.137652  0.000101  ACTIVE
# 123491  3.137662  0.000094  ACTIVE
# 123492  3.137778  0.002058  ACTIVE
# 123493  3.137816  0.000454  ACTIVE
#
# [123494 rows x 9 columns]
#         event_id  particle_id  hit_id          x           y           z  \
# 0        1000000           23       0 -62.902893  312.907623  212.046997
# 1        1000000           34       0 -62.902672  312.907623  212.046997
# 2        1000000           33       0 -62.902832  312.907532  212.046951
# 3        1000000           32       0 -62.902912  312.907593  212.047012
# 4        1000000           31       0 -62.902870  312.907654  212.046997
# ...          ...          ...     ...        ...         ...         ...
# 123489   1000340           59       1 -78.538589 -206.739258  762.828735
# 123490   1000340           58       0 -78.538071 -206.738983  762.828674
# 123491   1000340           57       0 -78.539032 -206.739105  762.830566
# 123492   1000340           57       1 -78.540787 -206.739182  762.833557
# 123493   1000340           57       2 -78.540504 -206.739563  762.833618
#
#             time    energy   label
# 0       1.887960  0.000185  ACTIVE
# 1       1.888017  0.000044  ACTIVE
# 2       1.887995  0.000033  ACTIVE
# 3       1.887973  0.000021  ACTIVE
# 4       1.887967  0.000046  ACTIVE
# ...          ...       ...     ...
# 123489  3.137650  0.000382  ACTIVE
# 123490  3.137652  0.000101  ACTIVE
# 123491  3.137662  0.000094  ACTIVE
# 123492  3.137778  0.002058  ACTIVE
# 123493  3.137816  0.000454  ACTIVE
#
# [122712 rows x 9 columns]

# %%
xs = df_MC_one.x
ys = df_MC_one.y
zs = df_MC_one.z
es = df_MC_one.energy
print("Sanity check, how much energy before:")
print(np.sum(es))

the_hits = []

for x, y, z, e in zip(xs, ys, zs, es):
    if np.isnan(e): continue
    h = Hit(0, Cluster(0, xy(x,y), xy(0,0), 0), z, e*1000, xy(0,0))
    the_hits.append(h)

voxels = voxelize_hits(the_hits,
                        np.array([base_vsize, base_vsize, base_vsize]), False)

print(voxels)

(mod_voxels, dropped_voxels) = drop_end_point_voxels(voxels, energy_threshold, min_voxels)


tracks = make_track_graphs(mod_voxels)

print(tracks)

E = []
for i in range(len(tracks)):
    E.append(get_track_energy(tracks[i]))


print("Energy after:")
print(sum(E))

print("Number of tracks:")
print(len(tracks))
# Out:
# Sanity check, how much energy before:
# 0.5831881
# [Voxel(411.0962036132788, 78.52730019887564, 743.3333129882808, E=29.781300176182413), Voxel(444.4447265625012, -22.219897905987263, 778.5719604492213, E=55.89614950076793), Voxel(455.5609008789087, -44.608164151512355, 719.8408813476537, E=45.37782451370731), Voxel(455.5609008789087, -44.608164151512355, 731.5870971679673, E=11.72928817140928), Voxel(455.5609008789087, -33.414031028749804, 719.8408813476537, E=72.44643123885908), Voxel(455.5609008789087, -33.414031028749804, 731.5870971679673, E=219.48189511022065), Voxel(455.5609008789087, -22.219897905987263, 719.8408813476537, E=44.81337661854923), Voxel(455.5609008789087, -22.219897905987263, 731.5870971679673, E=103.66185763268732)]
# (<networkx.classes.graph.Graph object at 0x1490b469b040>, <networkx.classes.graph.Graph object at 0x1490b47fd4f0>, <networkx.classes.graph.Graph object at 0x1490c41d63d0>)
# Energy after:
# 583.1881229623832
# Number of tracks:
# 3

# %%
upper_r = 546 # mm
upper_z = 1206 # mm
lower_z = 3.7 # mm
# check if track falls within or outwith the detector 
for c, t in enumerate(tracks, 0):
    print(c)
    print(t)
    v = t.nodes()
    pos = [h.pos for v in t.nodes() for h in v.hits]
    x, y, z = map(np.array, zip(*pos))
    r = np.sqrt(x**2 + y**2)
    if max(r) > upper_r:
        print("Out of range!")
        continue
    elif (max(z) > upper_z) or (min(z) < lower_z):
        print("Out of range!")
        continue
    else:
        print("Safe!\nMin R: {}   Max R: {}\nMin Z: {}   Max Z: {}\n".format(min(r), max(r), min(z), max(z)))
        # do the shenanigans here
# Out:
# 0
# Graph with 1 nodes and 0 edges
# Safe!
# Min R: 414.13854706273526   Max R: 414.33795656508335
# Min Z: 742.98828125   Max Z: 743.1243286132812
#
# test
# 1
# Graph with 1 nodes and 0 edges
# Safe!
# Min R: 445.36723399188406   Max R: 445.9737036613156
# Min Z: 784.2437133789062   Max Z: 784.445068359375
#
# test
# 2
# Graph with 6 nodes and 11 edges
# Safe!
# Min R: 452.9812414693991   Max R: 461.7652288359075
# Min Z: 713.9677734375   Max Z: 736.9537353515625
#
# test

# %%
def create_row(evt, track_ID, track_E, track_no):
    '''
    create list row for filling df
    '''
    return [evt, track_ID, track_E, track_no]

def MC_track_info(df):
    '''
    Pass through MC hits dataframe and this will produce a new df with formatting:
                                        (MeV)                               (MeV)
    event_id   |   track_ID   |   track energy   | numb_of_tracks  | total energy
        0             0               0.57               2                1.11
        0             1               0.54               2                1.11
        1             0               1.65               1                1.65
        .             .                 .                .                  .
    '''
    # obtained from finding the minima and maxima in the DECO/RECO information
    #upper_r = 546 # mm
    #upper_z = 1206 # mm
    #lower_z = 3.7 # mm
    
    data = []
    
    for (event, df_one) in df.groupby('event_id'):
        
        the_hits = []
        
        # keep the hits within the active region
        df_one = df_one[df_one.label == 'ACTIVE']
        
        xs = df_one.x
        ys = df_one.y
        zs = df_one.z
        es = df_one.energy
        
        
    
        for x, y, z, e in zip(xs, ys, zs, es):
            if np.isnan(e): continue
            h = Hit(0, Cluster(0, xy(x,y), xy(0,0), 0), z, e*1000, xy(0,0))
            the_hits.append(h)

        voxels = voxelize_hits(the_hits,
                        np.array([base_vsize, base_vsize, base_vsize]), False)

        
        (mod_voxels, dropped_voxels) = drop_end_point_voxels(voxels, energy_threshold, min_voxels)

        tracks = make_track_graphs(mod_voxels)
        
        track_number = len(tracks)
        
        for c, t in enumerate(tracks, 0):
            # collect information on track
            #pos = [h.pos for v in t.nodes() for h in v.hits]
            #x, y, z = map(np.array, zip(*pos))
            #r = np.sqrt(x**2 + y**2)
            #if max(r) > upper_r:
            #    #print("Out of range!")
            #    continue
            #elif (max(z) > upper_z) or (min(z) < lower_z):
            #    #print("Out of range!")
            #    continue
            #else:
            #    #print("Safe!\nMin R: {}   Max R: {}\nMin Z: {}   Max Z: {}\n".format(min(r), max(r), min(z), max(z)))
                
            #    # append only tracks that fall within the detector
            data.append(create_row(event, c, get_track_energy(t)/1000, track_number))
        
        
        
    return  pd.DataFrame(data, columns = ['event_id', 'track_ID', 'track_energy', 'numb_of_tracks'])

# %%
display(MC_track_info(df_MC_one))
# Out:
#    event_id  track_ID  track_energy  numb_of_tracks
# 0     80000         0      0.029781               3
# 1     80000         1      0.055896               3
# 2     80000         2      0.497511               3

# %% [markdown]
# ### sanity check, do any of the MC hits within active go outwith the volume?
# the answer is no, lol

# %%
print(np.min(df_MC.z.to_numpy()))
print(np.max(df_MC.z.to_numpy()))
R = np.sqrt(df_MC.x.to_numpy()**2 + df_MC.y.to_numpy()**2)
print(np.max(R), np.min(R))
# Out:
# 6.581435
# 1449.5265
# 499.50836 3.8328204

# %%
folder_path = '/gluster/data/next/files/TOPOLOGY_John/HYPPOS_DATA_QTHR/BEERSHEBA_STUDY/satkill/PORT_1a/isaura/'
file_names = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.h5')]


dfs = []
i = 0
tot = len(file_names)
for file in file_names:
    df_MC = pd.read_hdf(folder_path + file, 'MC/hits')
    
    dfs.append(MC_track_info(df_MC))
    
    i += 1
    
    if (i%5 == 0):
        print("{}/{}".format(i,tot))
    
MC_hit_energy = pd.concat(dfs, axis = 0, ignore_index = True)
# Out:
# 5/300
# 10/300
# 15/300
# 20/300
# 25/300
# 30/300
# 35/300
# 40/300
# 45/300
# 50/300
# 55/300
# 60/300
# 65/300
# 70/300
# 75/300
# 80/300
# 85/300
# 90/300
# 95/300
# 100/300
# 105/300
# 110/300
# 115/300
# 120/300
# 125/300
# 130/300
# 135/300
# 140/300
# 145/300
# 150/300
# 155/300
# 160/300
# 165/300
# 170/300
# 175/300
# 180/300
# 185/300
# 190/300
# 195/300
# 200/300
# 205/300
# 210/300
# 215/300
# 220/300
# 225/300
# 230/300
# 235/300
# 240/300
# 245/300
# 250/300
# 255/300
# 260/300
# 265/300
# 270/300
# 275/300
# 280/300
# 285/300
# 290/300
# 295/300
# 300/300

# %%
MC_hit_energy.to_hdf('MC_topology_info.h5', 'topology')

# %%
display(df_MC)
test_var = df_MC[df_MC.particle_id == 23].index
print(test_var)
display(df_MC.drop(test_var))
# Out:
#         event_id  particle_id  hit_id          x           y           z  \
# 0        1000000           23       0 -62.902893  312.907623  212.046997
# 1        1000000           34       0 -62.902672  312.907623  212.046997
# 2        1000000           33       0 -62.902832  312.907532  212.046951
# 3        1000000           32       0 -62.902912  312.907593  212.047012
# 4        1000000           31       0 -62.902870  312.907654  212.046997
# ...          ...          ...     ...        ...         ...         ...
# 123489   1000340           59       1 -78.538589 -206.739258  762.828735
# 123490   1000340           58       0 -78.538071 -206.738983  762.828674
# 123491   1000340           57       0 -78.539032 -206.739105  762.830566
# 123492   1000340           57       1 -78.540787 -206.739182  762.833557
# 123493   1000340           57       2 -78.540504 -206.739563  762.833618
#
#             time    energy   label
# 0       1.887960  0.000185  ACTIVE
# 1       1.888017  0.000044  ACTIVE
# 2       1.887995  0.000033  ACTIVE
# 3       1.887973  0.000021  ACTIVE
# 4       1.887967  0.000046  ACTIVE
# ...          ...       ...     ...
# 123489  3.137650  0.000382  ACTIVE
# 123490  3.137652  0.000101  ACTIVE
# 123491  3.137662  0.000094  ACTIVE
# 123492  3.137778  0.002058  ACTIVE
# 123493  3.137816  0.000454  ACTIVE
#
# [123494 rows x 9 columns]
# Int64Index([     0,    634,    635,   2366,   4645,   4991,   6307,   6308,
#               7558,   7559,
#             ...
#             120031, 120032, 120033, 120034, 120036, 121091, 121586, 121587,
#             122905, 123175],
#            dtype='int64', length=2431)
#         event_id  particle_id  hit_id          x           y           z  \
# 1        1000000           34       0 -62.902672  312.907623  212.046997
# 2        1000000           33       0 -62.902832  312.907532  212.046951
# 3        1000000           32       0 -62.902912  312.907593  212.047012
# 4        1000000           31       0 -62.902870  312.907654  212.046997
# 5        1000000           30       0 -62.902901  312.907623  212.046997
# ...          ...          ...     ...        ...         ...         ...
# 123489   1000340           59       1 -78.538589 -206.739258  762.828735
# 123490   1000340           58       0 -78.538071 -206.738983  762.828674
# 123491   1000340           57       0 -78.539032 -206.739105  762.830566
# 123492   1000340           57       1 -78.540787 -206.739182  762.833557
# 123493   1000340           57       2 -78.540504 -206.739563  762.833618
#
#             time    energy   label
# 1       1.888017  0.000044  ACTIVE
# 2       1.887995  0.000033  ACTIVE
# 3       1.887973  0.000021  ACTIVE
# 4       1.887967  0.000046  ACTIVE
# 5       1.887968  0.000012  ACTIVE
# ...          ...       ...     ...
# 123489  3.137650  0.000382  ACTIVE
# 123490  3.137652  0.000101  ACTIVE
# 123491  3.137662  0.000094  ACTIVE
# 123492  3.137778  0.002058  ACTIVE
# 123493  3.137816  0.000454  ACTIVE
#
# [121063 rows x 9 columns]

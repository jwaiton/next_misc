# %%
import sys,os,os.path
sys.path.append("../../") # if you move files around, you need to adjust this!
sys.path.append(os.path.expanduser('~/code/eol_hsrl_python'))
os.environ['ICTDIR']='/home/e78368jw/Documents/NEXT_CODE/IC'

#%load_ext autoreload
#%autoreload 2
#%matplotlib notebook
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
from matplotlib import rcParams

import pandas as pd
import numpy  as np
import tables as tb

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as clrs

import IC.invisible_cities.core.core_functions                   as     coref
import IC.invisible_cities.io.dst_io                           as     dstio

from IC.invisible_cities.cities                 import beersheba as beerfun

from IC.invisible_cities.evm.event_model                          import HitCollection

from IC.invisible_cities.database.load_db       import DataSiPM

from IC.invisible_cities.evm.event_model        import Cluster, Hit
from IC.invisible_cities.types.ic_types         import xy
from IC.invisible_cities.reco.paolina_functions import voxelize_hits

from IC.invisible_cities.evm.event_model        import HitEnergy
from IC.invisible_cities.cities.beersheba          import DeconvolutionMode
from IC.invisible_cities.cities.beersheba          import CutType

from IC.invisible_cities.reco import hits_functions as hif

from IC.invisible_cities.reco.deconv_functions import deconvolve
from IC.invisible_cities.reco.deconv_functions import deconvolution_input
from IC.invisible_cities.reco.deconv_functions import InterpolationMethod

import IC.invisible_cities.io.mcinfo_io as mcio

from collections import defaultdict

import matplotlib.cm as cm
from matplotlib.colors import Normalize

pd.set_option('display.max_rows', 200)

import imageio

import functions as func

# %% [markdown]
# ### STUDY EVENT
#
# select a particular file, look at the events in all fashions allowed by the file
#
# **Important note: Event IDs are separated between MC and reco by reco_id = MC_id x 2**
#
# #### MC
#
# Contains 6 tables:

# %%
# !ptdump example_files/sophronia_27_208Tl.h5:/MC/
# Out:
# /MC/ (Group) ''
# /MC//configuration (Table(30,)shuffle, zlib(4)) ''
# /MC//event_mapping (Table(316,)shuffle, zlib(4)) ''
# /MC//hits (Table(116760,)shuffle, zlib(4)) ''
# /MC//particles (Table(26089,)shuffle, zlib(4)) ''
# /MC//sns_positions (Table(0,)shuffle, zlib(4)) ''
# /MC//sns_response (Table(0,)shuffle, zlib(4)) ''

# %% [markdown]
# I dont really care about sns stuff, configuration is interesting, but really we care about hits and particles

# %%
evt_interest = np.load('/home/e78368jw/Downloads/tmp_out/testing_arena/signal_ids.npy', allow_pickle=True)

# %%
FILE_NUMBER = 27
#file_path = 'example_files/sophronia_27_208Tl.h5'
#file_path = '/home/e78368jw/Downloads/tmp_out/testing_arena/rel_0.2/isaura_' + str(FILE_NUMBER) + '_208Tl.h5'
#file_path = 'example_files/4bar_p1a_soph.h5'
file_path = '/home/e78368jw/Downloads/test_data/run_15107_2244_ldc1_trg2.v2.3.1.20250312-1-gc1f0fe5.HE.sophronia.h5'

# %%
# provide file_path here

# read in
df = pd.read_hdf(file_path, 'MC/particles', start = 0, stop = 100000)
events = np.unique(df.event_id.to_numpy())

print("{} events\nRange: {} - {}\nMC events are even and odd, unlike other events.".format(len(events), np.min(events), np.max(events)))

# To demonstrate if events are in our range
'''
# currently above
evt_interest = np.array([ 500212, 360410,  880326,  880632,  140498, 1400312,  780070, 1300678, 1420010,
 1560046, 3400254, 3460222, 3460368, 4640148, 2380072, 2400166, 2400352, 2420264,
 2420484, 2020596, 5100182, 2720126, 2460486, 4900236, 4900564, 2200130, 2920164,
 2220538, 3320592, 3360136, 3040542, 5080500, 5080582, 3240618, 4340258, 4660390,
 4780540, 5240042, 5240092, 5280344, 5280466, 5380300, 5520326, 5560540, 5600600,
 5640604, 5860010, 5860356, 5960124, 5980316,  300152,  520014,  120106,  860132,
  440576,  160018, 1360020,  580310, 1000074, 1880268, 1820390, 1980402, 1580424,
 1440166, 1600396, 1720598, 4180102, 4180346, 2260440, 2260602, 2660104, 3340078,
 3340220, 3340240, 3340322, 4460044, 4460280, 3100132, 3100620, 3700418, 3180024,
 2980156, 3160430, 3560008, 3960556, 3580280, 3580598, 4160120, 4160460, 4100438,
 4260578, 4520630, 4820472, 4720252, 5160298, 5500348, 5700592, 5800362, 5800476,
 5920294])'''




#print(f'events within this file from the above list: {np.intersect1d(evt_interest//2, events)}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # provide file_path here
#       2
#       3 # read in
# ----> 4 df = pd.read_hdf(file_path, 'MC/particles', start = 0, stop = 100000)
#       5 events = np.unique(df.event_id.to_numpy())
#       7 print("{} events\nRange: {} - {}\nMC events are even and odd, unlike other events.".format(len(events), np.min(events), np.max(events)))
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/io/pytables.py:427, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     424     exists = False
#     426 if not exists:
# --> 427     raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     429 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     430 # can't auto open/close if we are using an iterator
#     431 # so delegate to the iterator
#
# FileNotFoundError: File /home/e78368jw/Downloads/test_data/run_15107_2244_ldc1_trg2.v2.3.1.20250312-1-gc1f0fe5.HE.sophronia.h5 does not exist

# %% [markdown]
# **Select event**

# %%
evt = events[55]
print("Selected event: {} ({})".format(evt, evt*2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 evt = events[55]
#       2 print("Selected event: {} ({})".format(evt, evt*2))
#
# NameError: name 'events' is not defined

# %% [markdown]
# **Load particle information**
#
# Gives full information about particle interactions related to a Tl208 decay

# %%
# done already to determine number of events
print(df.columns.to_numpy())
df_ps = df[df.event_id == evt]
display(df_ps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # done already to determine number of events
# ----> 2 print(df.columns.to_numpy())
#       3 df_ps = df[df.event_id == evt]
#       4 display(df_ps)
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Load hits**

# %%
true_info = pd.read_hdf(file_path, 'RECO/Events')
evt = true_info.event.unique()[0]

this_evt_true_info = true_info[true_info.event == evt]

display(this_evt_true_info)

xt = this_evt_true_info.X
yt = this_evt_true_info.Y
zt = this_evt_true_info.Z
et = this_evt_true_info.E*1000
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 true_info = pd.read_hdf(file_path, 'RECO/Events')
#       2 evt = true_info.event.unique()[0]
#       4 this_evt_true_info = true_info[true_info.event == evt]
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/io/pytables.py:427, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     424     exists = False
#     426 if not exists:
# --> 427     raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     429 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     430 # can't auto open/close if we are using an iterator
#     431 # so delegate to the iterator
#
# FileNotFoundError: File /home/e78368jw/Downloads/test_data/run_15107_2244_ldc1_trg2.v2.3.1.20250312-1-gc1f0fe5.HE.sophronia.h5 does not exist

# %%
true_info = mcio.load_mchits_df(file_path).reset_index()
evt = 618469

this_evt_true_info = true_info[true_info.event_id == evt]

display(this_evt_true_info)

xt = this_evt_true_info.x
yt = this_evt_true_info.y
zt = this_evt_true_info.z
et = this_evt_true_info.energy*1000

######## PLOTTING

def return_id(number):
    return str(df_ps[df_ps.particle_id == number].particle_name.values).strip("'[]'")

this_evt_true_info['particle_name'] = this_evt_true_info['particle_id'].apply(return_id)

xt = this_evt_true_info.x
yt = this_evt_true_info.y
zt = this_evt_true_info.z
et = this_evt_true_info.energy*1000

for pid, df in this_evt_true_info.groupby('particle_name'):

    xt = df.x
    yt = df.y
    zt = df.z
    et = df.energy*1000

   
    if (pid == 'gamma') or (pid == 'Xe131') or (pid == 'Xe129'):
        plt.scatter(xt, yt,  alpha=1, label = str(pid))
    else:
        plt.scatter(xt, yt,  alpha=0.1, label = str(pid))

    
plt.xlabel('X (mm)');
plt.ylabel('Y (mm)');

# Retrieve legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()

# Create a single legend for all subplots
legend = plt.legend(handles, labels, fontsize=15)
for handle in legend.legendHandles:
    handle.set_alpha(1.0)

plt.title('True Hits_XY_' + str(evt), fontsize=30)
plt.show()


for pid, df in this_evt_true_info.groupby('particle_name'):

    xt = df.x
    yt = df.y
    zt = df.z
    et = df.energy*1000

   
    if (pid == 'gamma') or (pid == 'Xe131') or (pid == 'Xe129'):
        plt.scatter(xt, zt,  alpha=1, label = str(pid))
    else:
        plt.scatter(xt, zt,  alpha=0.1, label = str(pid))

    
plt.xlabel('X (mm)');
plt.ylabel('Z (mm)');

# Retrieve legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()

# Create a single legend for all subplots
legend = plt.legend(handles, labels, fontsize=15)
for handle in legend.legendHandles:
    handle.set_alpha(1.0)

plt.title('True Hits_XZ_' + str(evt), fontsize=30)
plt.show()

for pid, df in this_evt_true_info.groupby('particle_name'):

    xt = df.x
    yt = df.y
    zt = df.z
    et = df.energy*1000

   
    if (pid == 'gamma') or (pid == 'Xe131') or (pid == 'Xe129'):
        plt.scatter(yt, zt,  alpha=1, label = str(pid))
    else:
        plt.scatter(yt, zt,  alpha=0.1, label = str(pid))

    
plt.xlabel('Y (mm)');
plt.ylabel('Z (mm)');

# Retrieve legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()

# Create a single legend for all subplots
legend = plt.legend(handles, labels, fontsize=15)
for handle in legend.legendHandles:
    handle.set_alpha(1.0)

plt.title('True Hits_YZ_' + str(evt), fontsize=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 true_info = mcio.load_mchits_df(file_path).reset_index()
#       2 evt = 618469
#       4 this_evt_true_info = true_info[true_info.event_id == evt]
#
# File ~/Documents/NEXT_CODE/next_misc/toolbox/../../IC/invisible_cities/io/mcinfo_io.py:478, in load_mchits_df(file_name)
#     462 def load_mchits_df(file_name : str) -> pd.DataFrame:
#     463     """
#     464     Opens file and calls read_mchits_df
#     465
#    (...)
#     476            in nexus simulations.
#     477     """
# --> 478     if is_oldformat_file(file_name):
#     479         ## Is this a pre-Feb 2020 file?
#     480         return load_mchits_dfold(file_name)
#     481     else:
#
# File ~/Documents/NEXT_CODE/next_misc/toolbox/../../IC/invisible_cities/io/mcinfo_io.py:263, in is_oldformat_file(file_name)
#     249 def is_oldformat_file(file_name : str) -> bool:
#     250     """
#     251     Checks if the file type is pre 2020 or not
#     252
#    (...)
#     261           False if MC.extents not found : 2020-- format
#     262     """
# --> 263     with tb.open_file(file_name) as h5in:
#     264         return hasattr(h5in.root, 'MC/extents')
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/tables/file.py:300, in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     295             raise ValueError(
#     296                 "The file '%s' is already opened.  Please "
#     297                 "close it before reopening in write mode." % filename)
#     299 # Finally, create the File instance, and return it
# --> 300 return File(filename, mode, title, root_uep, filters, **kwargs)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/tables/file.py:750, in File.__init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     747 self.params = params
#     749 # Now, it is time to initialize the File extension
# --> 750 self._g_new(filename, mode, **params)
#     752 # Check filters and set PyTables format version for new files.
#     753 new = self._v_new
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/tables/hdf5extension.pyx:368, in tables.hdf5extension.File._g_new()
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/tables/utils.py:143, in check_file_access(filename, mode)
#     140 if mode == 'r':
#     141     # The file should be readable.
#     142     if not os.access(path, os.F_OK):
# --> 143         raise OSError(f"``{path}`` does not exist")
#     144     if not path.is_file():
#     145         raise OSError(f"``{path}`` is not a regular file")
#
# OSError: ``/home/e78368jw/Downloads/test_data/run_15107_2244_ldc1_trg2.v2.3.1.20250312-1-gc1f0fe5.HE.sophronia.h5`` does not exist

# %% [markdown]
# #### SOPHRONIA

# %%
file_path = '/home/e78368jw/Downloads/test_data/sop/'
file_names = [f for f in os.listdir(file_path) if os.path.isfile(os.path.join(file_path, f)) and f.endswith('.h5')]

for file in file_names:
    soph_file = file_path + file#f'/home/e78368jw/Documents/NEXT_CODE/next_misc/energy_topology_study/testing_data/sophronia_' + str(FILE_NUMBER) + '_208Tl.h5'
    soph_hdst = dstio.load_dst(soph_file, 'RECO', 'Events')#CHITS/lowTh

    for evt, df in soph_hdst.groupby('event'):
        soph_hits = df#soph_hdst[soph_hdst.event == soph_hdst.event.unique()[4]]
        #display(soph_hits)
    #soph_hits = this_evt_true_info
        print(f'EVENT: {evt}\n')
        q_cut = 8
        drop_dist       = [16, 16]
        cut_sensors       = beerfun.cut_over_Q   (q_cut, ['E', 'Ec'])
        drop_sensors      = beerfun.drop_isolated(drop_dist, ['E', 'Ec'])
        hits_cut = coref.timefunc(cut_sensors)(soph_hits.copy())
        hits_drop = coref.timefunc(drop_sensors)(hits_cut.copy())
        pitch = 15.55
        # then applying transformations to convert to 'SiPM outputs'
        fig, axes = plt.subplots(1, 3, figsize=(18, 6))


        xx = np.arange(hits_drop.X.min(), hits_drop.X.max() + pitch, pitch)
        yy = np.arange(hits_drop.Y.min(), hits_drop.Y.max() + pitch, pitch)
        zz = hits_cut.Z.unique()

        axes[0].hist2d(hits_drop.X, hits_drop.Y, bins=[xx, yy], weights=hits_drop.Q, cmin=0.0001);
        axes[0].set_xlabel('X (mm)');
        axes[0].set_ylabel('Y (mm)');

        axes[1].hist2d(hits_drop.X, hits_drop.Z, bins=[xx, zz], weights=hits_drop.Q, cmin=0.0001);
        axes[1].set_xlabel('X (mm)');
        axes[1].set_ylabel('Z (mm)');


        axes[2].hist2d(hits_drop.Y, hits_drop.Z, bins=[yy, zz], weights=hits_drop.Q, cmin=0.0001);
        axes[2].set_xlabel('Y (mm)');
        axes[2].set_ylabel('Z (mm)');

        fig.suptitle('Processed Sensors Signal_' + str(evt), fontsize=30)
        plt.savefig(f'output/event_{evt}.png')
        plt.close()
    #plt.tight_layout()
# Out:
# EVENT: 14450
#
# Time spent in cut_over_Q: 0.04307675361633301 s
# Time spent in drop_isolated: 0.023927688598632812 s
# EVENT: 14597
#
# Time spent in cut_over_Q: 0.01277923583984375 s
# Time spent in drop_isolated: 0.023661375045776367 s
# EVENT: 14625
#
# Time spent in cut_over_Q: 0.011542797088623047 s
# Time spent in drop_isolated: 0.013313531875610352 s
# EVENT: 14667
#
# Time spent in cut_over_Q: 0.006133317947387695 s
# Time spent in drop_isolated: 0.006005764007568359 s
# EVENT: 14779
#
# Time spent in cut_over_Q: 0.008389711380004883 s
# Time spent in drop_isolated: 0.02764129638671875 s
# EVENT: 14933
#
# Time spent in cut_over_Q: 0.01077413558959961 s
# Time spent in drop_isolated: 0.042441368103027344 s
# EVENT: 15052
#
# Time spent in cut_over_Q: 0.01081228256225586 s
# Time spent in drop_isolated: 0.011505126953125 s
# EVENT: 64010
#
# Time spent in cut_over_Q: 0.017382144927978516 s
# Time spent in drop_isolated: 0.02069401741027832 s
# EVENT: 64164
#
# Time spent in cut_over_Q: 0.02897357940673828 s
# Time spent in drop_isolated: 0.01957392692565918 s
# EVENT: 64269
#
# Time spent in cut_over_Q: 0.005341529846191406 s
# Time spent in drop_isolated: 0.006043910980224609 s
# EVENT: 64332
#
# Time spent in cut_over_Q: 0.008179187774658203 s
# Time spent in drop_isolated: 0.004677534103393555 s
# EVENT: 64570
#
# Time spent in cut_over_Q: 0.010523319244384766 s
# Time spent in drop_isolated: 0.008732080459594727 s
# EVENT: 759719
#
# Time spent in cut_over_Q: 0.0181272029876709 s
# Time spent in drop_isolated: 0.015720844268798828 s
# EVENT: 759740
#
# Time spent in cut_over_Q: 0.0282135009765625 s
# Time spent in drop_isolated: 0.294968843460083 s
# EVENT: 760041
#
# Time spent in cut_over_Q: 0.16994285583496094 s
# Time spent in drop_isolated: 0.08641242980957031 s
# EVENT: 760083
#
# Time spent in cut_over_Q: 0.13813233375549316 s
# Time spent in drop_isolated: 0.05992293357849121 s
# EVENT: 760111
#
# Time spent in cut_over_Q: 0.17432284355163574 s
# Time spent in drop_isolated: 0.058547258377075195 s
# EVENT: 760146
#
# Time spent in cut_over_Q: 0.11088085174560547 s
# Time spent in drop_isolated: 0.08299064636230469 s
# EVENT: 760160
#
# Time spent in cut_over_Q: 0.08045411109924316 s
# Time spent in drop_isolated: 0.019092798233032227 s
# EVENT: 2177989
#
# Time spent in cut_over_Q: 0.07799148559570312 s
# Time spent in drop_isolated: 0.03836345672607422 s
# EVENT: 2177996
#
# Time spent in cut_over_Q: 0.006592750549316406 s
# Time spent in drop_isolated: 0.013336896896362305 s
# EVENT: 2178101
#
# Time spent in cut_over_Q: 0.11280393600463867 s
# Time spent in drop_isolated: 0.035961151123046875 s
# EVENT: 2178199
#
# Time spent in cut_over_Q: 0.12688660621643066 s
# Time spent in drop_isolated: 0.04192948341369629 s
# EVENT: 761049
#
# Time spent in cut_over_Q: 0.11255550384521484 s
# Time spent in drop_isolated: 0.035099029541015625 s
# EVENT: 761098
#
# Time spent in cut_over_Q: 0.011583566665649414 s
# Time spent in drop_isolated: 0.03430676460266113 s
# EVENT: 761343
#
# Time spent in cut_over_Q: 0.009322404861450195 s
# Time spent in drop_isolated: 0.019807815551757812 s
# EVENT: 761518
#
# Time spent in cut_over_Q: 0.41747307777404785 s
# EVENT: 766033
#
# Time spent in cut_over_Q: 0.12871170043945312 s
# Time spent in drop_isolated: 0.07107162475585938 s
# EVENT: 766516
#
# Time spent in cut_over_Q: 0.10998940467834473 s
# Time spent in drop_isolated: 0.05100059509277344 s
# EVENT: 788202
#
# Time spent in cut_over_Q: 0.029224872589111328 s
# Time spent in drop_isolated: 0.02869248390197754 s
# EVENT: 788237
#
# Time spent in cut_over_Q: 0.08118605613708496 s
# Time spent in drop_isolated: 0.040477752685546875 s
# EVENT: 788279
#
# Time spent in cut_over_Q: 0.014628171920776367 s
# Time spent in drop_isolated: 0.011164665222167969 s
# EVENT: 788300
#
# Time spent in cut_over_Q: 0.006176948547363281 s
# Time spent in drop_isolated: 0.017566442489624023 s
# EVENT: 788468
#
# Time spent in cut_over_Q: 0.1613454818725586 s
# Time spent in drop_isolated: 0.047202348709106445 s
# EVENT: 788475
#
# Time spent in cut_over_Q: 0.15857791900634766 s
# Time spent in drop_isolated: 0.06104898452758789 s
# EVENT: 763114
#
# Time spent in cut_over_Q: 0.04387402534484863 s
# Time spent in drop_isolated: 0.03639936447143555 s
# EVENT: 763233
#
# Time spent in cut_over_Q: 0.10866546630859375 s
# Time spent in drop_isolated: 0.0660407543182373 s
# EVENT: 763303
#
# Time spent in cut_over_Q: 0.01076650619506836 s
# Time spent in drop_isolated: 0.018403291702270508 s
# EVENT: 763478
#
# Time spent in cut_over_Q: 0.01250600814819336 s
# Time spent in drop_isolated: 0.02727055549621582 s
# EVENT: 763681
#
# Time spent in cut_over_Q: 0.09846043586730957 s
# Time spent in drop_isolated: 0.048508405685424805 s
# EVENT: 65886
#
# Time spent in cut_over_Q: 0.016003847122192383 s
# Time spent in drop_isolated: 0.014976024627685547 s
# EVENT: 820962
#
# Time spent in cut_over_Q: 0.024869918823242188 s
# Time spent in drop_isolated: 0.02532672882080078 s
# EVENT: 821039
#
# Time spent in cut_over_Q: 0.13828516006469727 s
# Time spent in drop_isolated: 0.040947914123535156 s
# EVENT: 821067
#
# Time spent in cut_over_Q: 0.048574209213256836 s
# Time spent in drop_isolated: 0.02341294288635254 s
# EVENT: 821151
#
# Time spent in cut_over_Q: 0.01289057731628418 s
# Time spent in drop_isolated: 0.013623714447021484 s
# EVENT: 821186
#
# Time spent in cut_over_Q: 0.15246081352233887 s
# Time spent in drop_isolated: 0.04253363609313965 s
# EVENT: 821312
#
# Time spent in cut_over_Q: 0.00564885139465332 s
# Time spent in drop_isolated: 0.013733625411987305 s
# EVENT: 764892
#
# Time spent in cut_over_Q: 0.08404779434204102 s
# Time spent in drop_isolated: 0.03194904327392578 s
# EVENT: 765011
#
# Time spent in cut_over_Q: 0.15468358993530273 s
# Time spent in drop_isolated: 0.06217384338378906 s
# EVENT: 765018
#
# Time spent in cut_over_Q: 0.09124946594238281 s
# Time spent in drop_isolated: 0.021080732345581055 s
# EVENT: 772851
#
# Time spent in cut_over_Q: 0.17035555839538574 s
# Time spent in drop_isolated: 0.06472158432006836 s
# EVENT: 773096
#
# Time spent in cut_over_Q: 0.06216549873352051 s
# EVENT: 764465
#
# Time spent in cut_over_Q: 0.10762357711791992 s
# Time spent in drop_isolated: 0.03745889663696289 s
# EVENT: 777184
#
# Time spent in cut_over_Q: 0.012958288192749023 s
# Time spent in drop_isolated: 0.025260210037231445 s
# EVENT: 777310
#
# Time spent in cut_over_Q: 0.11976265907287598 s
# Time spent in drop_isolated: 0.06429553031921387 s
# EVENT: 34561
#
# Time spent in cut_over_Q: 0.024340152740478516 s
# Time spent in drop_isolated: 0.08685660362243652 s
# EVENT: 34652
#
# Time spent in cut_over_Q: 0.022277355194091797 s
# Time spent in drop_isolated: 0.017995357513427734 s
# EVENT: 34729
#
# Time spent in cut_over_Q: 0.026052474975585938 s
# Time spent in drop_isolated: 0.02075958251953125 s
# EVENT: 34848
#
# Time spent in cut_over_Q: 0.016867399215698242 s
# Time spent in drop_isolated: 0.02057361602783203 s
# EVENT: 35009
#
# Time spent in cut_over_Q: 0.02973461151123047 s
# Time spent in drop_isolated: 0.0353848934173584 s
# EVENT: 35079
#
# Time spent in cut_over_Q: 0.017602920532226562 s
# Time spent in drop_isolated: 0.016028165817260742 s
# EVENT: 27253
#
# Time spent in cut_over_Q: 0.009668588638305664 s
# Time spent in drop_isolated: 0.012732505798339844 s
# EVENT: 27316
#
# Time spent in cut_over_Q: 0.01656961441040039 s
# Time spent in drop_isolated: 0.012546062469482422 s
# EVENT: 27351
#
# Time spent in cut_over_Q: 0.010805368423461914 s
# Time spent in drop_isolated: 0.026813745498657227 s
# EVENT: 55330
#
# Time spent in cut_over_Q: 0.01334071159362793 s
# Time spent in drop_isolated: 0.07191038131713867 s
# EVENT: 55393
#
# Time spent in cut_over_Q: 0.017401933670043945 s
# Time spent in drop_isolated: 0.01023721694946289 s
# EVENT: 55442
#
# Time spent in cut_over_Q: 0.019651174545288086 s
# Time spent in drop_isolated: 0.015243053436279297 s
# EVENT: 55498
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#      15 cut_sensors       = beerfun.cut_over_Q   (q_cut, ['E', 'Ec'])
#      16 drop_sensors      = beerfun.drop_isolated(drop_dist, ['E', 'Ec'])
# ---> 17 hits_cut = coref.timefunc(cut_sensors)(soph_hits.copy())
#      18 hits_drop = coref.timefunc(drop_sensors)(hits_cut.copy())
#      19 pitch = 15.55
#
# File ~/Documents/NEXT_CODE/next_misc/toolbox/../../IC/invisible_cities/core/core_functions.py:21, in timefunc.<locals>.time_f(*args, **kwargs)
#      19 def time_f(*args, **kwargs):
#      20     t0 = time.time()
# ---> 21     output = f(*args, **kwargs)
#      22     print("Time spent in {}: {} s".format(f.__name__,
#      23                                           time.time() - t0))
#      24     return output
#
# File ~/Documents/NEXT_CODE/next_misc/toolbox/../../IC/invisible_cities/cities/beersheba.py:332, in cut_over_Q.<locals>.cut_over_Q(df)
#     331 def cut_over_Q(df):  # df shall be an event cdst
# --> 332     cdst = df.groupby(['event', 'npeak']).apply(cut).reset_index(drop=True)
#     334     return cdst
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1275, in GroupBy.apply(self, func, *args, **kwargs)
#    1273 with option_context("mode.chained_assignment", None):
#    1274     try:
# -> 1275         result = self._python_apply_general(f, self._selected_obj)
#    1276     except TypeError:
#    1277         # gh-20949
#    1278         # try again, with .apply acting as a filtering
#    (...)
#    1282         # fails on *some* columns, e.g. a numeric operation
#    1283         # on a string grouper column
#    1285         with group_selection_context(self):
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1311, in GroupBy._python_apply_general(self, f, data)
#    1294 """
#    1295 Apply function f in python space
#    1296
#    (...)
#    1307     data after applying f
#    1308 """
#    1309 keys, values, mutated = self.grouper.apply(f, data, self.axis)
# -> 1311 return self._wrap_applied_output(
#    1312     data, keys, values, not_indexed_same=mutated or self.mutated
#    1313 )
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/groupby/generic.py:1158, in DataFrameGroupBy._wrap_applied_output(self, data, keys, values, not_indexed_same)
#    1156     return self.obj._constructor()
#    1157 elif isinstance(first_not_none, DataFrame):
# -> 1158     return self._concat_objects(keys, values, not_indexed_same=not_indexed_same)
#    1160 key_index = self.grouper.result_index if self.as_index else None
#    1162 if isinstance(first_not_none, (np.ndarray, Index)):
#    1163     # GH#1738: values is list of arrays of unequal lengths
#    1164     #  fall through to the outer else clause
#    1165     # TODO: sure this is right?  we used to do this
#    1166     #  after raising AttributeError above
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1044, in GroupBy._concat_objects(self, keys, values, not_indexed_same)
#    1041     group_levels = self.grouper.levels
#    1042     group_names = self.grouper.names
# -> 1044     result = concat(
#    1045         values,
#    1046         axis=self.axis,
#    1047         keys=group_keys,
#    1048         levels=group_levels,
#    1049         names=group_names,
#    1050         sort=False,
#    1051     )
#    1052 else:
#    1053
#    1054     # GH5610, returns a MI, with the first level being a
#    1055     # range index
#    1056     keys = list(range(len(values)))
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/reshape/concat.py:294, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#      90 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#      91 def concat(
#      92     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     101     copy: bool = True,
#     102 ) -> FrameOrSeriesUnion:
#     103     """
#     104     Concatenate pandas objects along a particular axis with optional set logic
#     105     along the other axes.
#    (...)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#     297         ignore_index=ignore_index,
#     298         join=join,
#     299         keys=keys,
#     300         levels=levels,
#     301         names=names,
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
#     304         sort=sort,
#     305     )
#     307     return op.get_result()
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/reshape/concat.py:371, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     369     else:
#     370         name = getattr(keys, "name", None)
# --> 371         keys = Index(clean_keys, name=name)
#     373 if len(objs) == 0:
#     374     raise ValueError("All objects passed were None")
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/indexes/base.py:489, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     484     if data and all(isinstance(e, tuple) for e in data):
#     485         # we must be all tuples, otherwise don't construct
#     486         # 10697
#     487         from pandas.core.indexes.multi import MultiIndex
# --> 489         return MultiIndex.from_tuples(
#     490             data, names=name or kwargs.get("names")
#     491         )
#     492 # other iterable of some kind
#     494 subarr = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/indexes/multi.py:202, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     199 elif "name" in kwargs:
#     200     kwargs["names"] = kwargs.pop("name")
# --> 202 return meth(self_or_cls, *args, **kwargs)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/indexes/multi.py:560, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     557     arrs = zip(*tuples)
#     558     arrays = cast(List[Sequence[Hashable]], arrs)
# --> 560 return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/indexes/multi.py:483, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     480     if len(arrays[i]) != len(arrays[i - 1]):
#     481         raise ValueError("all arrays must be same length")
# --> 483 codes, levels = factorize_from_iterables(arrays)
#     484 if names is lib.no_default:
#     485     names = [getattr(arr, "name", None) for arr in arrays]
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2782, in factorize_from_iterables(iterables)
#    2778 if len(iterables) == 0:
#    2779     # For consistency, it should return two empty lists.
#    2780     return [], []
# -> 2782 codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    2783 return list(codes), list(categories)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2782, in <genexpr>(.0)
#    2778 if len(iterables) == 0:
#    2779     # For consistency, it should return two empty lists.
#    2780     return [], []
# -> 2782 codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    2783 return list(codes), list(categories)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2755, in factorize_from_iterable(values)
#    2750     codes = values.codes
#    2751 else:
#    2752     # The value of ordered is irrelevant since we don't use cat as such,
#    2753     # but only the resulting categories, the order of which is independent
#    2754     # from ordered. Set ordered to False as default. See GH #15457
# -> 2755     cat = Categorical(values, ordered=False)
#    2756     categories = cat.categories
#    2757     codes = cat.codes
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:432, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     430 if dtype.categories is None:
#     431     try:
# --> 432         codes, categories = factorize(values, sort=True)
#     433     except TypeError as err:
#     434         codes, categories = factorize(values, sort=False)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/algorithms.py:761, in factorize(values, sort, na_sentinel, size_hint)
#     758     else:
#     759         na_value = None
# --> 761     codes, uniques = factorize_array(
#     762         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763     )
#     765 if sort and len(uniques) > 0:
#     766     uniques, codes = safe_sort(
#     767         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     768     )
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/algorithms.py:560, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     527 def factorize_array(
#     528     values: np.ndarray,
#     529     na_sentinel: int = -1,
#    (...)
#     532     mask: np.ndarray | None = None,
#     533 ) -> tuple[np.ndarray, np.ndarray]:
#     534     """
#     535     Factorize an array-like to codes and uniques.
#     536
#    (...)
#     558     uniques : ndarray
#     559     """
# --> 560     hash_klass, values = get_data_algo(values)
#     562     table = hash_klass(size_hint or len(values))
#     563     uniques, codes = table.factorize(
#     564         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565     )
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/algorithms.py:294, in get_data_algo(values)
#     291 def get_data_algo(values: ArrayLike):
#     292     values = _get_values_for_rank(values)
# --> 294     ndtype = _check_object_for_strings(values)
#     295     htable = _hashtables.get(ndtype, _hashtables["object"])
#     297     return htable, values
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/core/algorithms.py:318, in _check_object_for_strings(values)
#     312 ndtype = values.dtype.name
#     313 if ndtype == "object":
#     314
#     315     # it's cheaper to use a String Hash Table than Object; we infer
#     316     # including nulls because that is the only difference between
#     317     # StringHashTable and ObjectHashtable
# --> 318     if lib.infer_dtype(values, skipna=False) in ["string"]:
#     319         ndtype = "string"
#     320 return ndtype
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/_libs/lib.pyx:1450, in pandas._libs.lib.infer_dtype()
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/pandas/_libs/lib.pyx:1306, in pandas._libs.lib._try_infer_map()
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/numpy/core/_dtype.py:344, in _name_get(dtype)
#     340     else:
#     341         return True
# --> 344 def _name_get(dtype):
#     345     # provides dtype.name.__get__, documented as returning a "bit name"
#     347     if dtype.isbuiltin == 2:
#     348         # user dtypes don't promise to do anything special
#     349         return dtype.type.__name__
#
# KeyboardInterrupt:

# %%
file_path = '/home/e78368jw/Downloads/test_data/sop/'
file_names = [f for f in os.listdir(file_path) if os.path.isfile(os.path.join(file_path, f)) and f.endswith('.h5')]

for file in file_names:
    soph_file = file_path + file#f'/home/e78368jw/Documents/NEXT_CODE/next_misc/energy_topology_study/testing_data/sophronia_' + str(FILE_NUMBER) + '_208Tl.h5'
    soph_hdst = dstio.load_dst(soph_file, 'RECO', 'Events')#CHITS/lowTh
    number_of_interest = 759740
    if number_of_interest in (soph_hdst.event.unique()):
        print(soph_file)
        break
# Out:
# /home/e78368jw/Downloads/test_data/sop/run_15107_1105_ldc1_trg2.v2.3.1.20250328.HEDesmanTest.sophronia.h5

# %%
from cycler import cycler

color_sequence = ("k", "m", "g", "b", "r",
                  "gray", "aqua", "gold", "lime", "purple",
                  "brown", "lawngreen", "tomato", "lightgray", "lightpink")

def auto_plot_style(overrides = dict()):
    plt.rcParams[ "figure.figsize"               ] = 10, 8
    plt.rcParams[   "font.size"                  ] = 25
    plt.rcParams[  "lines.markersize"            ] = 25
    plt.rcParams[  "lines.linewidth"             ] = 3
    plt.rcParams[  "patch.linewidth"             ] = 3
    plt.rcParams[   "axes.linewidth"             ] = 2
    plt.rcParams[   "grid.linewidth"             ] = 3
    plt.rcParams[   "grid.linestyle"             ] = "--"
    plt.rcParams[   "grid.alpha"                 ] = 0.5
    plt.rcParams["savefig.dpi"                   ] = 300
    plt.rcParams["savefig.bbox"                  ] = "tight"
    plt.rcParams[   "axes.formatter.use_mathtext"] = True
    plt.rcParams[   "axes.formatter.limits"      ] = (-3 ,4)
    plt.rcParams[  "xtick.major.size"            ] = 10
    plt.rcParams[  "ytick.major.size"            ] = 10
    plt.rcParams[  "xtick.minor.size"            ] = 5
    plt.rcParams[  "ytick.minor.size"            ] = 5
    plt.rcParams[   "axes.prop_cycle"            ] = cycler(color=color_sequence)
    plt.rcParams[  "image.cmap"                  ] = "gnuplot2"
    plt.rcParams.update(overrides)

# %%
auto_plot_style()

# %%
file_path = '/home/e78368jw/Downloads/test_data/sop/run_15107_1115_ldc1_trg2.v2.3.1.20250328.HEDesmanTest.sophronia.h5'
file_path = '/home/e78368jw/Downloads/test_data/sop/run_15107_1105_ldc1_trg2.v2.3.1.20250328.HEDesmanTest.sophronia.h5' # alpha

# %%
true_info = pd.read_hdf(file_path, 'RECO/Events')
evt = number_of_interest
pitch = 15.55

filtered_evt = true_info[true_info.event == evt]
display(filtered_evt)
#filtered_evt = this_evt_true_info[(this_evt_true_info.X > 0)]
#filtered_evt = filtered_evt[(filtered_evt.X < 400)]
#filtered_evt = filtered_evt[(filtered_evt.X > 50)]
#filtered_evt = filtered_evt[(filtered_evt.Y > -200)]
#filtered_evt = filtered_evt[(filtered_evt.Y < 100)]
#filtered_evt = filtered_evt[(filtered_evt.Z > 1600)]
#filtered_evt = filtered_evt[(filtered_evt.Z < 1800)]
filtered_evt = filtered_evt[filtered_evt.Q > 12]

plt.figure(figsize = (10,8))

xx = np.arange(filtered_evt.X.min(), filtered_evt.X.max() + pitch, pitch)
yy = np.arange(filtered_evt.Y.min(), filtered_evt.Y.max() + pitch, pitch)
zz = filtered_evt.Z.unique()

xx_MC = xx
yy_MC = yy
zz_MC = zz

energy_hist = plt.hist2d(filtered_evt.X, filtered_evt.Y, bins=[xx, yy], weights=filtered_evt.Q, cmin=0.0001);
plt.xlabel('X (mm)');
#plt.ylabel('Y (mm)');
plt.ylabel('Z (mm)');
cbar = plt.colorbar(energy_hist[3])
cbar.set_label('SiPM charge (PE)')
#plt.hist2d(filtered_evt.X, filtered_evt.Z, bins=[xx, zz], weights=filtered_evt.Q, cmin=0.0001);
#plt.set_xlabel('X (mm)');
#plt.set_ylabel('Z (mm)');
plt.xlim([100, 450])
plt.ylim([-150, 325])


plt.title('Double electron track candidate', fontsize=30)
plt.savefig('double_electron_candidate.pdf')
# Out:
#         event          time  npeak       Xpeak       Ypeak  nsipm        X  \
# 1627   759740  1.742945e+09      0    7.967181  -87.181131      1 -297.025
# 1628   759740  1.742945e+09      0    7.967181  -87.181131      1  104.275
# 1629   759740  1.742945e+09      0    7.967181  -87.181131      1   26.525
# 1630   759740  1.742945e+09      0    7.967181  -87.181131      1  -19.125
# 1631   759740  1.742945e+09      0    7.967181  -87.181131      1  119.825
# ...       ...           ...    ...         ...         ...    ...      ...
# 11133  759740  1.742945e+09      4  153.062807  175.072465      1  381.175
# 11134  759740  1.742945e+09      4  153.062807  175.072465      1  288.875
# 11135  759740  1.742945e+09      4  153.062807  175.072465      1  319.975
# 11136  759740  1.742945e+09      4  153.062807  175.072465      1  366.625
# 11137  759740  1.742945e+09      4  153.062807  175.072465      1  366.625
#
#              Y  Xrms  Yrms            Z         Q          E   Qc        Ec  \
# 1627    75.375   0.0   0.0   928.859125  5.409806  -4.149327 -1.0 -0.000012
# 1628  -464.375   0.0   0.0   928.859125  5.686775  -4.361763 -1.0 -0.000015
# 1629  -263.225   0.0   0.0   928.859125  5.923001  -4.542949 -1.0 -0.000013
# 1630   492.725   0.0   0.0   931.851250  5.096422  83.881361 -1.0       NaN
# 1631    75.875   0.0   0.0   931.851250  5.028828  82.768839 -1.0  0.000236
# ...        ...   ...   ...          ...       ...        ...  ...       ...
# 11133  307.625   0.0   0.0  2725.037000  8.748800  40.876313 -1.0       NaN
# 11134  276.525   0.0   0.0  2728.090500  5.472166  15.452206 -1.0  0.000060
# 11135  292.075   0.0   0.0  2728.090500  5.119298  14.455784 -1.0  0.000060
# 11136  276.525   0.0   0.0  2728.090500  8.634259  24.381270 -1.0  0.000101
# 11137  292.075   0.0   0.0  2728.090500  5.987136  16.906371 -1.0  0.000072
#
#        track_id   Ep
# 1627         -1 -1.0
# 1628         -1 -1.0
# 1629         -1 -1.0
# 1630         -1 -1.0
# 1631         -1 -1.0
# ...         ...  ...
# 11133        -1 -1.0
# 11134        -1 -1.0
# 11135        -1 -1.0
# 11136        -1 -1.0
# 11137        -1 -1.0
#
# [9511 rows x 17 columns]

# %%
true_info = pd.read_hdf(file_path, 'RECO/Events')
evt = number_of_interest
pitch = 15.55

filtered_evt = true_info[true_info.event == evt]
display(filtered_evt)
#filtered_evt = this_evt_true_info[(this_evt_true_info.X > 0)]
#filtered_evt = filtered_evt[(filtered_evt.X < 400)]
#filtered_evt = filtered_evt[(filtered_evt.X > 50)]
#filtered_evt = filtered_evt[(filtered_evt.Y > -200)]
#filtered_evt = filtered_evt[(filtered_evt.Y < 100)]
#filtered_evt = filtered_evt[(filtered_evt.Z > 1600)]
#filtered_evt = filtered_evt[(filtered_evt.Z < 1800)]
filtered_evt = filtered_evt[filtered_evt.Q > 35]

plt.figure(figsize = (10,8))

xx = np.arange(filtered_evt.X.min(), filtered_evt.X.max() + pitch, pitch)
yy = np.arange(filtered_evt.Y.min(), filtered_evt.Y.max() + pitch, pitch)
zz = filtered_evt.Z.unique()

xx_MC = xx
yy_MC = yy
zz_MC = zz

energy_hist = plt.hist2d(filtered_evt.X, filtered_evt.Y, bins=[xx, yy], weights=filtered_evt.Q, cmin=0.0001);
plt.xlabel('X (mm)');
#plt.ylabel('Y (mm)');
plt.ylabel('Z (mm)');
cbar = plt.colorbar(energy_hist[3])
cbar.set_label('SiPM charge (PE)')
#plt.hist2d(filtered_evt.X, filtered_evt.Z, bins=[xx, zz], weights=filtered_evt.Q, cmin=0.0001);
#plt.set_xlabel('X (mm)');
#plt.set_ylabel('Z (mm)');
#plt.xlim([100, 450])
#plt.ylim([-150, 325])


plt.title('Alpha track candidate', fontsize=30)
plt.savefig('alpha_track_candidate.pdf')
# Out:
#         event          time  npeak       Xpeak       Ypeak  nsipm        X  \
# 1627   759740  1.742945e+09      0    7.967181  -87.181131      1 -297.025
# 1628   759740  1.742945e+09      0    7.967181  -87.181131      1  104.275
# 1629   759740  1.742945e+09      0    7.967181  -87.181131      1   26.525
# 1630   759740  1.742945e+09      0    7.967181  -87.181131      1  -19.125
# 1631   759740  1.742945e+09      0    7.967181  -87.181131      1  119.825
# ...       ...           ...    ...         ...         ...    ...      ...
# 11133  759740  1.742945e+09      4  153.062807  175.072465      1  381.175
# 11134  759740  1.742945e+09      4  153.062807  175.072465      1  288.875
# 11135  759740  1.742945e+09      4  153.062807  175.072465      1  319.975
# 11136  759740  1.742945e+09      4  153.062807  175.072465      1  366.625
# 11137  759740  1.742945e+09      4  153.062807  175.072465      1  366.625
#
#              Y  Xrms  Yrms            Z         Q          E   Qc        Ec  \
# 1627    75.375   0.0   0.0   928.859125  5.409806  -4.149327 -1.0 -0.000012
# 1628  -464.375   0.0   0.0   928.859125  5.686775  -4.361763 -1.0 -0.000015
# 1629  -263.225   0.0   0.0   928.859125  5.923001  -4.542949 -1.0 -0.000013
# 1630   492.725   0.0   0.0   931.851250  5.096422  83.881361 -1.0       NaN
# 1631    75.875   0.0   0.0   931.851250  5.028828  82.768839 -1.0  0.000236
# ...        ...   ...   ...          ...       ...        ...  ...       ...
# 11133  307.625   0.0   0.0  2725.037000  8.748800  40.876313 -1.0       NaN
# 11134  276.525   0.0   0.0  2728.090500  5.472166  15.452206 -1.0  0.000060
# 11135  292.075   0.0   0.0  2728.090500  5.119298  14.455784 -1.0  0.000060
# 11136  276.525   0.0   0.0  2728.090500  8.634259  24.381270 -1.0  0.000101
# 11137  292.075   0.0   0.0  2728.090500  5.987136  16.906371 -1.0  0.000072
#
#        track_id   Ep
# 1627         -1 -1.0
# 1628         -1 -1.0
# 1629         -1 -1.0
# 1630         -1 -1.0
# 1631         -1 -1.0
# ...         ...  ...
# 11133        -1 -1.0
# 11134        -1 -1.0
# 11135        -1 -1.0
# 11136        -1 -1.0
# 11137        -1 -1.0
#
# [9511 rows x 17 columns]

# %%
    plt.figure(figsize=(10,8))
    c = plt.Circle((0,0), 500, facecolor=(.1, .1, .1, .06), edgecolor="k")
    plt.gca().add_patch(c)
    #filtered_evt = filtered_evt[(filtered_evt.Y > -200)]
    energy_hist = plt.hist2d(filtered_evt.X, filtered_evt.Y, bins=[xx, yy], weights=filtered_evt.Q, vmin = 0, cmin=0.0001, edgecolors = 'w', linewidths = 0.05);
    #energy_scat = plt.scatter(filtered_evt.X, filtered_evt.Y, c=filtered_evt.Q, s = 1, marker = 's', vmin = 0)
    plt.xlabel("x (mm)")
    plt.ylabel("y (mm)")
    plt.xticks(np.arange(-400, 401, 200))
    plt.yticks(np.arange(-400, 401, 200))
    plt.xlim(-500, 500)
    plt.ylim(-500, 500)
    plt.gca().set_aspect(1)
    plt.colorbar().set_label("SiPM response (pe)")
    plt.grid()

# %%
    plt.figure(figsize=(10,8))
    c = plt.Circle((0,0), 500, facecolor=(.1, .1, .1, .06), edgecolor="k")
    plt.gca().add_patch(c)
    filtered_evt = filtered_evt[(filtered_evt.Y > -200)]
    energy_hist = plt.hist2d(filtered_evt.X, filtered_evt.Y, bins=[xx, yy], weights=filtered_evt.Q, vmin = 0, cmin=0.0001);

    plt.xlabel("x (mm)")
    plt.ylabel("y (mm)")
    plt.xticks(np.arange(-400, 401, 200))
    plt.yticks(np.arange(-400, 401, 200))
    plt.xlim(-500, 500)
    plt.ylim(-500, 500)
    plt.gca().set_aspect(1)
    plt.colorbar().set_label("SiPM response (pe)")
    plt.grid()

# %%
q_cut = 8
drop_dist       = [16, 16]
cut_sensors       = beerfun.cut_over_Q   (q_cut, ['E', 'Ec'])
drop_sensors      = beerfun.drop_isolated(drop_dist, ['E', 'Ec'])
hits_cut = coref.timefunc(cut_sensors)(soph_hits.copy())
hits_drop = coref.timefunc(drop_sensors)(hits_cut.copy())
pitch = 15.55
# then applying transformations to convert to 'SiPM outputs'
fig, axes = plt.subplots(1, 3, figsize=(18, 6))


xx = np.arange(hits_drop.X.min(), hits_drop.X.max() + pitch, pitch)
yy = np.arange(hits_drop.Y.min(), hits_drop.Y.max() + pitch, pitch)
zz = hits_cut.Z.unique()

axes[0].hist2d(hits_drop.X, hits_drop.Y, bins=[xx, yy], weights=hits_drop.Q, cmin=0.0001);
axes[0].set_xlabel('X (mm)');
axes[0].set_ylabel('Y (mm)');

axes[1].hist2d(hits_drop.X, hits_drop.Z, bins=[xx, zz], weights=hits_drop.Q, cmin=0.0001);
axes[1].set_xlabel('X (mm)');
axes[1].set_ylabel('Z (mm)');


axes[2].hist2d(hits_drop.Y, hits_drop.Z, bins=[yy, zz], weights=hits_drop.Q, cmin=0.0001);
axes[2].set_xlabel('Y (mm)');
axes[2].set_ylabel('Z (mm)');

fig.suptitle('Processed Sensors Signal_' + str(evt), fontsize=30)

#plt.tight_layout()
# Out:
# Time spent in cut_over_Q: 0.020863771438598633 s
# Time spent in drop_isolated: 0.009417295455932617 s
# Text(0.5, 0.98, 'Processed Sensors Signal_1541668')

# %% [markdown]
# ### quick plotting change (for simplicity)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))


xx = np.arange(hits_drop.X.min(), hits_drop.X.max() + pitch, pitch)
yy = np.arange(hits_drop.Y.min(), hits_drop.Y.max() + pitch, pitch)
zz = hits_cut.Z.unique()

xx_MC = xx
yy_MC = yy
zz_MC = zz

axes[0].hist2d(hits_drop.X, hits_drop.Y, bins=[xx, yy], weights=hits_drop.Q, cmin=0.0001);
axes[0].set_xlabel('X (mm)');
axes[0].set_ylabel('Y (mm)');

axes[1].hist2d(hits_drop.X, hits_drop.Z, bins=[xx, zz], weights=hits_drop.Q, cmin=0.0001);
axes[1].set_xlabel('X (mm)');
axes[1].set_ylabel('Z (mm)');


fig.suptitle('Post-sophronia sensor signal', fontsize=30)
# Out:
# Text(0.5, 0.98, 'Post-sophronia sensor signal')

# %%
true_info = pd.read_hdf(file_path, 'RECO/Events')
evt = 618469

this_evt_true_info = true_info[true_info.event == evt]

filtered_evt = this_evt_true_info[(this_evt_true_info.X > -300)]
filtered_evt = filtered_evt[(this_evt_true_info.X < -100)]
filtered_evt = filtered_evt[(filtered_evt.Y > 250)]
filtered_evt = filtered_evt[(filtered_evt.Y < 450)]
filtered_evt = filtered_evt[(filtered_evt.Z > 1600)]
filtered_evt = filtered_evt[(filtered_evt.Z < 1800)]

display(this_evt_true_info)

# interpolate

xt = filtered_evt.X
yt = filtered_evt.Y
zt = filtered_evt.Z
et = filtered_evt.E

fig = plt.figure()
#fig.suptitle('3D post deconvolution ' + str(evt), fontsize=30)
fig.suptitle('Electron candidate event', fontsize=30)
ax = fig.add_subplot(111, projection='3d')



ets = et > 80 # eliminate small things for measurement

#p = ax.scatter(x[em], y[em], z[em], c=e[em], alpha=0.3, cmap='viridis')
#plt_sphere([(-track.blob2_x.values[0], -track.blob2_y.values[0], -track.blob2_z.values[0])], [blobR])
p = ax.scatter([xt[ets]], yt[ets], zt[ets], c=et[ets], alpha=0.65, cmap='viridis', s = 30)#, s = et[ets])
#q = ax.scatter(xt, yt, zt, alpha = 0.3, color = 'red')

# overlay the blobs and their radii

cb = fig.colorbar(p, ax=ax)
cb.set_label('Energy (keV)')


ax.set_xlabel('\nx (mm)')
ax.set_ylabel('\ny (mm)')
ax.set_zlabel('\nz (mm)')

ax.set_xlim([-300, -100])
ax.set_ylim([250, 450])
ax.set_zlim([1600, 1800])
ax.view_init(20, -150)

#plt.savefig(f'gif_making/deconv/angle_{i}.png')
plt.savefig(f'nice_plot.pdf')
plt.show()

filtered_evt.to_hdf('filtered_event.h5', key = 'good_stuff')
# Out:
# /tmp/ipykernel_34079/3536429867.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_evt = filtered_evt[(this_evt_true_info.X < -100)]
#          event          time  npeak     Xpeak      Ypeak  nsipm        X  \
# 461982  618469  1.730649e+09      0  111.0944  12.966709      1 -265.925
# 461983  618469  1.730649e+09      0  111.0944  12.966709      1  -19.125
# 461984  618469  1.730649e+09      0  111.0944  12.966709      1  227.675
# 461985  618469  1.730649e+09      0  111.0944  12.966709      1  149.925
# 461986  618469  1.730649e+09      0  111.0944  12.966709      1 -389.325
# ...        ...           ...    ...       ...        ...    ...      ...
# 465783  618469  1.730649e+09      0  111.0944  12.966709      1  -81.325
# 465784  618469  1.730649e+09      0  111.0944  12.966709      1  -65.775
# 465785  618469  1.730649e+09      0  111.0944  12.966709      1  243.225
# 465786  618469  1.730649e+09      0  111.0944  12.966709      1  381.175
# 465787  618469  1.730649e+09      0  111.0944  12.966709      1  104.275
#
#               Y  Xrms  Yrms            Z          Q          E   Qc   Ec  \
# 461982 -201.525   0.0   0.0   940.837500   5.403278  -4.892044 -1.0 -1.0
# 461983  369.325   0.0   0.0   940.837500   6.378484  -5.774980 -1.0 -1.0
# 461984  183.725   0.0   0.0   940.837500   5.176700  -4.686903 -1.0 -1.0
# 461985  369.325   0.0   0.0   940.837500   6.460370  -5.849118 -1.0 -1.0
# 461986  276.525   0.0   0.0   945.732625   5.872298  30.574573 -1.0 -1.0
# ...         ...   ...   ...          ...        ...        ...  ...  ...
# 465783   75.875   0.0   0.0  1944.750000   5.275096   7.395539 -1.0 -1.0
# 465784  477.175   0.0   0.0  1944.750000   5.408134   7.582055 -1.0 -1.0
# 465785 -340.975   0.0   0.0  1944.750000  18.288076  25.639378 -1.0 -1.0
# 465786   75.375   0.0   0.0  1944.750000   5.485300   7.690239 -1.0 -1.0
# 465787 -402.175   0.0   0.0  1948.189500   5.180300  45.111554 -1.0 -1.0
#
#         track_id   Ep
# 461982        -1 -1.0
# 461983        -1 -1.0
# 461984        -1 -1.0
# 461985        -1 -1.0
# 461986        -1 -1.0
# ...          ...  ...
# 465783        -1 -1.0
# 465784        -1 -1.0
# 465785        -1 -1.0
# 465786        -1 -1.0
# 465787        -1 -1.0
#
# [3806 rows x 17 columns]

# %% [markdown]
# ### making a nice set of plots for Helena

# %%
from cycler import cycler

color_sequence = ("k", "m", "g", "b", "r",
                  "gray", "aqua", "gold", "lime", "purple",
                  "brown", "lawngreen", "tomato", "lightgray", "lightpink")

def auto_plot_style(overrides = dict()):
    plt.rcParams[ "figure.figsize"               ] = 10, 8
    plt.rcParams[   "font.size"                  ] = 25
    plt.rcParams[  "lines.markersize"            ] = 25
    plt.rcParams[  "lines.linewidth"             ] = 3
    plt.rcParams[  "patch.linewidth"             ] = 3
    plt.rcParams[   "axes.linewidth"             ] = 2
    plt.rcParams[   "grid.linewidth"             ] = 3
    plt.rcParams[   "grid.linestyle"             ] = "--"
    plt.rcParams[   "grid.alpha"                 ] = 0.5
    plt.rcParams["savefig.dpi"                   ] = 300
    plt.rcParams["savefig.bbox"                  ] = "tight"
    plt.rcParams[   "axes.formatter.use_mathtext"] = True
    plt.rcParams[   "axes.formatter.limits"      ] = (-3 ,4)
    plt.rcParams[  "xtick.major.size"            ] = 10
    plt.rcParams[  "ytick.major.size"            ] = 10
    plt.rcParams[  "xtick.minor.size"            ] = 5
    plt.rcParams[  "ytick.minor.size"            ] = 5
    plt.rcParams[   "axes.prop_cycle"            ] = cycler(color=color_sequence)
    plt.rcParams[  "image.cmap"                  ] = "gnuplot2"
    plt.rcParams.update(overrides)

# %%
auto_plot_style()

# %%
true_info = pd.read_hdf(file_path, 'RECO/Events')
evt = 3698

filtered_evt = true_info[true_info.event == evt]

#filtered_evt = this_evt_true_info[(this_evt_true_info.X > 0)]
filtered_evt = filtered_evt[(filtered_evt.X < 600)]
filtered_evt = filtered_evt[(filtered_evt.X > -100)]
filtered_evt = filtered_evt[(filtered_evt.Y > 000)]
filtered_evt = filtered_evt[(filtered_evt.Y < 400)]
#filtered_evt = filtered_evt[(filtered_evt.Z > 1600)]
#filtered_evt = filtered_evt[(filtered_evt.Z < 1800)]
filtered_evt = filtered_evt[filtered_evt.Q > 11]
plt.figure(figsize = (10,8))

xx = np.arange(filtered_evt.X.min(), filtered_evt.X.max() + pitch, pitch)
yy = np.arange(filtered_evt.Y.min(), filtered_evt.Y.max() + pitch, pitch)
zz = hits_cut.Z.unique()

xx_MC = xx
yy_MC = yy
zz_MC = zz

energy_hist = plt.hist2d(filtered_evt.X, filtered_evt.Y, bins=[xx, yy], weights=filtered_evt.Q, cmin=0.0001);
plt.xlabel('X (mm)');
plt.ylabel('Y (mm)');
cbar = plt.colorbar(energy_hist[3])
cbar.set_label('SiPM charge (PE)')
#plt.hist2d(filtered_evt.X, filtered_evt.Z, bins=[xx, zz], weights=filtered_evt.Q, cmin=0.0001);
#plt.set_xlabel('X (mm)');
#plt.set_ylabel('Z (mm)');
plt.xlim([0, 350])
plt.ylim([170, 370])


plt.title('Electron track candidate', fontsize=30)
plt.savefig('electron_candidate.pdf')

# %%
hfiltered_evt = hits_drop

plt.figure(figsize = (10,8))

xx = np.arange(hfiltered_evt.X.min(), hfiltered_evt.X.max() + pitch, pitch)
yy = np.arange(hfiltered_evt.Y.min(), hfiltered_evt.Y.max() + pitch, pitch)
zz = hfiltered_evt.Z.unique()

xx_MC = xx
yy_MC = yy
zz_MC = zz

energy_hist = plt.hist2d(hfiltered_evt.X, hfiltered_evt.Y, bins=[xx, yy], weights=hfiltered_evt.Q, cmin=200)
plt.xlabel('X (mm)');
plt.ylabel('Y (mm)');
cbar = plt.colorbar(energy_hist[3])
cbar.set_label('SiPM charge (PE)')
#plt.hist2d(filtered_evt.X, filtered_evt.Z, bins=[xx, zz], weights=filtered_evt.Q, cmin=0.0001);
#plt.set_xlabel('X (mm)');
#plt.set_ylabel('Z (mm)');
plt.xlim([360, 525])
plt.ylim([-200, 50])


plt.title('Alpha track canditate', fontsize=30)
plt.savefig('alpha_candidate.pdf')

# %%
from scipy.interpolate import griddata

grid_x, grid_y = np.meshgrid(
    np.linspace(min(xt), max(xt), 100),
    np.linspace(min(yt), max(yt), 100)
)

# Interpolate z values on the grid
grid_z = np.nan_to_num(griddata((xt, yt), zt, (grid_x, grid_y), method='cubic'), 0)

# Plot the original scatter points
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(xt, yt, zt, color='red', label='Original Points')

# Plot the interpolated surface
ax.plot_surface(grid_x, grid_y, grid_z, cmap='viridis', alpha=0.7)

# %%
rotation = True
if rotation==True:
  rotation_space = np.linspace(0, 359, 180, endpoint = True)

  for i in (rotation_space):
    fig = plt.figure()
    fig.suptitle('3D event ' + str(evt), fontsize=30)
    ax = fig.add_subplot(111, projection='3d')
    #em = e > 0.00005 # eliminate small things for measurement
    #p = ax.scatter(x[em], y[em], z[em], c=e[em], alpha=0.3, cmap='viridis')
    #plt_sphere([(-track.blob2_x.values[0], -track.blob2_y.values[0], -track.blob2_z.values[0])], [blobR])
    p = ax.scatter([xt[ets]], yt[ets], zt[ets], c=et[ets]/1000, alpha=0.5, cmap='viridis', s = 100)

    # overlay the blobs and their radii

    cb = fig.colorbar(p, ax=ax)
    cb.set_label('Energy (keV)')

    ax.set_xlabel('x (mm)')
    ax.set_ylabel('y (mm)')
    ax.set_zlabel('z (mm)')
    
    ax.set_xlim([-300, -100])
    ax.set_ylim([250, 450])
    ax.set_zlim([1600, 1800])
    ax.view_init(20, -i)
    plt.savefig(f'gif_making/deconv/angle_{i}.png')
    plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 27
#      25 ax.set_zlim([1600, 1800])
#      26 ax.view_init(20, -i)
# ---> 27 plt.savefig(f'gif_making/deconv/angle_{i}.png')
#      28 plt.close(fig)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/pyplot.py:966, in savefig(*args, **kwargs)
#     963 @_copy_docstring_and_deprecators(Figure.savefig)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/figure.py:3015, in Figure.savefig(self, fname, transparent, **kwargs)
#    3012         patch.set_facecolor('none')
#    3013         patch.set_edgecolor('none')
# -> 3015 self.canvas.print_figure(fname, **kwargs)
#    3017 if transparent:
#    3018     for ax, cc in zip(self.axes, original_axes_colors):
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/backend_bases.py:2255, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2251 try:
#    2252     # _get_renderer may change the figure dpi (as vector formats
#    2253     # force the figure dpi to 72), so we need to set it again here.
#    2254     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255         result = print_method(
#    2256             filename,
#    2257             facecolor=facecolor,
#    2258             edgecolor=edgecolor,
#    2259             orientation=orientation,
#    2260             bbox_inches_restore=_bbox_inches_restore,
#    2261             **kwargs)
#    2262 finally:
#    2263     if bbox_inches and restore_bbox:
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/backend_bases.py:1669, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1661     _api.warn_deprecated(
#    1662         '3.3', name=name,
#    1663         message='%(name)s() got unexpected keyword argument "'
#    1664                 + arg + '" which is no longer supported as of '
#    1665                 '%(since)s and will become an error '
#    1666                 '%(removal)s')
#    1667     kwargs.pop(arg)
# -> 1669 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:508, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     459 @_check_savefig_extra_args
#     460 def print_png(self, filename_or_obj, *args,
#     461               metadata=None, pil_kwargs=None):
#     462     """
#     463     Write the figure to a PNG file.
#     464
#    (...)
#     506         *metadata*, including the default 'Software' key.
#     507     """
# --> 508     FigureCanvasAgg.draw(self)
#     509     mpl.image.imsave(
#     510         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:406, in FigureCanvasAgg.draw(self)
#     402 # Acquire a lock on the shared font cache.
#     403 with RendererAgg.lock, \
#     404      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405       else nullcontext()):
# --> 406     self.figure.draw(self.renderer)
#     407     # A GUI class may be need to update a window using this draw, so
#     408     # don't forget to call the superclass.
#     409     super().draw()
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer, *args, **kwargs)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/figure.py:2790, in Figure.draw(self, renderer)
#    2787         # ValueError can occur when resizing a window.
#    2789 self.patch.draw(renderer)
# -> 2790 mimage._draw_list_compositing_images(
#    2791     renderer, self, artists, self.suppressComposite)
#    2793 for sfig in self.subfigs:
#    2794     sfig.draw(renderer)
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer, *args, **kwargs)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/text.py:679, in Text.draw(self, renderer)
#     676 renderer.open_group('text', self.get_gid())
#     678 with _wrap_text(self) as textobj:
# --> 679     bbox, info, descent = textobj._get_layout(renderer)
#     680     trans = textobj.get_transform()
#     682     # don't use textobj.get_position here, which refers to text
#     683     # position in Text:
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/text.py:441, in Text._get_layout(self, renderer)
#     438 xys = M.transform(offset_layout) - (offsetx, offsety)
#     440 ret = bbox, list(zip(lines, zip(ws, hs), *xys.T)), descent
# --> 441 self._cached[key] = ret
#     442 return ret
#
# File ~/anaconda3/envs/IC-3.8-2024-06-08/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:591, in maxdict.__setitem__(self, k, v)
#     590 def __setitem__(self, k, v):
# --> 591     if k not in self:
#     592         if len(self) >= self.maxsize:
#     593             del self[self._killkeys[0]]
#
# KeyboardInterrupt:

# %% [markdown]
# #### BEERSHEBA
#
# Pass through an isaura file

# %% [markdown]
# #### Track visualisation

# %%
#file_path = '/home/e78368jw/Downloads/tmp_out/testing_arena/rel_0.2/isaura_' + str(FILE_NUMBER) + '_208Tl.h5'
file_path = '/home/e78368jw/Documents/NEXT_CODE/next_misc/alphas_muon_track/soph_data/beersheba_qcut8.h5'
#file_path = '/home/e78368jw/Downloads/tmp_out/testing_arena/isaura/isaura_' + str(FILE_NUMBER) + '_208Tl.h5'
#file_path = '/home/e78368jw/Documents/NEXT_CODE/IC/invisible_cities/database/test_data/228Th_10evt_deco_satellite.h5'


hdst = dstio.load_dst(file_path, 'DECO', 'Events')#CHITS/lowTh
evt = 618469
hits_deco = hdst[hdst.event == evt]
#hits_deco = hdst[hdst.event == evt*2]
display(hits_deco)
# Out:
#           event  npeak        X        Y            Z         E     Xpeak  \
# 3822298  618469    0.0  439.875  -77.425   957.040875  0.000091  111.0944
# 3822299  618469    0.0  439.875  -76.425   957.040875  0.000093  111.0944
# 3822300  618469    0.0  439.875  -75.425   957.040875  0.000094  111.0944
# 3822301  618469    0.0  439.875  -74.425   957.040875  0.000094  111.0944
# 3822302  618469    0.0  439.875  -73.425   957.040875  0.000094  111.0944
# ...         ...    ...      ...      ...          ...       ...       ...
# 3829465  618469    0.0 -222.125  305.575  1756.689250  0.000102  111.0944
# 3829466  618469    0.0 -222.125  306.575  1756.689250  0.000101  111.0944
# 3829467  618469    0.0 -222.125  307.575  1756.689250  0.000093  111.0944
# 3829468  618469    0.0 -221.125  305.575  1756.689250  0.000092  111.0944
# 3829469  618469    0.0 -221.125  306.575  1756.689250  0.000091  111.0944
#
#              Ypeak          time  nsipm  Xrms  Yrms
# 3822298  12.966709  1.730649e+09      0     0     0
# 3822299  12.966709  1.730649e+09      0     0     0
# 3822300  12.966709  1.730649e+09      0     0     0
# 3822301  12.966709  1.730649e+09      0     0     0
# 3822302  12.966709  1.730649e+09      0     0     0
# ...            ...           ...    ...   ...   ...
# 3829465  12.966709  1.730649e+09      0     0     0
# 3829466  12.966709  1.730649e+09      0     0     0
# 3829467  12.966709  1.730649e+09      0     0     0
# 3829468  12.966709  1.730649e+09      0     0     0
# 3829469  12.966709  1.730649e+09      0     0     0
#
# [7172 rows x 12 columns]

# %%
#xt = this_evt_true_info.x
#yt = this_evt_true_info.y
#zt = this_evt_true_info.z

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

xx = np.arange(hits_deco.X.min(), hits_deco.X.max())
yy = np.arange(hits_deco.Y.min(), hits_deco.Y.max())
zz = np.sort(hits_deco.Z.unique())

#axes[0].scatter(xt, yt,  alpha=0.05, color='red')
axes[0].hist2d(hits_deco.X, hits_deco.Y, bins=[xx, yy], weights=hits_deco.E, cmin=0.0001);
#axes[0].set_xlim([xx_MC.min(), xx_MC.max()])
#axes[0].set_ylim([yy_MC.min(), yy_MC.max()])
axes[0].set_xlabel('X (mm)');
axes[0].set_ylabel('Y (mm)');

#axes[1].scatter(xt, zt,  alpha=0.05, color='red')
#axes[1].hist2d(hits_deco.X, hits_deco.Z, bins=[xx, zz], weights=hits_deco.E, cmin=0.0001);

#axes[1].set_xlim([xx_MC.min(), xx_MC.max()])
#axes[1].set_ylim([zz_MC.min(), zz_MC.max()])
axes[1].set_xlabel('X (mm)');
axes[1].set_ylabel('Z (mm)');


fig.suptitle('deconvolved tracks after changes', fontsize=30)
# Out:
# Text(0.5, 0.98, 'deconvolved tracks after changes')

# %%
# relevant beersheba nonsense

pitch = 15.55


hdst = dstio.load_dst(file_path, 'DECO', 'Events')#CHITS/lowTh

hits = hdst[hdst.event == evt*2]
display(hits)

x_range, y_range, z_range, mid_x, mid_y, mid_z, min_x, min_y, min_z, max_x, max_y, max_z, xbins, ybins, zbins = func.collect_max_min(hits)
# then applying transformations to convert to 'SiPM outputs'
fig, axes = plt.subplots(1, 3, figsize=(18, 4))


xx = np.arange(hits.X.min(), hits.X.max() + pitch, pitch)
yy = np.arange(hits.Y.min(), hits.Y.max() + pitch, pitch)
zz = hits.Z.unique()

axes[0].hist2d(hits.X, hits.Y, bins=[xx, yy], weights=hits.Q, cmin=0.0001);
axes[0].set_xlabel('X (mm)');
axes[0].set_ylabel('Y (mm)');

axes[1].hist2d(hits.X, hits.Z, bins=[xx, zz], weights=hits.Q, cmin=0.0001);
axes[1].set_xlabel('X (mm)');
axes[1].set_ylabel('Z (mm)');

axes[2].hist2d(hits.Y, hits.Z, bins=[yy, zz], weights=hits.Q, cmin=0.0001);
axes[2].set_xlabel('Y (mm)');
axes[2].set_ylabel('Z (mm)');

for pid, df in this_evt_true_info.groupby('particle_name'):

    xt = df.x
    yt = df.y
    zt = df.z
    et = df.energy*1000

   
    if (pid == 'gamma') or (pid == 'Xe131') or (pid == 'Xe129'):
        axes[0].scatter(xt, yt,  alpha=1, label = str(pid))
        axes[1].scatter(xt, zt,  alpha=1, label = str(pid))
        axes[2].scatter(yt, zt,  alpha=1, label = str(pid))
    else:
        axes[0].scatter(xt, yt,  alpha=0.1, label = str(pid))
        axes[1].scatter(xt, zt,  alpha=0.1, label = str(pid))
        axes[2].scatter(yt, zt,  alpha=0.1, label = str(pid))


fig.suptitle('deconvolved_evt_' + str(evt), fontsize=30)

fig.show()

x = hits.X
y = hits.Y
z = hits.Z
e = hits.E

xt = this_evt_true_info.x
yt = this_evt_true_info.y
zt = this_evt_true_info.z
et = this_evt_true_info.energy*1000

fig = plt.figure()
fig.suptitle('3D post deconvolution ' + str(evt), fontsize=30)
ax = fig.add_subplot(111, projection='3d')
#em = e > 0.00005 # eliminate small things for measurement
#p = ax.scatter(x[em], y[em], z[em], c=e[em], alpha=0.3, cmap='viridis')
p = ax.scatter(x, y, z, c=e, alpha=0.03, cmap='viridis')
q = ax.scatter(xt, yt, zt, alpha = 0.3, color = 'r')
cb = fig.colorbar(p, ax=ax)
cb.set_label('Energy (keV)')

ax.set_xlabel('x (mm)')
ax.set_ylabel('y (mm)')
ax.set_zlabel('z (mm)')
#ax.view_init(-160, 90)
plt.show()
# Out:
# Empty DataFrame
# Columns: [event, npeak, X, Y, Z, E, Xpeak, Ypeak, time, nsipm, Xrms, Yrms]
# Index: []
# X maximum and minimum
# nan nan
#
# Y maximum and minimum
# nan nan
#
# Z maximum and minimum
# nan nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 11
#       8 hits = hdst[hdst.event == evt*2]
#       9 display(hits)
# ---> 11 x_range, y_range, z_range, mid_x, mid_y, mid_z, min_x, min_y, min_z, max_x, max_y, max_z, xbins, ybins, zbins = func.collect_max_min(hits)
#      12 # then applying transformations to convert to 'SiPM outputs'
#      13 fig, axes = plt.subplots(1, 3, figsize=(18, 4))
#
# File ~/Documents/NEXT_CODE/next_misc/toolbox/functions.py:28, in collect_max_min(hits)
#      25 print("Z maximum and minimum")
#      26 print(max_z, min_z)
# ---> 28 xbins = int(hits.X.max()-hits.X.min())
#      29 ybins = int(hits.Y.max()-hits.Y.min())
#      30 zbins = int((hits.Z.max()-hits.Z.min())/2.)
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# #### ISAURA
# Make sure you have run beersheba to get this output

# %% [markdown]
# #### Track information

# %%
track = dstio.load_dst(file_path, 'Tracking', 'Tracks')#CHITS/lowTh

track = track[track.event == evt*2]

for i in range(len(track.columns)):
    print(f'{track.columns[i]}: {track.iloc[0][track.columns[i]]}')
# Out:
# event: 1980402.0
# trackID: 0.0
# energy: 1.59186260912737
# length: 144.2321863949552
# numb_of_voxels: 102.0
# numb_of_hits: 12149.0
# numb_of_tracks: 1.0
# x_min: -80.125
# y_min: 80.57499999999999
# z_min: 352.8792093750001
# r_min: 102.14522137623472
# x_max: 35.875
# y_max: 164.575
# z_max: 433.46050781250005
# r_max: 166.2977638153923
# x_ave: -25.804866498696523
# y_ave: 114.39093409041705
# z_ave: 389.84482335297673
# r_ave: 123.52737309329682
# extreme1_x: -74.32500000000269
# extreme1_y: 85.88749999999737
# extreme1_z: 358.6350164062475
# extreme2_x: 30.075000000002703
# extreme2_y: 149.63750000000186
# extreme2_z: 404.6814726562509
# blob1_x: -71.9371300562057
# blob1_y: 88.15229036542469
# blob1_z: 358.88268225118713
# blob2_x: 28.561597744166434
# blob2_y: 150.45426422894008
# blob2_z: 402.3611995258182
# eblob1: 0.4772630589673764
# eblob2: 0.15246346923137524
# ovlp_blob_energy: 0.0
# vox_size_x: 11.600000000000605
# vox_size_y: 10.625000000000753
# vox_size_z: 11.511614062500882

# %% [markdown]
# ### Visualisation
#
# First with the blob highlights

# %%
blobR = 18 # mm
rotation = True


# need a sphere plotter for the blob radii
def plt_sphere(list_center, list_radius):
  for c, r in zip(list_center, list_radius):

    print(c)
    # draw sphere
    u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j]
    x_s = r*np.cos(u)*np.sin(v)
    y_s = r*np.sin(u)*np.sin(v)
    z_s = r*np.cos(v)

    ax.plot_surface(x_s-c[0], y_s-c[1], z_s-c[2], color=np.random.choice(['r']), alpha=0.2)




if rotation==True:
  rotation_space = np.linspace(0, 359, 30, endpoint = True)

  for i in (rotation_space):
    fig = plt.figure()
    fig.suptitle('3D post deconvolution ' + str(evt), fontsize=30)
    ax = fig.add_subplot(111, projection='3d')
    #em = e > 0.00005 # eliminate small things for measurement
    #p = ax.scatter(x[em], y[em], z[em], c=e[em], alpha=0.3, cmap='viridis')
    plt_sphere([(-track.blob2_x.values[0], -track.blob2_y.values[0], -track.blob2_z.values[0])], [blobR])
    p = ax.scatter(x, y, z, c=e, alpha=0.03, cmap='viridis')
    q = ax.scatter(xt, yt, zt, alpha = 0.3, color = 'red')

    # overlay the blobs and their radii

    cb = fig.colorbar(p, ax=ax)
    cb.set_label('Energy (keV)')

    ax.set_xlabel('x (mm)')
    ax.set_ylabel('y (mm)')
    ax.set_zlabel('z (mm)')
    ax.view_init(20, -i)
    plt.savefig(f'gif_making/deconv/angle_{i}.png')
    plt.close(fig)
# Out:
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)

# %%
if rotation == True:
    
    files = [f for f in os.listdir('gif_making/deconv/') if os.path.isfile(os.path.join('gif_making/deconv/', f))]

    #sort files in a human manner
    files.sort(key=func.alphanum_key)
    images = []
    for filename in files:
        images.append(imageio.imread('gif_making/deconv/' + filename))
    

    print("Creating gif...")
    gif_name = f'output/rotating_track_evt_{evt}.gif'
    imageio.mimsave(gif_name, images, loop = 0, fps = 20)
# Out:
# /tmp/ipykernel_12883/1821347754.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread('gif_making/deconv/' + filename))
# Creating gif...

# %% [markdown]
# #### warning, you need to autoset the event number to visualise the new tracks

# %% [markdown]
# <img src=output/rotating_track_evt_990201.gif width="750" align="center">

# %% [markdown]
# Then as voxels

# %%
base_vsize = 12 #mm
the_hits = []

xs = x
ys = y
zs = z
es = e

for x, y, z, e in zip(xs, ys, zs, es):
    if np.isnan(e): continue
    h = Hit(0, Cluster(0, xy(x,y), xy(0,0), 0), z, e*1000, xy(0,0))
    the_hits.append(h)

voxels = voxelize_hits(the_hits,
                       np.array([base_vsize, base_vsize, base_vsize]), False)

vsizex = voxels[0].size[0]
vsizey = voxels[0].size[1]
vsizez = voxels[0].size[2]

min_corner_x = min(v.X for v in voxels) - vsizex/2.
min_corner_y = min(v.Y for v in voxels) - vsizey/2.
min_corner_z = min(v.Z for v in voxels) - vsizez/2.

x = [np.round(v.X/vsizex) for v in voxels]
y = [np.round(v.Y/vsizey) for v in voxels]
z = [np.round(v.Z/vsizez) for v in voxels]
e = [v.E for v in voxels]

x_min = int(min(x))
y_min = int(min(y))
z_min = int(min(z))

x_max = int(max(x))
y_max = int(max(y))
z_max = int(max(z))

#print(f'X min = {x_min}, X max = {x_max}')
#print(f'Y min = {y_min}, Y max = {y_max}')
#print(f'Z min = {z_min}, Z max = {z_max}')

VOXELS = np.zeros((x_max-x_min+1, y_max-y_min+1, z_max-z_min+1))
#print(VOXELS.shape)

# sort through the event set the "turn on" the hit voxels
cmap = cm.viridis
norm = Normalize(vmin=0, vmax=max(e))

colors = np.empty(VOXELS.shape, dtype=object)
for q in range(0,len(z)):
    VOXELS[int(x[q])-x_min][int(y[q])-y_min][int(z[q])-z_min] = 1
    colors[int(x[q])-x_min][int(y[q])-y_min][int(z[q])-z_min] = cmap(norm(e[q]))

# and plot everything
fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')
#a,b,c is spacing in mm needs an extra dim
a,b,c = np.indices((x_max-x_min+2, y_max-y_min+2, z_max-z_min+2))
a = a*vsizex + min_corner_x
b = b*vsizey + min_corner_y
c = c*vsizez + min_corner_z

# a, b, c are the corners of the voxels
ax.voxels(a,b,c, VOXELS, facecolors=colors , edgecolor='k',alpha=0.8)
plt_sphere([(-track.blob2_x.values[0], -track.blob2_y.values[0], -track.blob2_z.values[0])], [blobR])

ax.set_xlabel('x (mm)')#,fontsize=16)
ax.set_ylabel('y (mm)')#,fontsize=16)
ax.set_zlabel('z (mm)')#,fontsize=16)


sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cb = fig.colorbar(sm)
cb.set_label('Energy (keV)')

fig.suptitle('voxelised_plot_' + str(evt))

#ax.view_init(-160, 90)

plt.show(fig)
# Out:
# /tmp/ipykernel_12932/431890950.py:56: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)

# %%
if rotation==True:
    for i in (rotation_space):
        # and plot everything
        fig = plt.figure(figsize=(8,8))
        ax = fig.gca(projection='3d')

        # a, b, c are the corners of the voxels
        ax.voxels(a,b,c, VOXELS, facecolors=colors , edgecolor='k',alpha=0.8)
        plt_sphere([(-track.blob2_x.values[0], -track.blob2_y.values[0], -track.blob2_z.values[0])], [blobR])

        ax.set_xlabel('x (mm)')#,fontsize=16)
        ax.set_ylabel('y (mm)')#,fontsize=16)
        ax.set_zlabel('z (mm)')#,fontsize=16)


        sm = cm.ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])
        cb = fig.colorbar(sm)
        cb.set_label('Energy (keV)')

        fig.suptitle('voxelised_plot_' + str(evt))
        ax.view_init(20, -i)
        plt.savefig(f'gif_making/voxel/vox_angle_{i}.png')
        plt.close(fig)
        #ax.view_init(-160, 90)


    files = [f for f in os.listdir('gif_making/voxel/') if os.path.isfile(os.path.join('gif_making/voxel/', f))]

    #sort files in a human manner
    files.sort(key=func.alphanum_key)
    images = []
    for filename in files:
        images.append(imageio.imread('gif_making/voxel/' + filename))
    

    print("Creating gif...")
    gif_name = f'output/rotating_voxel_evt_{evt}.gif'
    imageio.mimsave(gif_name, images, loop = 0, fps = 7)
# Out:
# /tmp/ipykernel_12932/1973631466.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# (-28.561597744166434, -150.45426422894008, -402.3611995258182)
# /tmp/ipykernel_12932/1973631466.py:34: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread('gif_making/voxel/' + filename))
# Creating gif...

# %% [markdown]
# #### warning, you need to autoset the event number to visualise the new tracks

# %% [markdown]
# <img src=output/rotating_voxel_evt_990201.gif width="750" align="center">
